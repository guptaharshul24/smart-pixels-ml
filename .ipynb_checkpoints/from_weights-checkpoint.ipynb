# %%
import os
import tensorflow as tf
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import layers, models

from DG.OptimizedDataGenerator_v2 import OptimizedDataGenerator
from losses.diag_loss_nll import custom_diag_loss
from models.mlp_encoder_model import CreateModel

pi = 3.14159265359

maxval=1e9
minval=1e-9
# Out:
# 2025-06-26 17:50:32.023398: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-26 17:50:32.023483: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-26 17:50:32.024677: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-26 17:50:32.032597: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-26 17:50:35.192815: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model=CreateModel(shape = (16,16,2), output = 8)
model.compile(
    optimizer=tf.keras.optimizers.Nadam(learning_rate=1e-3, clipnorm=1.0),
    loss=custom_diag_loss,
)

model.summary()
# Out:
# 2025-06-26 17:50:48.141116: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 37404 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB MIG 7g.40gb, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2025-06-26 17:50:48.455287: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Model: "smrtpxl_regression"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_pxls/ (InputLayer)    [(None, 16, 16, 2)]          0         []
#
#  average_pooling2d (Average  (None, 16, 1, 2)             0         ['input_pxls/[0][0]']
#  Pooling2D)
#
#  average_pooling2d_1 (Avera  (None, 1, 16, 2)             0         ['input_pxls/[0][0]']
#  gePooling2D)
#
#  flatten_x (Flatten)         (None, 32)                   0         ['average_pooling2d[0][0]']
#
#  flatten_y (Flatten)         (None, 32)                   0         ['average_pooling2d_1[0][0]']
#
#  q_dense (QDense)            (None, 16)                   528       ['flatten_x[0][0]']
#
#  q_dense_1 (QDense)          (None, 16)                   528       ['flatten_y[0][0]']
#
#  q_activation (QActivation)  (None, 16)                   0         ['q_dense[0][0]']
#
#  q_activation_1 (QActivatio  (None, 16)                   0         ['q_dense_1[0][0]']
#  n)
#
#  concatenate (Concatenate)   (None, 32)                   0         ['q_activation[0][0]',
#                                                                      'q_activation_1[0][0]']
#
#  q_dense_2 (QDense)          (None, 16)                   528       ['concatenate[0][0]']
#
#  q_activation_2 (QActivatio  (None, 16)                   0         ['q_dense_2[0][0]']
#  n)
#
#  flatten (Flatten)           (None, 16)                   0         ['q_activation_2[0][0]']
#
#  dense_1 (QDense)            (None, 16)                   272       ['flatten[0][0]']
#
#  activation_tanh_2 (QActiva  (None, 16)                   0         ['dense_1[0][0]']
#  tion)
#
#  dense_2 (QDense)            (None, 16)                   272       ['activation_tanh_2[0][0]']
#
#  activation_tanh_3 (QActiva  (None, 16)                   0         ['dense_2[0][0]']
#  tion)
#
#  dense_3 (QDense)            (None, 8)                    136       ['activation_tanh_3[0][0]']
#
# ==================================================================================================
# Total params: 2264 (8.84 KB)
# Trainable params: 2264 (8.84 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
fingerprint = "edda7eb7"

# %%
base_dir = f'./trained_models/model-{fingerprint}-checkpoints'
plot_dir = os.path.join(base_dir, 'plots')
checkpoints_dir = os.path.join(base_dir, 'checkpoints')
training_cp_path = os.path.join(base_dir, 'training_log.csv')
training_history = pd.read_csv(training_cp_path)

os.makedirs(plot_dir, exist_ok=True)

checkpoint_files = [os.path.join(checkpoints_dir, f) for f in os.listdir(checkpoints_dir) if f.endswith('.hdf5')]
# Out:
# ['./trained_models/model-edda7eb7-checkpoints/checkpoints/weights.295-t-28964.80-v-29516.91.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.19-t-20960.18-v-20748.49.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.134-t-27464.22-v-25735.06.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.141-t-27766.50-v-28112.44.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.167-t-28067.93-v-27878.02.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.213-t-28269.05-v-27338.45.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.337-t-28986.40-v-28011.01.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.360-t-28810.91-v-27991.94.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.109-t-26592.59-v-25529.22.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.12-t-19234.88-v-19105.33.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.74-t-25637.89-v-25485.00.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.364-t-29289.47-v-29891.12.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.144-t-27596.64-v-26484.48.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.374-t-29353.82-v-28946.43.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.111-t-27036.99-v-27531.25.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.183-t-28185.69-v-27994.54.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.129-t-27642.17-v-26103.38.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.10-t-18318.68-v-18509.38.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.404-t-29312.69-v-29109.43.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.93-t-26156.75-v-25206.68.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.405-t-28932.95-v-28748.61.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.166-t-28067.92-v-28060.26.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.97-t-26344.21-v-24663.68.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.224-t-28789.28-v-29041.54.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.322-t-28982.84-v-29348.45.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.65-t-24989.81-v-24560.75.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.51-t-23805.00-v-23810.25.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.193-t-28346.94-v-28354.88.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.411-t-29429.15-v-29174.63.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.335-t-29365.76-v-28861.19.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.420-t-29453.35-v-29234.11.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.110-t-26910.66-v-27419.83.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.300-t-29080.70-v-29625.37.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.320-t-29123.96-v-29663.29.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.357-t-28899.12-v-29325.54.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.123-t-27385.33-v-26998.83.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.289-t-28577.23-v-29494.41.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.85-t-26075.36-v-25760.52.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.254-t-28655.30-v-29259.60.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.359-t-28879.10-v-27145.92.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.400-t-29259.02-v-29322.95.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.179-t-27950.94-v-28108.83.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.345-t-29128.08-v-29666.58.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.105-t-26555.85-v-26756.32.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.243-t-28680.86-v-28275.95.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.15-t-20256.99-v-20470.57.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.398-t-29325.83-v-28393.21.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.99-t-26455.74-v-26699.67.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.211-t-28616.76-v-28275.78.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.75-t-25440.36-v-25304.47.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.53-t-23891.10-v-23644.80.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.342-t-29334.02-v-28577.70.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.355-t-29289.78-v-29301.96.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.62-t-24455.19-v-24575.73.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.72-t-25169.17-v-25386.09.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.306-t-29344.10-v-28604.72.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.361-t-29274.93-v-29194.97.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.118-t-27347.34-v-24275.92.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.279-t-28983.77-v-29346.85.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.117-t-27469.95-v-25957.96.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.305-t-29245.52-v-28630.96.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.370-t-29413.70-v-29061.12.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.206-t-28650.10-v-28219.90.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.78-t-25686.21-v-25584.42.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.101-t-26660.19-v-26492.59.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.116-t-27385.82-v-27252.06.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.17-t-20485.84-v-20837.38.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.01-t10856.46-v2146.93.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.264-t-29280.93-v-29500.09.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.397-t-29479.27-v-29842.67.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.140-t-27600.68-v-27181.37.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.257-t-28830.43-v-28369.19.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.240-t-28785.58-v-27752.87.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.02-t-4288.73-v-8565.43.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.251-t-28884.48-v-29101.45.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.343-t-29298.95-v-28361.01.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.103-t-26665.24-v-26391.20.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.153-t-27630.55-v-27062.04.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.125-t-27508.92-v-27598.15.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.369-t-29616.76-v-30046.55.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.402-t-29525.35-v-27431.79.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.249-t-28637.89-v-26288.31.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.43-t-23050.96-v-23541.12.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.377-t-29195.11-v-28487.31.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.174-t-28191.59-v-27704.01.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.290-t-28724.54-v-29637.69.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.399-t-29462.37-v-27951.69.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.115-t-27247.24-v-27697.25.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.44-t-23082.78-v-22730.34.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.280-t-29133.28-v-29309.64.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.76-t-25670.34-v-24535.04.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.70-t-25034.31-v-25512.37.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.372-t-29209.55-v-28946.25.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.35-t-22779.99-v-21144.69.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.188-t-28036.78-v-27648.49.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.68-t-24936.69-v-24036.54.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.299-t-28812.09-v-29515.78.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.318-t-28965.12-v-29646.10.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.107-t-27129.49-v-27277.40.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.236-t-28574.25-v-28592.99.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.381-t-29085.12-v-29587.05.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.81-t-25497.50-v-24627.61.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.208-t-28403.44-v-27733.87.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.191-t-28147.11-v-27514.93.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.242-t-28808.07-v-29125.58.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.196-t-28314.61-v-27308.63.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.172-t-27805.45-v-27152.04.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.408-t-29375.67-v-29752.54.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.327-t-28949.53-v-29679.19.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.201-t-28515.84-v-28625.23.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.268-t-29192.42-v-29061.81.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.329-t-29542.37-v-29189.02.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.348-t-29540.85-v-29286.44.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.160-t-27989.16-v-27417.78.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.46-t-23391.65-v-22214.44.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.214-t-28481.13-v-28708.25.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.241-t-28987.89-v-29351.20.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.321-t-29088.22-v-29747.95.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.292-t-28705.38-v-28455.74.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.217-t-28675.69-v-28527.24.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.06-t-15451.83-v-15641.64.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.61-t-24468.13-v-23825.85.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.366-t-29425.08-v-29911.02.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.171-t-27970.18-v-27552.44.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.08-t-17031.26-v-17246.36.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.199-t-28161.56-v-27778.09.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.356-t-29066.61-v-29371.86.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.277-t-28926.29-v-29188.65.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.84-t-26074.89-v-26078.79.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.205-t-28587.09-v-29122.64.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.36-t-22848.90-v-23081.17.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.106-t-26979.04-v-26500.36.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.07-t-16253.85-v-16347.28.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.371-t-29397.05-v-28587.70.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.100-t-26628.67-v-26651.88.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.311-t-28942.64-v-28430.39.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.27-t-21664.04-v-22067.29.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.16-t-20313.23-v-19342.96.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.226-t-28559.44-v-28150.06.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.91-t-26050.44-v-24837.86.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.423-t-29609.49-v-30124.05.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.147-t-27922.25-v-28533.90.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.66-t-25013.26-v-25094.17.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.317-t-29052.49-v-29793.39.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.192-t-28079.05-v-28506.97.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.126-t-27546.46-v-26274.12.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.378-t-29180.23-v-29359.88.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.122-t-27461.26-v-27099.71.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.230-t-28834.76-v-28311.46.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.421-t-29651.75-v-29702.96.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.244-t-28730.15-v-29201.60.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.385-t-29441.90-v-30065.05.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.82-t-25549.42-v-26431.67.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.304-t-29132.82-v-29620.59.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.186-t-28138.81-v-28492.84.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.64-t-24833.01-v-25188.97.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.184-t-28232.04-v-28294.69.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.13-t-19671.44-v-19503.42.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.23-t-21486.28-v-21828.04.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.169-t-28148.71-v-28216.31.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.309-t-29316.36-v-29275.65.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.57-t-24004.58-v-23078.96.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.209-t-28509.09-v-28981.01.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.18-t-20719.67-v-20847.45.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.323-t-29078.77-v-28680.15.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.387-t-29601.99-v-28330.35.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.319-t-29179.65-v-29514.84.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.146-t-27745.00-v-28241.44.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.133-t-27050.28-v-27111.53.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.302-t-29106.19-v-28870.18.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.367-t-29480.07-v-29985.32.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.384-t-29014.79-v-28694.70.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.182-t-28124.29-v-27996.39.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.58-t-23819.64-v-24219.64.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.346-t-29230.71-v-30048.70.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.190-t-28175.28-v-27344.92.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.267-t-28882.93-v-29596.88.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.83-t-25752.86-v-24734.42.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.417-t-29789.66-v-30022.61.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.332-t-29397.20-v-29968.62.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.310-t-28948.30-v-29670.74.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.336-t-29283.81-v-29173.93.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.158-t-27655.90-v-27264.20.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.136-t-27797.93-v-28372.92.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.128-t-27133.30-v-27997.12.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.288-t-28767.77-v-27698.39.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.154-t-27786.21-v-26836.92.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.22-t-21237.91-v-21252.65.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.28-t-21914.48-v-21737.93.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.162-t-27902.24-v-28863.48.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.79-t-25536.03-v-26145.39.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.303-t-29156.58-v-27988.16.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.294-t-28663.58-v-28153.68.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.225-t-28689.54-v-28127.30.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.104-t-26469.21-v-26926.44.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.373-t-29272.45-v-28880.80.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.30-t-22269.70-v-21224.67.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.351-t-29199.05-v-28827.87.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.77-t-25873.07-v-25003.55.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.04-t-12688.69-v-13494.88.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.362-t-29015.26-v-28246.17.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.285-t-29227.81-v-29700.68.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.352-t-29327.58-v-29814.43.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.195-t-28637.72-v-27683.52.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.176-t-28137.31-v-28078.95.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.403-t-29512.34-v-27521.84.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.407-t-29378.44-v-28046.62.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.313-t-29024.80-v-29373.49.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.94-t-26249.72-v-26474.51.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.219-t-28608.70-v-28287.29.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.228-t-28675.77-v-28779.56.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.24-t-21606.34-v-20759.24.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.20-t-20886.13-v-21024.86.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.315-t-28923.84-v-27094.83.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.307-t-29315.18-v-28584.57.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.204-t-28320.79-v-28532.28.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.203-t-28469.43-v-28861.48.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.202-t-28204.12-v-27812.91.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.218-t-28790.18-v-29055.52.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.270-t-29251.37-v-29116.02.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.29-t-22175.25-v-22464.72.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.96-t-26347.07-v-26752.30.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.308-t-29332.61-v-28554.62.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.401-t-29397.10-v-29520.34.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.273-t-29085.49-v-28864.64.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.170-t-28254.38-v-28040.61.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.331-t-29476.68-v-29438.81.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.189-t-28338.70-v-28245.25.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.135-t-27626.32-v-27803.04.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.47-t-23281.05-v-23707.41.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.375-t-29493.49-v-30126.39.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.164-t-27965.16-v-26691.56.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.39-t-23176.47-v-21870.67.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.330-t-29284.50-v-29801.93.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.40-t-23049.06-v-21678.70.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.197-t-28080.01-v-28288.26.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.394-t-29357.10-v-29213.83.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.233-t-28735.30-v-29262.31.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.245-t-28911.91-v-29149.71.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.63-t-24504.41-v-24821.36.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.234-t-28920.75-v-29030.41.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.252-t-29045.58-v-29112.29.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.151-t-27723.24-v-27075.50.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.287-t-29016.00-v-29226.92.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.328-t-29515.00-v-29813.52.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.227-t-28685.62-v-29249.75.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.223-t-28807.74-v-29152.35.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.37-t-22628.53-v-22204.51.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.247-t-28513.35-v-26908.36.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.49-t-23898.54-v-23229.59.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.380-t-29273.56-v-30054.15.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.138-t-27624.19-v-24098.68.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.198-t-28278.99-v-28418.98.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.143-t-27887.13-v-27177.58.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.340-t-29373.03-v-29666.59.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.265-t-29168.85-v-29119.60.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.312-t-29009.54-v-29059.34.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.253-t-28506.80-v-28778.16.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.276-t-28958.13-v-29069.83.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.341-t-29345.13-v-29472.66.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.314-t-29065.66-v-27680.51.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.255-t-28515.02-v-28940.86.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.185-t-27968.05-v-28528.31.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.293-t-29032.00-v-28909.25.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.163-t-28057.65-v-28291.03.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.413-t-29606.41-v-27962.60.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.382-t-29198.71-v-28236.53.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.60-t-24158.51-v-24438.75.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.260-t-28959.38-v-29368.69.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.152-t-27842.93-v-27755.88.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.25-t-21451.23-v-21399.27.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.301-t-28857.59-v-28830.59.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.416-t-29481.61-v-29445.31.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.278-t-28932.07-v-29659.34.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.284-t-28978.49-v-29137.81.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.120-t-27565.62-v-27297.21.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.137-t-27702.95-v-26607.21.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.168-t-28285.10-v-27765.29.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.50-t-23764.80-v-23008.93.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.210-t-28673.42-v-27722.80.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.419-t-29634.87-v-28558.08.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.412-t-29337.85-v-27521.95.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.108-t-26997.02-v-27553.87.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.112-t-27176.94-v-27341.68.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.296-t-29164.61-v-29831.27.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.282-t-28973.92-v-28977.39.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.388-t-29570.79-v-29180.02.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.274-t-29018.83-v-29267.06.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.391-t-29198.79-v-29743.81.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.139-t-27481.72-v-27623.34.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.262-t-28939.80-v-28407.08.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.52-t-23954.53-v-23469.73.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.216-t-28365.01-v-29355.92.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.263-t-29012.33-v-29370.58.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.121-t-27470.24-v-26785.99.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.392-t-29334.05-v-30015.75.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.415-t-29640.27-v-30033.37.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.266-t-29049.11-v-29502.45.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.269-t-29384.10-v-29666.17.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.286-t-28817.52-v-28756.79.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.87-t-25723.30-v-23970.26.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.89-t-25907.44-v-25923.49.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.261-t-29091.92-v-28822.51.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.207-t-28591.25-v-28201.23.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.368-t-29692.25-v-29462.17.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.98-t-26347.24-v-26604.43.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.05-t-14370.56-v-14980.16.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.90-t-25965.31-v-26821.83.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.59-t-24190.13-v-24847.28.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.338-t-28935.63-v-28132.93.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.194-t-28525.20-v-27905.66.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.71-t-25046.75-v-24779.51.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.229-t-28837.39-v-27527.85.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.418-t-29435.49-v-29762.13.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.291-t-28692.32-v-28329.70.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.393-t-29365.87-v-29582.10.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.187-t-28091.10-v-27276.28.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.237-t-28869.33-v-28905.53.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.03-t-10398.66-v-11673.40.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.56-t-23920.39-v-24170.53.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.390-t-29396.13-v-28685.19.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.156-t-27644.13-v-26972.77.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.325-t-29059.65-v-28294.15.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.339-t-29226.17-v-29074.26.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.119-t-27368.59-v-27689.48.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.396-t-29392.14-v-29923.51.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.395-t-29488.34-v-30065.91.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.424-t-29584.31-v-29709.84.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.80-t-25475.62-v-25930.74.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.150-t-27628.06-v-28171.39.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.114-t-27376.89-v-27723.56.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.32-t-22336.77-v-22734.38.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.180-t-28315.71-v-28209.24.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.145-t-27736.52-v-27094.32.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.354-t-29220.81-v-27965.20.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.349-t-29449.63-v-29574.49.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.132-t-27432.04-v-27462.65.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.130-t-27416.00-v-28036.20.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.235-t-28867.00-v-28516.51.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.333-t-29300.10-v-29875.17.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.41-t-22681.30-v-22406.49.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.142-t-27690.06-v-27523.10.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.409-t-29634.38-v-29639.48.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.271-t-29172.22-v-28943.20.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.298-t-28866.38-v-27631.95.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.376-t-29318.49-v-28935.84.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.113-t-27347.35-v-27423.09.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.102-t-26662.00-v-26359.86.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.157-t-27897.78-v-28301.19.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.250-t-28555.96-v-28189.97.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.347-t-29334.01-v-30054.31.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.200-t-28455.56-v-27343.95.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.159-t-27638.84-v-28384.60.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.256-t-28589.43-v-28647.64.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.88-t-25700.77-v-25581.83.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.181-t-27938.93-v-27729.72.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.316-t-29091.71-v-29563.39.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.281-t-28984.84-v-29160.60.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.326-t-29461.06-v-28322.31.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.344-t-29299.00-v-28479.58.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.272-t-29273.20-v-29365.13.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.259-t-29034.92-v-29254.04.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.14-t-19974.06-v-19596.32.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.95-t-26485.71-v-25272.77.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.55-t-23797.71-v-23527.06.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.283-t-29064.05-v-29034.54.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.239-t-28780.71-v-29012.64.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.389-t-29350.45-v-28954.28.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.406-t-29240.85-v-29291.91.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.414-t-29325.36-v-27217.33.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.363-t-29026.53-v-28373.56.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.232-t-28500.78-v-28016.29.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.246-t-28639.05-v-28283.29.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.09-t-17689.66-v-17185.62.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.165-t-27749.91-v-27638.30.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.334-t-29313.77-v-29491.88.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.379-t-29183.03-v-28422.20.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.222-t-28859.21-v-28786.27.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.248-t-28770.57-v-28418.78.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.221-t-28679.25-v-28309.73.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.177-t-28080.19-v-28544.19.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.365-t-29243.17-v-29921.89.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.131-t-27395.32-v-27190.28.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.33-t-22563.88-v-21822.86.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.86-t-25861.87-v-20918.32.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.26-t-21692.77-v-21159.35.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.358-t-29140.08-v-29422.46.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.155-t-27778.14-v-26795.22.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.38-t-22938.41-v-23253.68.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.175-t-28127.01-v-28367.62.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.173-t-27657.69-v-28096.59.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.231-t-28784.23-v-28136.73.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.67-t-24784.72-v-24622.70.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.149-t-27905.13-v-27410.87.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.48-t-23551.30-v-23749.39.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.383-t-29071.74-v-29552.16.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.161-t-27920.67-v-27463.21.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.275-t-28857.45-v-28304.93.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.178-t-27971.24-v-27349.51.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.238-t-28925.74-v-29060.72.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.31-t-22215.31-v-22315.19.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.148-t-27919.34-v-27881.56.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.34-t-22609.58-v-23012.10.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.258-t-28762.37-v-29281.84.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.92-t-25984.02-v-25776.49.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.353-t-29360.48-v-29263.89.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.69-t-25002.32-v-25217.48.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.425-t-29549.17-v-28868.18.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.54-t-23986.58-v-24285.41.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.220-t-28573.76-v-28422.92.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.11-t-18819.15-v-18661.55.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.386-t-29494.16-v-29336.56.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.350-t-29092.36-v-27917.71.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.127-t-27370.37-v-25854.60.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.42-t-22968.06-v-23184.29.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.124-t-27223.56-v-26493.10.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.422-t-29490.71-v-29921.35.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.297-t-29078.78-v-29208.50.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.324-t-29172.42-v-28527.04.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.45-t-23148.87-v-23571.74.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.212-t-28380.82-v-28039.57.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.73-t-25494.33-v-25696.82.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.21-t-21070.14-v-20614.47.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.215-t-28182.27-v-28171.11.hdf5',
#  './trained_models/model-edda7eb7-checkpoints/checkpoints/weights.410-t-29499.48-v-28916.89.hdf5']

# %%
def extract_val_metric(fname):
    try:
        val_str = fname.split("-v-")[-1].replace(".hdf5", "")
        return float(val_str)
    except Exception:
        return float("-inf")

best_ckpt = None
best_val = float("-inf")

for f in checkpoint_files:
    val = extract_val_metric(os.path.basename(f))
    if val > best_val:
        best_val = val
        best_ckpt = f

print(f"Loading model from {best_ckpt}")
model.load_weights(best_ckpt)
# Out:
# Loading model from ./trained_models/model-edda7eb7-checkpoints/checkpoints/weights.375-t-29493.49-v-30126.39.hdf5

# %%
plt.scatter(training_history['epoch'], training_history['loss'])
plt.scatter(training_history['epoch'], training_history['val_loss'])
plt.legend(['training', 'validation'])
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('NLL loss')
plt.tight_layout() 

plt.savefig(os.path.join(base_dir,'training_hist.png'))
plt.show()

# %%
dataset_base_dir = "/depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/contained"
tfrecords_base_dir = os.path.join(dataset_base_dir, "TFR_files", "2t")
tfrecords_dir_val   = os.path.join(tfrecords_base_dir, "TFR_val")

# %%
test_generator = OptimizedDataGenerator(
    load_from_tfrecords_dir= tfrecords_dir_val,
    shuffle=True,
    seed=42,
    quantize=True,
)
labels_scale = test_generator.labels_scale
print(labels_scale)
# Out:
# WARNING:root:Quantization is True in data generator. This may affect model performance.
# Loading metadata from /depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/contained/TFR_files/2t/TFR_val/metadata.json
# [99.17029747 24.79370923  6.53245764  1.89031215]

# %%
# predicts test data
p_test = model.predict(test_generator)
# Out:
# 2025-06-26 18:10:37.137584: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 21/21 [==============================] - 3s 70ms/step

# %%
complete_truth = None
for _, y in tqdm(test_generator):
        if complete_truth is None:
            complete_truth = y
        else:
            complete_truth = np.concatenate((complete_truth, y), axis=0)
# Out:
# 100%|██████████| 21/21 [00:01<00:00, 15.76it/s]

# %%
def softplus(x):
    x = np.asarray(x)
    return np.maximum(x, 0) + np.log1p(np.exp(-np.abs(x)))

# %%
# creates df with all predicted values and matrix elements - 4 predictions, all 10 unique matrix elements
df = pd.DataFrame(p_test,columns=['x','y','cotA','cotB','M11','M22','M33','M44'])

# stores all true values in same matrix as xtrue, ytrue, etc.
df['xtrue'] = complete_truth[:,0]
df['ytrue'] = complete_truth[:,1]
df['cotAtrue'] = complete_truth[:,2]
df['cotBtrue'] = complete_truth[:,3]

df['sigmax'] = softplus(p_test[:,4])
df['sigmay'] = softplus(p_test[:,5])
df['sigmacotA'] = softplus(p_test[:,6])
df['sigmacotB'] = softplus(p_test[:,7])

# calculates residuals for x, y, cotA, cotB
residuals = df['xtrue'] - df['x']
residualsy = df['ytrue'] - df['y']
residualsA = df['cotAtrue'] - df['cotA']
residualsB = df['cotBtrue'] - df['cotB']

# stores results as csv
df.to_csv("test_4x4.csv",header=True,index=False)

# %% [markdown]
# # residuals (mean, stdv)

# %%
# x
(np.mean(residuals)*labels_scale[0],np.std(residuals)*labels_scale[0])
# Out:
# (0.8347421683723856, 8.732657005967667)

# %%
# y
(np.mean(residualsy)*labels_scale[1],np.std(residualsy)*labels_scale[1])
# Out:
# (-0.13158895801420015, 2.492383536080998)

# %%
# cotA
(np.mean(residualsA)*labels_scale[2],np.std(residualsA)*labels_scale[2])
# Out:
# (-0.002990618193184867, 0.2631937764627976)

# %%
# cotB
(np.mean(residualsB)*labels_scale[3],np.std(residualsB)*labels_scale[3])
# Out:
# (-0.016877396975138317, 0.09563456952788556)

# %% [markdown]
# # x residuals

# %%
plt.hist(p_test[:,0],bins=np.linspace(-2,2,50))
plt.yscale('log')
plt.xlabel(r'$x$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residuals,bins=np.linspace(-1,1,50))
#plt.yscale('Log')
plt.xlabel(r'$x-\mu_x$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['xtrue'], y=(df['xtrue']-df['x']), x_bins=np.linspace(-1,1,50), fit_reg=None, marker='.')
plt.xlabel(r'True $x$ [um]')
plt.ylabel(r'$x-\mu_x$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # y residuals

# %%
plt.hist(p_test[:,2],bins=np.linspace(-1.5,1.5,50))
plt.yscale('log')
plt.xlabel(r'$y$ [um]')

save_fig_path = os.path.join(plot_dir, 'y_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residualsy,bins=np.linspace(-1,1,50))
#plt.yscale('Log')
plt.xlabel(r'$y-\mu_y$ [um]')

save_fig_path = os.path.join(plot_dir, 'y_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['ytrue'], y=(df['ytrue']-df['y']), x_bins=np.linspace(-1,1,50), fit_reg=None, marker='.')
plt.xlabel(r'True $y$ [um]')
plt.ylabel(r'$y-\mu_y$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # cotA residuals

# %%
plt.hist(df["cotA"],bins=np.linspace(-1.25,1.25,50))
plt.yscale('log')
plt.xlabel(r'$cotA$')

save_fig_path = os.path.join(plot_dir, 'cotA_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residualsA,bins=np.linspace(-0.5,0.5,50))
#plt.yscale('Log')
plt.xlabel(r'$cotA-\mu_{cotA}$')

save_fig_path = os.path.join(plot_dir, 'cotA_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['cotAtrue']*labels_scale[2], y=(df['cotAtrue']-df['cotA'])*labels_scale[2], x_bins=np.linspace(-labels_scale[2],labels_scale[2],50), fit_reg=None, marker='.')
plt.xlabel(r'True $cotA$ [um]')
plt.ylabel(r'$cotA-\mu_{cotA}$ [um]')

save_fig_path = os.path.join(plot_dir, 'cotA_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # cotB residuals

# %%
plt.hist(df["cotB"]*labels_scale[3],bins=np.linspace(-labels_scale[3],labels_scale[3],50))
#plt.yscale('Log')
plt.xlabel(r'$cotB$')

save_fig_path = os.path.join(plot_dir, 'cotB_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residualsB*labels_scale[3],bins=np.linspace(-labels_scale[3],labels_scale[3],50))
#plt.yscale('Log')
plt.xlabel(r'$cotB-\mu_{cotB}$')

save_fig_path = os.path.join(plot_dir, 'cotB_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['cotBtrue']*labels_scale[3], y=(df['cotBtrue']-df['cotB'])*labels_scale[3], x_bins=np.linspace(-labels_scale[3],labels_scale[3],100), fit_reg=None, marker='.')
plt.xlabel(r'True $cotB$')
plt.ylabel(r'$cotB-\mu_{cotB} $')

save_fig_path = os.path.join(plot_dir, 'cotB_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # pull

# %%
df['pullx'] = (df['xtrue']-df['x'])/df['sigmax']
df['pully'] = (df['ytrue']-df['y'])/df['sigmay']
df['pullcotA'] = (df['cotAtrue']-df['cotA'])/df['sigmacotA']
df['pullcotB'] = (df['cotBtrue']-df['cotB'])/df['sigmacotB']

# %%
plt.hist(df['sigmax'] * 75,bins=np.linspace(0,35,50))
plt.xlabel('$\sigma_{x}$')
plt.yscale('log')

# %%
plt.hist(df['sigmay']* 18.75,bins=np.linspace(0,6,50))
plt.xlabel('$\sigma_{y}$')
plt.yscale('log')

# %%
plt.hist(df['sigmacotA'] * 8,bins=np.linspace(0,1.0,50))
plt.xlabel('$\sigma_{cotA}$')
plt.yscale('log')

# %%
plt.hist(df['sigmacotB'] * 0.5 ,bins=np.linspace(0,0.25,50))
plt.xlabel('$\sigma_{cotB}$')
plt.yscale('log')

# %%
from scipy.optimize import curve_fit

def gauss(x, A, mu, sigma):
    return A * np.exp(-(x - mu) ** 2 / (2 * sigma ** 2))

def pull_plot(ax, var, name):
    
    h = ax.hist(df[var],bins=np.linspace(-5,5,50),histtype='step')
    ax.set_xlabel(name)
    ax.set_yscale('log')

    ydata = h[0]
    xdata = h[1][:-1]+3/50.

    pars, cov = curve_fit(gauss,xdata,ydata)

    xbins = np.linspace(-5,5,100)
    ax.plot(xbins,gauss(xbins,pars[0],pars[1],pars[2]),color='black')
    ax.set_ylim(0.5,100000)

    print('Mean',pars[1])
    print('Sigma',pars[2])
    
    ax.text(-5,2000,"$\mu$="+str(round(pars[1],2)))
    ax.text(-5,1000,"$\sigma$="+str(round(abs(pars[2]),2)))

# %%
fig, axes = plt.subplots(2,2,sharex=True,sharey=True,figsize=(8,6))
pull_plot(axes[0][0],'pullx',r'$x$ pull')
pull_plot(axes[0][1],'pully',r'$y$ pull')
pull_plot(axes[1][0],'pullcotA',r'$\cot\alpha$ pull')
pull_plot(axes[1][1],'pullcotB',r'$\cot\beta$ pull')

save_fig_path = os.path.join(plot_dir, 'Pull.png')
plt.savefig(save_fig_path)

plt.show()
# Out:
# Mean 0.04753159926018127
# Sigma 0.9507736508306743
# Mean -0.09145758262709915
# Sigma -0.8924356277091727
# Mean -0.055749576160053764
# Sigma -0.8562942195862598
# Mean -0.24017046867115438
# Sigma 0.8458865013000008

# %%
def residual_plot(ax, thisdf, var1, var2, name, scaling=1.0):
    
    nbins = 15
    
    var1_scaled = thisdf[var1] * scaling
    var2_scaled = thisdf[var2] * scaling
    residual_scaled = var1_scaled - var2_scaled
    
    xmin = np.min(var1_scaled)
    xmax = np.max(var1_scaled)
    
    step = 1.0*(xmax-xmin)/nbins
    
    x = sns.regplot(x=var1_scaled, y=residual_scaled, x_bins=np.linspace(xmin,xmax,nbins), fit_reg=None, marker='.', ax=ax)
    ax.set_xlabel('True ' + name)
    ax.set_ylabel('True - predicted ' + name)
    
    thisdf['residual'+var2] = residual_scaled
    print(var1)
    
    means = []
    upbar = []
    downbar = []
    for i in range(0,nbins):
        means += [np.mean(thisdf['residual'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)])]
        upbar += [means[i] + np.mean(thisdf['sigma'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)] * scaling)]
        downbar += [means[i] - np.mean(thisdf['sigma'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)] * scaling)]
    ax.fill_between(x=np.linspace(xmin,xmax,nbins),y1=upbar,y2=downbar, alpha=0.2)

def inverse_cot(cota):
    a = np.arctan(1.0/cota)
    a[np.where(a<0)] = a[np.where(a<0)] + pi
    return a    

def residual_plot_deg(ax, thisdf, var1, var2, name, scaling=1.0):
    # positions
    if 'cot' not in var1:
        residual_plot(ax, thisdf, var1, var2, name, scaling=scaling)
        return

    thisdf['angle'] = inverse_cot(thisdf[var2].values * scaling)*180/pi
    
    thisdf['angleup'] = abs(inverse_cot((thisdf[var2].values + thisdf['sigma'+var2].values) * scaling)*180/pi - thisdf['angle'])
    thisdf['angledown'] = abs(inverse_cot((thisdf[var2].values - thisdf['sigma'+var2].values) * scaling)*180/pi - thisdf['angle'])
    thisdf['angletrue'] = inverse_cot(thisdf[var1].values * scaling)*180/pi
        
    var1 = 'angletrue'
    var2 = 'angle'
    
    nbins = 15
    xmin = np.min(thisdf[var1])
    xmax = np.max(thisdf[var1])
    
    step = 1.0*(xmax-xmin)/nbins
        
    x = sns.regplot(x=thisdf[var1], y=(thisdf[var1]-thisdf[var2]), x_bins=np.linspace(xmin,xmax,nbins), fit_reg=None, marker='.', ax=ax)
    ax.set_xlabel('True ' + name)
    ax.set_ylabel('True - predicted ' + name)
    
    thisdf['residual'+var2] = (thisdf[var1]-thisdf[var2])
    print(var1)
    
    means = []    
    upbar = []
    downbar = []
    for i in range(0,nbins):
        means += [np.mean(thisdf['residual'+var2][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
        upbar += [means[i] + np.mean(thisdf['angleup'][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
        downbar += [means[i] - np.mean(thisdf['angledown'][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
    #ax.scatter(x=np.linspace(xmin,xmax,nbins),y=means)
    ax.fill_between(x=np.linspace(xmin,xmax,nbins),y1=upbar,y2=downbar, alpha=0.2)

# %%
fig, axes = plt.subplots(2,2,figsize=(8,6))
fig.tight_layout(pad=4.0)
residual_plot(axes[0][0],df,'xtrue','x',r'$x$ [um]', scaling=labels_scale[0])
axes[0][0].plot([-25,-25],[-10,10],color='gray',linestyle=':')
axes[0][0].plot([25,25],[-10,10],color='gray',linestyle=':')
residual_plot(axes[0][1],df,'ytrue','y',r'$y$ [um]', scaling=labels_scale[1])
axes[0][1].plot([-6.25,-6.25],[-2,2],color='gray',linestyle=':')
axes[0][1].plot([6.25,6.25],[-2,2],color='gray',linestyle=':')
residual_plot_deg(axes[1][0],df,'cotAtrue','cotA',r'$\alpha$ [deg]', scaling=labels_scale[2])
axes[1][0].plot([90,90],[-10,10],color='gray',linestyle=':')
residual_plot_deg(axes[1][1],df,'cotBtrue','cotB',r'$\beta$ [deg]', scaling=labels_scale[3])
axes[1][1].plot([90,90],[-10,10],color='gray',linestyle=':')

save_fig_path = os.path.join(plot_dir, 'summary.png')
plt.savefig(save_fig_path)
# Out:
# xtrue
# ytrue
# /tmp/ipykernel_2588577/1472323418.py:31: RuntimeWarning: divide by zero encountered in divide
#   a = np.arctan(1.0/cota)
# angletrue
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[50], line 9
#       7 axes[0][1].plot([-6.25,-6.25],[-2,2],color='gray',linestyle=':')
#       8 axes[0][1].plot([6.25,6.25],[-2,2],color='gray',linestyle=':')
# ----> 9 residual_plot_deg(axes[1][0],df,'cotAtrue','cotA',r'$\alpha$ [deg]', scaling=labels_scale[2])
#      10 axes[1][0].plot([90,90],[-10,10],color='gray',linestyle=':')
#      11 residual_plot_deg(axes[1][1],df,'cotBtrue','cotB',r'$\beta$ [deg]', scaling=labels_scale[3])
#
# Cell In[49], line 66, in residual_plot_deg(ax, thisdf, var1, var2, name, scaling)
#      64 downbar = []
#      65 for i in range(0,nbins):
# ---> 66     means += [np.mean(thisdf['residual'+var2][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
#      67     upbar += [means[i] + np.mean(thisdf['angleup'][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
#      68     downbar += [means[i] - np.mean(thisdf['angledown'][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
#
# UnboundLocalError: local variable 'means' referenced before assignment
