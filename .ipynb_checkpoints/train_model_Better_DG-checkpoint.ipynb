# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
import keras
from keras.models import Sequential, Model
from keras.layers import *
from keras.utils import Sequence
from keras.layers import Conv2D, MaxPooling2D
from qkeras import *

from keras.utils import Sequence
from keras.callbacks import CSVLogger
from keras.callbacks import EarlyStopping

import os
import random
from datetime import datetime
import time

import matplotlib.pyplot as plt

pi = 3.14159265359

maxval=1e9
minval=1e-9
# Out:
# 2025-06-25 01:35:54.363173: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-25 01:35:54.363244: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-25 01:35:54.364123: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-25 01:35:54.370620: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-25 01:35:55.927329: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# os.chdir('SmartPix/data_generator')
os.chdir('/home/das214/SmartPix/mlp_enc_dev')
# !pwd
# Out:
# /home/das214/SmartPix/mlp_enc_dev

# %%
from DG.OptimizedDataGenerator_v2 import OptimizedDataGenerator
from losses.diag_loss_nll import custom_diag_loss
from models.mlp_encoder_model import CreateModel

# %%
dataset_base_dir = "/depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/contained"
tfrecords_base_dir = os.path.join(dataset_base_dir, "TFR_files", "2t")

dataset_train_dir = os.path.join(dataset_base_dir, "train")
dataset_test_dir = os.path.join(dataset_base_dir, "test")
tfrecords_dir_train = os.path.join(tfrecords_base_dir, "TFR_train")
tfrecords_dir_val   = os.path.join(tfrecords_base_dir, "TFR_val")

batch_size = 5000
val_batch_size = 5000
train_file_size = len(os.listdir(dataset_train_dir))
val_file_size = len(os.listdir(dataset_test_dir))

# %%
# start_time = time.time()
# validation_generator = OptimizedDataGenerator(
#     dataset_base_dir = dataset_test_dir,
#     file_type = "parquet",
#     data_format = "3D",
#     batch_size = val_batch_size,
#     # optimize_batch_size = True,
#     file_count = val_file_size,
#     to_standardize= True,
#     labels_list = ['x-midplane','y-midplane','cotAlpha','cotBeta'],
#     input_shape = (2,16,16), # (20,13,21),
#     transpose = (0,2,3,1),
#     shuffle = False, 
#     files_from_end=True,

#     tfrecords_dir = tfrecords_dir_val,
#     use_time_stamps = [0,19],
#     max_workers = 2
# )

# print("--- Validation generator %s seconds ---" % (time.time() - start_time))

# # training generator
# start_time = time.time()
# training_generator = OptimizedDataGenerator(
#     dataset_base_dir = dataset_train_dir,
#     file_type = "parquet",
#     data_format = "3D",
#     batch_size = batch_size,
#     # optimize_batch_size = True,
#     file_count = train_file_size,
#     to_standardize= True,
#     labels_list = ['x-midplane','y-midplane','cotAlpha','cotBeta'],
#     input_shape = (2,16,16), # (20,13,21),
#     transpose = (0,2,3,1),
#     shuffle = False, # True 

#     tfrecords_dir = tfrecords_dir_train,
#     use_time_stamps = [0,19],
#     max_workers = 2
# )
# print("--- Training generator %s seconds ---" % (time.time() - start_time))

# %%
# Loading pre-generated TFRecords
validation_generator = OptimizedDataGenerator(
    load_from_tfrecords_dir= tfrecords_dir_val,
    shuffle=True,
    seed=42,
    quantize=True,
)

training_generator = OptimizedDataGenerator(
    load_from_tfrecords_dir = tfrecords_dir_train,
    shuffle=True,
    seed=42,
    quantize=True,
)
# Out:
# WARNING:root:Quantization is True in data generator. This may affect model performance.
# Loading metadata from /depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/contained/TFR_files/2t/TFR_val/metadata.json
# Loading metadata from /depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/contained/TFR_files/2t/TFR_train/metadata.json
# WARNING:root:Quantization is True in data generator. This may affect model performance.

# %%
diag_model=CreateModel(shape = (16,16,2), output = 8)
diag_model.compile(
    optimizer=tf.keras.optimizers.Nadam(learning_rate=1e-3, clipnorm=1.0),
    loss=custom_diag_loss,
)

diag_model.summary()
# Out:
# 2025-06-25 01:36:02.834081: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38397 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB MIG 7g.40gb, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2025-06-25 01:36:03.133724: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Model: "smrtpxl_regression"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_pxls/ (InputLayer)    [(None, 16, 16, 2)]          0         []
#
#  average_pooling2d (Average  (None, 16, 1, 2)             0         ['input_pxls/[0][0]']
#  Pooling2D)
#
#  average_pooling2d_1 (Avera  (None, 1, 16, 2)             0         ['input_pxls/[0][0]']
#  gePooling2D)
#
#  flatten_x (Flatten)         (None, 32)                   0         ['average_pooling2d[0][0]']
#
#  flatten_y (Flatten)         (None, 32)                   0         ['average_pooling2d_1[0][0]']
#
#  q_dense (QDense)            (None, 16)                   528       ['flatten_x[0][0]']
#
#  q_dense_1 (QDense)          (None, 16)                   528       ['flatten_y[0][0]']
#
#  q_activation (QActivation)  (None, 16)                   0         ['q_dense[0][0]']
#
#  q_activation_1 (QActivatio  (None, 16)                   0         ['q_dense_1[0][0]']
#  n)
#
#  concatenate (Concatenate)   (None, 32)                   0         ['q_activation[0][0]',
#                                                                      'q_activation_1[0][0]']
#
#  q_dense_2 (QDense)          (None, 16)                   528       ['concatenate[0][0]']
#
#  q_activation_2 (QActivatio  (None, 16)                   0         ['q_dense_2[0][0]']
#  n)
#
#  flatten (Flatten)           (None, 16)                   0         ['q_activation_2[0][0]']
#
#  dense_1 (QDense)            (None, 16)                   272       ['flatten[0][0]']
#
#  activation_tanh_2 (QActiva  (None, 16)                   0         ['dense_1[0][0]']
#  tion)
#
#  dense_2 (QDense)            (None, 16)                   272       ['activation_tanh_2[0][0]']
#
#  activation_tanh_3 (QActiva  (None, 16)                   0         ['dense_2[0][0]']
#  tion)
#
#  dense_3 (QDense)            (None, 8)                    136       ['activation_tanh_3[0][0]']
#
# ==================================================================================================
# Total params: 2264 (8.84 KB)
# Trainable params: 2264 (8.84 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from datetime import datetime

fingerprint = '%08x' % random.randrange(16**8)
timestamp = datetime.now().strftime('%Y%m%d-%H%M%S')
os.makedirs("trained_models", exist_ok=True)
base_dir = f'./trained_models/model-{fingerprint}-checkpoints'
os.makedirs(base_dir, exist_ok=True)  
checkpoint_filepath = base_dir + '/weights.{epoch:02d}-t{loss:.2f}-v{val_loss:.2f}.hdf5'

# %%
print(fingerprint)
# Out:
# 15252d39

# %%
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, Callback

early_stopping_patience = 50

class CustomModelCheckpoint(ModelCheckpoint):
    def on_epoch_end(self, epoch, logs=None):
        super().on_epoch_end(epoch, logs)
        checkpoints = [f for f in os.listdir(base_dir) if f.startswith('weights')]
        if len(checkpoints) > 1:
            checkpoints.sort()
            for checkpoint in checkpoints[:-1]:
                os.remove(os.path.join(base_dir, checkpoint))

es = EarlyStopping(patience=early_stopping_patience, restore_best_weights=True)

mcp = CustomModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    save_best_only=True,
    save_freq='epoch',
    verbose=1
)

csv_logger = CSVLogger(f'{base_dir}/training_log.csv', append=True)

# %%
history = diag_model.fit(
        x=training_generator,
        validation_data=validation_generator,
        callbacks=[es, mcp, csv_logger],
        epochs=1000,
        shuffle=False,
        verbose=1
    )
# Out:
# Epoch 1/1000
# 2025-06-25 01:36:08.800515: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-06-25 01:36:10.279849: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f5da134dfb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-06-25 01:36:10.279909: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-PCIE-40GB MIG 7g.40gb, Compute Capability 8.0
# 2025-06-25 01:36:10.291403: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750808170.408194 1398859 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 84/84 [==============================] - ETA: 0s - loss: 10369.0264
# Epoch 1: val_loss improved from inf to 920.39050, saving model to ./trained_models/model-15252d39-checkpoints/weights.01-t10369.03-v920.39.hdf5
# 84/84 [==============================] - 13s 94ms/step - loss: 10369.0264 - val_loss: 920.3905
# Epoch 2/1000
# 84/84 [==============================] - ETA: 0s - loss: -4994.4375
# Epoch 2: val_loss improved from 920.39050 to -8823.31348, saving model to ./trained_models/model-15252d39-checkpoints/weights.02-t-4994.44-v-8823.31.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -4994.4375 - val_loss: -8823.3135
# Epoch 3/1000
# 84/84 [==============================] - ETA: 0s - loss: -10431.8086
# Epoch 3: val_loss improved from -8823.31348 to -11619.96973, saving model to ./trained_models/model-15252d39-checkpoints/weights.03-t-10431.81-v-11619.97.hdf5
# 84/84 [==============================] - 7s 87ms/step - loss: -10431.8086 - val_loss: -11619.9697
# Epoch 4/1000
# 84/84 [==============================] - ETA: 0s - loss: -12380.6836
# Epoch 4: val_loss improved from -11619.96973 to -12958.51758, saving model to ./trained_models/model-15252d39-checkpoints/weights.04-t-12380.68-v-12958.52.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -12380.6836 - val_loss: -12958.5176
# Epoch 5/1000
# 84/84 [==============================] - ETA: 0s - loss: -13811.4414
# Epoch 5: val_loss improved from -12958.51758 to -14288.83105, saving model to ./trained_models/model-15252d39-checkpoints/weights.05-t-13811.44-v-14288.83.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -13811.4414 - val_loss: -14288.8311
# Epoch 6/1000
# 84/84 [==============================] - ETA: 0s - loss: -15035.6797
# Epoch 6: val_loss improved from -14288.83105 to -15522.23340, saving model to ./trained_models/model-15252d39-checkpoints/weights.06-t-15035.68-v-15522.23.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -15035.6797 - val_loss: -15522.2334
# Epoch 7/1000
# 84/84 [==============================] - ETA: 0s - loss: -15970.3340
# Epoch 7: val_loss improved from -15522.23340 to -16104.37793, saving model to ./trained_models/model-15252d39-checkpoints/weights.07-t-15970.33-v-16104.38.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -15970.3340 - val_loss: -16104.3779
# Epoch 8/1000
# 84/84 [==============================] - ETA: 0s - loss: -16729.2012
# Epoch 8: val_loss improved from -16104.37793 to -17088.48047, saving model to ./trained_models/model-15252d39-checkpoints/weights.08-t-16729.20-v-17088.48.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -16729.2012 - val_loss: -17088.4805
# Epoch 9/1000
# 84/84 [==============================] - ETA: 0s - loss: -17402.4160
# Epoch 9: val_loss did not improve from -17088.48047
# 84/84 [==============================] - 7s 88ms/step - loss: -17402.4160 - val_loss: -17023.4570
# Epoch 10/1000
# 84/84 [==============================] - ETA: 0s - loss: -17974.6445
# Epoch 10: val_loss improved from -17088.48047 to -17802.45898, saving model to ./trained_models/model-15252d39-checkpoints/weights.10-t-17974.64-v-17802.46.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -17974.6445 - val_loss: -17802.4590
# Epoch 11/1000
# 84/84 [==============================] - ETA: 0s - loss: -18417.6230
# Epoch 11: val_loss improved from -17802.45898 to -18564.74805, saving model to ./trained_models/model-15252d39-checkpoints/weights.11-t-18417.62-v-18564.75.hdf5
# 84/84 [==============================] - 7s 87ms/step - loss: -18417.6230 - val_loss: -18564.7480
# Epoch 12/1000
# 84/84 [==============================] - ETA: 0s - loss: -18845.4805
# Epoch 12: val_loss improved from -18564.74805 to -19091.91992, saving model to ./trained_models/model-15252d39-checkpoints/weights.12-t-18845.48-v-19091.92.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -18845.4805 - val_loss: -19091.9199
# Epoch 13/1000
# 84/84 [==============================] - ETA: 0s - loss: -19297.2402
# Epoch 13: val_loss improved from -19091.91992 to -19345.20898, saving model to ./trained_models/model-15252d39-checkpoints/weights.13-t-19297.24-v-19345.21.hdf5
# 84/84 [==============================] - 7s 87ms/step - loss: -19297.2402 - val_loss: -19345.2090
# Epoch 14/1000
# 84/84 [==============================] - ETA: 0s - loss: -19565.9238
# Epoch 14: val_loss improved from -19345.20898 to -19965.12695, saving model to ./trained_models/model-15252d39-checkpoints/weights.14-t-19565.92-v-19965.13.hdf5
# 84/84 [==============================] - 7s 89ms/step - loss: -19565.9238 - val_loss: -19965.1270
# Epoch 15/1000
# 84/84 [==============================] - ETA: 0s - loss: -19986.8359
# Epoch 15: val_loss did not improve from -19965.12695
# 84/84 [==============================] - 7s 87ms/step - loss: -19986.8359 - val_loss: -19729.6426
# Epoch 16/1000
# 84/84 [==============================] - ETA: 0s - loss: -19995.2324
# Epoch 16: val_loss did not improve from -19965.12695
# 84/84 [==============================] - 7s 88ms/step - loss: -19995.2324 - val_loss: -19907.3203
# Epoch 17/1000
# 84/84 [==============================] - ETA: 0s - loss: -20053.7715
# Epoch 17: val_loss improved from -19965.12695 to -20046.07422, saving model to ./trained_models/model-15252d39-checkpoints/weights.17-t-20053.77-v-20046.07.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -20053.7715 - val_loss: -20046.0742
# Epoch 18/1000
# 84/84 [==============================] - ETA: 0s - loss: -20078.3770
# Epoch 18: val_loss improved from -20046.07422 to -20577.03320, saving model to ./trained_models/model-15252d39-checkpoints/weights.18-t-20078.38-v-20577.03.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -20078.3770 - val_loss: -20577.0332
# Epoch 19/1000
# 84/84 [==============================] - ETA: 0s - loss: -20465.8340
# Epoch 19: val_loss improved from -20577.03320 to -20758.17969, saving model to ./trained_models/model-15252d39-checkpoints/weights.19-t-20465.83-v-20758.18.hdf5
# 84/84 [==============================] - 7s 89ms/step - loss: -20465.8340 - val_loss: -20758.1797
# Epoch 20/1000
# 84/84 [==============================] - ETA: 0s - loss: -20775.1113
# Epoch 20: val_loss did not improve from -20758.17969
# 84/84 [==============================] - 7s 88ms/step - loss: -20775.1113 - val_loss: -18440.9844
# Epoch 21/1000
# 84/84 [==============================] - ETA: 0s - loss: -20975.0410
# Epoch 21: val_loss improved from -20758.17969 to -21047.27734, saving model to ./trained_models/model-15252d39-checkpoints/weights.21-t-20975.04-v-21047.28.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -20975.0410 - val_loss: -21047.2773
# Epoch 22/1000
# 84/84 [==============================] - ETA: 0s - loss: -20820.0195
# Epoch 22: val_loss improved from -21047.27734 to -21753.04688, saving model to ./trained_models/model-15252d39-checkpoints/weights.22-t-20820.02-v-21753.05.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -20820.0195 - val_loss: -21753.0469
# Epoch 23/1000
# 84/84 [==============================] - ETA: 0s - loss: -21413.8066
# Epoch 23: val_loss did not improve from -21753.04688
# 84/84 [==============================] - 7s 86ms/step - loss: -21413.8066 - val_loss: -20721.2520
# Epoch 24/1000
# 84/84 [==============================] - ETA: 0s - loss: -21525.2500
# Epoch 24: val_loss improved from -21753.04688 to -21907.89844, saving model to ./trained_models/model-15252d39-checkpoints/weights.24-t-21525.25-v-21907.90.hdf5
# 84/84 [==============================] - 7s 85ms/step - loss: -21525.2500 - val_loss: -21907.8984
# Epoch 25/1000
# 84/84 [==============================] - ETA: 0s - loss: -21457.0488
# Epoch 25: val_loss did not improve from -21907.89844
# 84/84 [==============================] - 7s 86ms/step - loss: -21457.0488 - val_loss: -20819.2383
# Epoch 26/1000
# 84/84 [==============================] - ETA: 0s - loss: -21286.8359
# Epoch 26: val_loss did not improve from -21907.89844
# 84/84 [==============================] - 7s 86ms/step - loss: -21286.8359 - val_loss: -20932.7285
# Epoch 27/1000
# 84/84 [==============================] - ETA: 0s - loss: -21695.4160
# Epoch 27: val_loss did not improve from -21907.89844
# 84/84 [==============================] - 7s 87ms/step - loss: -21695.4160 - val_loss: -20490.8633
# Epoch 28/1000
# 84/84 [==============================] - ETA: 0s - loss: -21948.4023
# Epoch 28: val_loss improved from -21907.89844 to -22105.03906, saving model to ./trained_models/model-15252d39-checkpoints/weights.28-t-21948.40-v-22105.04.hdf5
# 84/84 [==============================] - 7s 87ms/step - loss: -21948.4023 - val_loss: -22105.0391
# Epoch 29/1000
# 84/84 [==============================] - ETA: 0s - loss: -22271.7324
# Epoch 29: val_loss did not improve from -22105.03906
# 84/84 [==============================] - 7s 86ms/step - loss: -22271.7324 - val_loss: -22073.1152
# Epoch 30/1000
# 84/84 [==============================] - ETA: 0s - loss: -22440.8574
# Epoch 30: val_loss improved from -22105.03906 to -22638.53906, saving model to ./trained_models/model-15252d39-checkpoints/weights.30-t-22440.86-v-22638.54.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -22440.8574 - val_loss: -22638.5391
# Epoch 31/1000
# 84/84 [==============================] - ETA: 0s - loss: -22549.1641
# Epoch 31: val_loss did not improve from -22638.53906
# 84/84 [==============================] - 7s 87ms/step - loss: -22549.1641 - val_loss: -20754.9863
# Epoch 32/1000
# 84/84 [==============================] - ETA: 0s - loss: -22470.6094
# Epoch 32: val_loss did not improve from -22638.53906
# 84/84 [==============================] - 7s 85ms/step - loss: -22470.6094 - val_loss: -22099.8711
# Epoch 33/1000
# 84/84 [==============================] - ETA: 0s - loss: -22609.3242
# Epoch 33: val_loss improved from -22638.53906 to -22808.10156, saving model to ./trained_models/model-15252d39-checkpoints/weights.33-t-22609.32-v-22808.10.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -22609.3242 - val_loss: -22808.1016
# Epoch 34/1000
# 84/84 [==============================] - ETA: 0s - loss: -22861.4336
# Epoch 34: val_loss improved from -22808.10156 to -22992.63281, saving model to ./trained_models/model-15252d39-checkpoints/weights.34-t-22861.43-v-22992.63.hdf5
# 84/84 [==============================] - 7s 85ms/step - loss: -22861.4336 - val_loss: -22992.6328
# Epoch 35/1000
# 84/84 [==============================] - ETA: 0s - loss: -23029.4570
# Epoch 35: val_loss did not improve from -22992.63281
# 84/84 [==============================] - 7s 86ms/step - loss: -23029.4570 - val_loss: -22278.9609
# Epoch 36/1000
# 84/84 [==============================] - ETA: 0s - loss: -22939.8379
# Epoch 36: val_loss improved from -22992.63281 to -23266.40234, saving model to ./trained_models/model-15252d39-checkpoints/weights.36-t-22939.84-v-23266.40.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -22939.8379 - val_loss: -23266.4023
# Epoch 37/1000
# 84/84 [==============================] - ETA: 0s - loss: -23019.8633
# Epoch 37: val_loss did not improve from -23266.40234
# 84/84 [==============================] - 7s 86ms/step - loss: -23019.8633 - val_loss: -22374.4336
# Epoch 38/1000
# 84/84 [==============================] - ETA: 0s - loss: -23134.5840
# Epoch 38: val_loss improved from -23266.40234 to -23663.51758, saving model to ./trained_models/model-15252d39-checkpoints/weights.38-t-23134.58-v-23663.52.hdf5
# 84/84 [==============================] - 7s 87ms/step - loss: -23134.5840 - val_loss: -23663.5176
# Epoch 39/1000
# 84/84 [==============================] - ETA: 0s - loss: -23318.0859
# Epoch 39: val_loss did not improve from -23663.51758
# 84/84 [==============================] - 7s 87ms/step - loss: -23318.0859 - val_loss: -23491.6172
# Epoch 40/1000
# 84/84 [==============================] - ETA: 0s - loss: -23426.3301
# Epoch 40: val_loss improved from -23663.51758 to -23840.45312, saving model to ./trained_models/model-15252d39-checkpoints/weights.40-t-23426.33-v-23840.45.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -23426.3301 - val_loss: -23840.4531
# Epoch 41/1000
# 84/84 [==============================] - ETA: 0s - loss: -23603.1309
# Epoch 41: val_loss improved from -23840.45312 to -23959.97656, saving model to ./trained_models/model-15252d39-checkpoints/weights.41-t-23603.13-v-23959.98.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -23603.1309 - val_loss: -23959.9766
# Epoch 42/1000
# 84/84 [==============================] - ETA: 0s - loss: -23827.0000
# Epoch 42: val_loss did not improve from -23959.97656
# 84/84 [==============================] - 7s 86ms/step - loss: -23827.0000 - val_loss: -23776.6250
# Epoch 43/1000
# 84/84 [==============================] - ETA: 0s - loss: -23822.1699
# Epoch 43: val_loss did not improve from -23959.97656
# 84/84 [==============================] - 7s 86ms/step - loss: -23822.1699 - val_loss: -23458.1934
# Epoch 44/1000
# 84/84 [==============================] - ETA: 0s - loss: -23752.6406
# Epoch 44: val_loss improved from -23959.97656 to -23966.82617, saving model to ./trained_models/model-15252d39-checkpoints/weights.44-t-23752.64-v-23966.83.hdf5
# 84/84 [==============================] - 7s 85ms/step - loss: -23752.6406 - val_loss: -23966.8262
# Epoch 45/1000
# 84/84 [==============================] - ETA: 0s - loss: -23908.7266
# Epoch 45: val_loss did not improve from -23966.82617
# 84/84 [==============================] - 7s 86ms/step - loss: -23908.7266 - val_loss: -23744.6758
# Epoch 46/1000
# 84/84 [==============================] - ETA: 0s - loss: -24095.4102
# Epoch 46: val_loss did not improve from -23966.82617
# 84/84 [==============================] - 7s 89ms/step - loss: -24095.4102 - val_loss: -23683.5098
# Epoch 47/1000
# 84/84 [==============================] - ETA: 0s - loss: -24123.5430
# Epoch 47: val_loss did not improve from -23966.82617
# 84/84 [==============================] - 7s 87ms/step - loss: -24123.5430 - val_loss: -23202.1660
# Epoch 48/1000
# 84/84 [==============================] - ETA: 0s - loss: -24166.2520
# Epoch 48: val_loss improved from -23966.82617 to -24086.46875, saving model to ./trained_models/model-15252d39-checkpoints/weights.48-t-24166.25-v-24086.47.hdf5
# 84/84 [==============================] - 7s 87ms/step - loss: -24166.2520 - val_loss: -24086.4688
# Epoch 49/1000
# 84/84 [==============================] - ETA: 0s - loss: -24085.9121
# Epoch 49: val_loss did not improve from -24086.46875
# 84/84 [==============================] - 7s 85ms/step - loss: -24085.9121 - val_loss: -23658.8379
# Epoch 50/1000
# 84/84 [==============================] - ETA: 0s - loss: -24261.7012
# Epoch 50: val_loss did not improve from -24086.46875
# 84/84 [==============================] - 7s 87ms/step - loss: -24261.7012 - val_loss: -23457.5137
# Epoch 51/1000
# 84/84 [==============================] - ETA: 0s - loss: -24296.6875
# Epoch 51: val_loss did not improve from -24086.46875
# 84/84 [==============================] - 7s 86ms/step - loss: -24296.6875 - val_loss: -23862.3203
# Epoch 52/1000
# 84/84 [==============================] - ETA: 0s - loss: -24420.0859
# Epoch 52: val_loss improved from -24086.46875 to -24890.68164, saving model to ./trained_models/model-15252d39-checkpoints/weights.52-t-24420.09-v-24890.68.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -24420.0859 - val_loss: -24890.6816
# Epoch 53/1000
# 84/84 [==============================] - ETA: 0s - loss: -24542.1836
# Epoch 53: val_loss improved from -24890.68164 to -25063.97266, saving model to ./trained_models/model-15252d39-checkpoints/weights.53-t-24542.18-v-25063.97.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -24542.1836 - val_loss: -25063.9727
# Epoch 54/1000
# 84/84 [==============================] - ETA: 0s - loss: -24595.1211
# Epoch 54: val_loss did not improve from -25063.97266
# 84/84 [==============================] - 7s 87ms/step - loss: -24595.1211 - val_loss: -25028.8145
# Epoch 55/1000
# 84/84 [==============================] - ETA: 0s - loss: -24828.6016
# Epoch 55: val_loss did not improve from -25063.97266
# 84/84 [==============================] - 7s 87ms/step - loss: -24828.6016 - val_loss: -24503.2090
# Epoch 56/1000
# 84/84 [==============================] - ETA: 0s - loss: -24969.7012
# Epoch 56: val_loss did not improve from -25063.97266
# 84/84 [==============================] - 7s 85ms/step - loss: -24969.7012 - val_loss: -25044.3926
# Epoch 57/1000
# 84/84 [==============================] - ETA: 0s - loss: -24880.6055
# Epoch 57: val_loss did not improve from -25063.97266
# 84/84 [==============================] - 7s 88ms/step - loss: -24880.6055 - val_loss: -25037.3945
# Epoch 58/1000
# 84/84 [==============================] - ETA: 0s - loss: -25086.6914
# Epoch 58: val_loss improved from -25063.97266 to -25322.24023, saving model to ./trained_models/model-15252d39-checkpoints/weights.58-t-25086.69-v-25322.24.hdf5
# 84/84 [==============================] - 7s 87ms/step - loss: -25086.6914 - val_loss: -25322.2402
# Epoch 59/1000
# 84/84 [==============================] - ETA: 0s - loss: -25331.0137
# Epoch 59: val_loss did not improve from -25322.24023
# 84/84 [==============================] - 7s 87ms/step - loss: -25331.0137 - val_loss: -25241.3574
# Epoch 60/1000
# 84/84 [==============================] - ETA: 0s - loss: -25434.0879
# Epoch 60: val_loss did not improve from -25322.24023
# 84/84 [==============================] - 7s 88ms/step - loss: -25434.0879 - val_loss: -25052.8398
# Epoch 61/1000
# 84/84 [==============================] - ETA: 0s - loss: -25202.4277
# Epoch 61: val_loss improved from -25322.24023 to -25477.21094, saving model to ./trained_models/model-15252d39-checkpoints/weights.61-t-25202.43-v-25477.21.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -25202.4277 - val_loss: -25477.2109
# Epoch 62/1000
# 84/84 [==============================] - ETA: 0s - loss: -25315.5801
# Epoch 62: val_loss did not improve from -25477.21094
# 84/84 [==============================] - 7s 87ms/step - loss: -25315.5801 - val_loss: -24100.8164
# Epoch 63/1000
# 84/84 [==============================] - ETA: 0s - loss: -25160.0898
# Epoch 63: val_loss did not improve from -25477.21094
# 84/84 [==============================] - 7s 87ms/step - loss: -25160.0898 - val_loss: -23829.7715
# Epoch 64/1000
# 84/84 [==============================] - ETA: 0s - loss: -25338.7559
# Epoch 64: val_loss improved from -25477.21094 to -25832.93359, saving model to ./trained_models/model-15252d39-checkpoints/weights.64-t-25338.76-v-25832.93.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -25338.7559 - val_loss: -25832.9336
# Epoch 65/1000
# 84/84 [==============================] - ETA: 0s - loss: -25339.3926
# Epoch 65: val_loss did not improve from -25832.93359
# 84/84 [==============================] - 7s 87ms/step - loss: -25339.3926 - val_loss: -25319.3457
# Epoch 66/1000
# 84/84 [==============================] - ETA: 0s - loss: -25263.4961
# Epoch 66: val_loss did not improve from -25832.93359
# 84/84 [==============================] - 7s 85ms/step - loss: -25263.4961 - val_loss: -25392.1816
# Epoch 67/1000
# 84/84 [==============================] - ETA: 0s - loss: -25497.2871
# Epoch 67: val_loss did not improve from -25832.93359
# 84/84 [==============================] - 7s 87ms/step - loss: -25497.2871 - val_loss: -25808.1426
# Epoch 68/1000
# 84/84 [==============================] - ETA: 0s - loss: -25843.6602
# Epoch 68: val_loss did not improve from -25832.93359
# 84/84 [==============================] - 7s 86ms/step - loss: -25843.6602 - val_loss: -25646.4395
# Epoch 69/1000
# 84/84 [==============================] - ETA: 0s - loss: -25739.6621
# Epoch 69: val_loss did not improve from -25832.93359
# 84/84 [==============================] - 7s 87ms/step - loss: -25739.6621 - val_loss: -25512.1016
# Epoch 70/1000
# 84/84 [==============================] - ETA: 0s - loss: -25804.2285
# Epoch 70: val_loss did not improve from -25832.93359
# 84/84 [==============================] - 7s 86ms/step - loss: -25804.2285 - val_loss: -25621.0352
# Epoch 71/1000
# 84/84 [==============================] - ETA: 0s - loss: -25670.1855
# Epoch 71: val_loss improved from -25832.93359 to -25902.84180, saving model to ./trained_models/model-15252d39-checkpoints/weights.71-t-25670.19-v-25902.84.hdf5
# 84/84 [==============================] - 7s 87ms/step - loss: -25670.1855 - val_loss: -25902.8418
# Epoch 72/1000
# 84/84 [==============================] - ETA: 0s - loss: -25601.1426
# Epoch 72: val_loss improved from -25902.84180 to -26017.61523, saving model to ./trained_models/model-15252d39-checkpoints/weights.72-t-25601.14-v-26017.62.hdf5
# 84/84 [==============================] - 7s 89ms/step - loss: -25601.1426 - val_loss: -26017.6152
# Epoch 73/1000
# 84/84 [==============================] - ETA: 0s - loss: -25918.1992
# Epoch 73: val_loss did not improve from -26017.61523
# 84/84 [==============================] - 7s 86ms/step - loss: -25918.1992 - val_loss: -25279.8574
# Epoch 74/1000
# 84/84 [==============================] - ETA: 0s - loss: -25906.1230
# Epoch 74: val_loss did not improve from -26017.61523
# 84/84 [==============================] - 7s 88ms/step - loss: -25906.1230 - val_loss: -25864.4863
# Epoch 75/1000
# 84/84 [==============================] - ETA: 0s - loss: -25449.0098
# Epoch 75: val_loss did not improve from -26017.61523
# 84/84 [==============================] - 7s 87ms/step - loss: -25449.0098 - val_loss: -25636.2852
# Epoch 76/1000
# 84/84 [==============================] - ETA: 0s - loss: -25938.7852
# Epoch 76: val_loss improved from -26017.61523 to -26042.88672, saving model to ./trained_models/model-15252d39-checkpoints/weights.76-t-25938.79-v-26042.89.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -25938.7852 - val_loss: -26042.8867
# Epoch 77/1000
# 84/84 [==============================] - ETA: 0s - loss: -26204.7676
# Epoch 77: val_loss improved from -26042.88672 to -26684.70117, saving model to ./trained_models/model-15252d39-checkpoints/weights.77-t-26204.77-v-26684.70.hdf5
# 84/84 [==============================] - 8s 90ms/step - loss: -26204.7676 - val_loss: -26684.7012
# Epoch 78/1000
# 84/84 [==============================] - ETA: 0s - loss: -26322.2168
# Epoch 78: val_loss did not improve from -26684.70117
# 84/84 [==============================] - 7s 87ms/step - loss: -26322.2168 - val_loss: -26085.7852
# Epoch 79/1000
# 84/84 [==============================] - ETA: 0s - loss: -26160.1289
# Epoch 79: val_loss did not improve from -26684.70117
# 84/84 [==============================] - 7s 86ms/step - loss: -26160.1289 - val_loss: -26409.0391
# Epoch 80/1000
# 84/84 [==============================] - ETA: 0s - loss: -26293.2422
# Epoch 80: val_loss improved from -26684.70117 to -26824.03320, saving model to ./trained_models/model-15252d39-checkpoints/weights.80-t-26293.24-v-26824.03.hdf5
# 84/84 [==============================] - 7s 89ms/step - loss: -26293.2422 - val_loss: -26824.0332
# Epoch 81/1000
# 84/84 [==============================] - ETA: 0s - loss: -26349.3770
# Epoch 81: val_loss did not improve from -26824.03320
# 84/84 [==============================] - 7s 88ms/step - loss: -26349.3770 - val_loss: -25823.0820
# Epoch 82/1000
# 84/84 [==============================] - ETA: 0s - loss: -26510.9492
# Epoch 82: val_loss did not improve from -26824.03320
# 84/84 [==============================] - 7s 88ms/step - loss: -26510.9492 - val_loss: -26082.5605
# Epoch 83/1000
# 84/84 [==============================] - ETA: 0s - loss: -26374.1816
# Epoch 83: val_loss did not improve from -26824.03320
# 84/84 [==============================] - 7s 87ms/step - loss: -26374.1816 - val_loss: -26438.3164
# Epoch 84/1000
# 84/84 [==============================] - ETA: 0s - loss: -26641.5527
# Epoch 84: val_loss did not improve from -26824.03320
# 84/84 [==============================] - 7s 87ms/step - loss: -26641.5527 - val_loss: -25682.8672
# Epoch 85/1000
# 84/84 [==============================] - ETA: 0s - loss: -26446.8887
# Epoch 85: val_loss improved from -26824.03320 to -26873.47266, saving model to ./trained_models/model-15252d39-checkpoints/weights.85-t-26446.89-v-26873.47.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -26446.8887 - val_loss: -26873.4727
# Epoch 86/1000
# 84/84 [==============================] - ETA: 0s - loss: -26590.1172
# Epoch 86: val_loss did not improve from -26873.47266
# 84/84 [==============================] - 7s 88ms/step - loss: -26590.1172 - val_loss: -26780.0840
# Epoch 87/1000
# 84/84 [==============================] - ETA: 0s - loss: -26762.2324
# Epoch 87: val_loss improved from -26873.47266 to -27031.18945, saving model to ./trained_models/model-15252d39-checkpoints/weights.87-t-26762.23-v-27031.19.hdf5
# 84/84 [==============================] - 8s 90ms/step - loss: -26762.2324 - val_loss: -27031.1895
# Epoch 88/1000
# 84/84 [==============================] - ETA: 0s - loss: -26667.7422
# Epoch 88: val_loss did not improve from -27031.18945
# 84/84 [==============================] - 7s 86ms/step - loss: -26667.7422 - val_loss: -26877.7910
# Epoch 89/1000
# 84/84 [==============================] - ETA: 0s - loss: -26637.7754
# Epoch 89: val_loss did not improve from -27031.18945
# 84/84 [==============================] - 7s 88ms/step - loss: -26637.7754 - val_loss: -26933.1797
# Epoch 90/1000
# 84/84 [==============================] - ETA: 0s - loss: -26666.8262
# Epoch 90: val_loss did not improve from -27031.18945
# 84/84 [==============================] - 7s 86ms/step - loss: -26666.8262 - val_loss: -26804.9492
# Epoch 91/1000
# 84/84 [==============================] - ETA: 0s - loss: -26493.1055
# Epoch 91: val_loss did not improve from -27031.18945
# 84/84 [==============================] - 7s 89ms/step - loss: -26493.1055 - val_loss: -26846.9473
# Epoch 92/1000
# 84/84 [==============================] - ETA: 0s - loss: -26571.3301
# Epoch 92: val_loss did not improve from -27031.18945
# 84/84 [==============================] - 7s 88ms/step - loss: -26571.3301 - val_loss: -26104.3340
# Epoch 93/1000
# 84/84 [==============================] - ETA: 0s - loss: -26818.5234
# Epoch 93: val_loss did not improve from -27031.18945
# 84/84 [==============================] - 7s 88ms/step - loss: -26818.5234 - val_loss: -26836.4023
# Epoch 94/1000
# 84/84 [==============================] - ETA: 0s - loss: -26690.4180
# Epoch 94: val_loss did not improve from -27031.18945
# 84/84 [==============================] - 7s 88ms/step - loss: -26690.4180 - val_loss: -26627.1133
# Epoch 95/1000
# 84/84 [==============================] - ETA: 0s - loss: -26719.7070
# Epoch 95: val_loss improved from -27031.18945 to -27257.59570, saving model to ./trained_models/model-15252d39-checkpoints/weights.95-t-26719.71-v-27257.60.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -26719.7070 - val_loss: -27257.5957
# Epoch 96/1000
# 84/84 [==============================] - ETA: 0s - loss: -26763.5723
# Epoch 96: val_loss did not improve from -27257.59570
# 84/84 [==============================] - 7s 89ms/step - loss: -26763.5723 - val_loss: -26653.5605
# Epoch 97/1000
# 84/84 [==============================] - ETA: 0s - loss: -27032.5664
# Epoch 97: val_loss improved from -27257.59570 to -27259.36719, saving model to ./trained_models/model-15252d39-checkpoints/weights.97-t-27032.57-v-27259.37.hdf5
# 84/84 [==============================] - 7s 89ms/step - loss: -27032.5664 - val_loss: -27259.3672
# Epoch 98/1000
# 84/84 [==============================] - ETA: 0s - loss: -26804.5195
# Epoch 98: val_loss did not improve from -27259.36719
# 84/84 [==============================] - 7s 87ms/step - loss: -26804.5195 - val_loss: -26313.3457
# Epoch 99/1000
# 84/84 [==============================] - ETA: 0s - loss: -26585.3516
# Epoch 99: val_loss improved from -27259.36719 to -27536.98633, saving model to ./trained_models/model-15252d39-checkpoints/weights.99-t-26585.35-v-27536.99.hdf5
# 84/84 [==============================] - 8s 90ms/step - loss: -26585.3516 - val_loss: -27536.9863
# Epoch 100/1000
# 84/84 [==============================] - ETA: 0s - loss: -26779.3184
# Epoch 100: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 86ms/step - loss: -26779.3184 - val_loss: -27100.8594
# Epoch 101/1000
# 84/84 [==============================] - ETA: 0s - loss: -26957.1973
# Epoch 101: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 86ms/step - loss: -26957.1973 - val_loss: -26390.3613
# Epoch 102/1000
# 84/84 [==============================] - ETA: 0s - loss: -26846.9902
# Epoch 102: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 87ms/step - loss: -26846.9902 - val_loss: -26302.2617
# Epoch 103/1000
# 84/84 [==============================] - ETA: 0s - loss: -26983.8301
# Epoch 103: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 89ms/step - loss: -26983.8301 - val_loss: -26398.9785
# Epoch 104/1000
# 84/84 [==============================] - ETA: 0s - loss: -27111.0000
# Epoch 104: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 88ms/step - loss: -27111.0000 - val_loss: -27077.1621
# Epoch 105/1000
# 84/84 [==============================] - ETA: 0s - loss: -27241.6562
# Epoch 105: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 86ms/step - loss: -27241.6562 - val_loss: -26680.6895
# Epoch 106/1000
# 84/84 [==============================] - ETA: 0s - loss: -26958.1289
# Epoch 106: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 87ms/step - loss: -26958.1289 - val_loss: -25807.9688
# Epoch 107/1000
# 84/84 [==============================] - ETA: 0s - loss: -27083.9102
# Epoch 107: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 86ms/step - loss: -27083.9102 - val_loss: -26583.4238
# Epoch 108/1000
# 84/84 [==============================] - ETA: 0s - loss: -26909.7207
# Epoch 108: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 86ms/step - loss: -26909.7207 - val_loss: -27242.7129
# Epoch 109/1000
# 84/84 [==============================] - ETA: 0s - loss: -27008.1777
# Epoch 109: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 87ms/step - loss: -27008.1777 - val_loss: -26193.7871
# Epoch 110/1000
# 84/84 [==============================] - ETA: 0s - loss: -27093.4453
# Epoch 110: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 88ms/step - loss: -27093.4453 - val_loss: -27252.4746
# Epoch 111/1000
# 84/84 [==============================] - ETA: 0s - loss: -27176.2871
# Epoch 111: val_loss did not improve from -27536.98633
# 84/84 [==============================] - 7s 88ms/step - loss: -27176.2871 - val_loss: -26764.2578
# Epoch 112/1000
# 84/84 [==============================] - ETA: 0s - loss: -27038.7617
# Epoch 112: val_loss improved from -27536.98633 to -27667.40625, saving model to ./trained_models/model-15252d39-checkpoints/weights.112-t-27038.76-v-27667.41.hdf5
# 84/84 [==============================] - 7s 89ms/step - loss: -27038.7617 - val_loss: -27667.4062
# Epoch 113/1000
# 84/84 [==============================] - ETA: 0s - loss: -27166.0195
# Epoch 113: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 85ms/step - loss: -27166.0195 - val_loss: -27445.3926
# Epoch 114/1000
# 84/84 [==============================] - ETA: 0s - loss: -26941.1523
# Epoch 114: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 85ms/step - loss: -26941.1523 - val_loss: -26740.2051
# Epoch 115/1000
# 84/84 [==============================] - ETA: 0s - loss: -27106.1465
# Epoch 115: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 86ms/step - loss: -27106.1465 - val_loss: -27382.1777
# Epoch 116/1000
# 84/84 [==============================] - ETA: 0s - loss: -26928.3496
# Epoch 116: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 87ms/step - loss: -26928.3496 - val_loss: -26718.9785
# Epoch 117/1000
# 84/84 [==============================] - ETA: 0s - loss: -27231.7422
# Epoch 117: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 86ms/step - loss: -27231.7422 - val_loss: -26730.6309
# Epoch 118/1000
# 84/84 [==============================] - ETA: 0s - loss: -27144.8301
# Epoch 118: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 87ms/step - loss: -27144.8301 - val_loss: -26838.0742
# Epoch 119/1000
# 84/84 [==============================] - ETA: 0s - loss: -27481.2402
# Epoch 119: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 87ms/step - loss: -27481.2402 - val_loss: -27529.1719
# Epoch 120/1000
# 84/84 [==============================] - ETA: 0s - loss: -27399.2695
# Epoch 120: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 87ms/step - loss: -27399.2695 - val_loss: -27342.3828
# Epoch 121/1000
# 84/84 [==============================] - ETA: 0s - loss: -27663.8438
# Epoch 121: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 86ms/step - loss: -27663.8438 - val_loss: -27588.2773
# Epoch 122/1000
# 84/84 [==============================] - ETA: 0s - loss: -27344.1484
# Epoch 122: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 87ms/step - loss: -27344.1484 - val_loss: -27402.8262
# Epoch 123/1000
# 84/84 [==============================] - ETA: 0s - loss: -27563.0742
# Epoch 123: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 88ms/step - loss: -27563.0742 - val_loss: -27147.9062
# Epoch 124/1000
# 84/84 [==============================] - ETA: 0s - loss: -27394.2070
# Epoch 124: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 88ms/step - loss: -27394.2070 - val_loss: -27279.7148
# Epoch 125/1000
# 84/84 [==============================] - ETA: 0s - loss: -27600.9844
# Epoch 125: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 88ms/step - loss: -27600.9844 - val_loss: -27123.7090
# Epoch 126/1000
# 84/84 [==============================] - ETA: 0s - loss: -27585.0781
# Epoch 126: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 88ms/step - loss: -27585.0781 - val_loss: -27561.7754
# Epoch 127/1000
# 84/84 [==============================] - ETA: 0s - loss: -27225.3340
# Epoch 127: val_loss did not improve from -27667.40625
# 84/84 [==============================] - 7s 86ms/step - loss: -27225.3340 - val_loss: -27571.3340
# Epoch 128/1000
# 84/84 [==============================] - ETA: 0s - loss: -27227.0234
# Epoch 128: val_loss improved from -27667.40625 to -27915.66992, saving model to ./trained_models/model-15252d39-checkpoints/weights.128-t-27227.02-v-27915.67.hdf5
# 84/84 [==============================] - 7s 87ms/step - loss: -27227.0234 - val_loss: -27915.6699
# Epoch 129/1000
# 84/84 [==============================] - ETA: 0s - loss: -27317.5859
# Epoch 129: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 89ms/step - loss: -27317.5859 - val_loss: -27484.1133
# Epoch 130/1000
# 84/84 [==============================] - ETA: 0s - loss: -27230.4609
# Epoch 130: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 88ms/step - loss: -27230.4609 - val_loss: -27302.7324
# Epoch 131/1000
# 84/84 [==============================] - ETA: 0s - loss: -27332.9668
# Epoch 131: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 88ms/step - loss: -27332.9668 - val_loss: -26700.9004
# Epoch 132/1000
# 84/84 [==============================] - ETA: 0s - loss: -27443.9766
# Epoch 132: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 86ms/step - loss: -27443.9766 - val_loss: -27681.9043
# Epoch 133/1000
# 84/84 [==============================] - ETA: 0s - loss: -27467.3535
# Epoch 133: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 86ms/step - loss: -27467.3535 - val_loss: -26756.7305
# Epoch 134/1000
# 84/84 [==============================] - ETA: 0s - loss: -27386.9375
# Epoch 134: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 85ms/step - loss: -27386.9375 - val_loss: -26883.4336
# Epoch 135/1000
# 84/84 [==============================] - ETA: 0s - loss: -27356.9824
# Epoch 135: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 89ms/step - loss: -27356.9824 - val_loss: -27868.5918
# Epoch 136/1000
# 84/84 [==============================] - ETA: 0s - loss: -27361.4922
# Epoch 136: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 86ms/step - loss: -27361.4922 - val_loss: -27005.6602
# Epoch 137/1000
# 84/84 [==============================] - ETA: 0s - loss: -27614.1836
# Epoch 137: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 86ms/step - loss: -27614.1836 - val_loss: -27502.9590
# Epoch 138/1000
# 84/84 [==============================] - ETA: 0s - loss: -27634.0156
# Epoch 138: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 86ms/step - loss: -27634.0156 - val_loss: -27552.9199
# Epoch 139/1000
# 84/84 [==============================] - ETA: 0s - loss: -27760.5527
# Epoch 139: val_loss did not improve from -27915.66992
# 84/84 [==============================] - 7s 87ms/step - loss: -27760.5527 - val_loss: -27045.0840
# Epoch 140/1000
# 84/84 [==============================] - ETA: 0s - loss: -27821.6406
# Epoch 140: val_loss improved from -27915.66992 to -28023.80273, saving model to ./trained_models/model-15252d39-checkpoints/weights.140-t-27821.64-v-28023.80.hdf5
# 84/84 [==============================] - 7s 88ms/step - loss: -27821.6406 - val_loss: -28023.8027
# Epoch 141/1000
# 84/84 [==============================] - ETA: 0s - loss: -27825.3262
# Epoch 141: val_loss did not improve from -28023.80273
# 84/84 [==============================] - 7s 86ms/step - loss: -27825.3262 - val_loss: -27804.6914
# Epoch 142/1000
# 84/84 [==============================] - ETA: 0s - loss: -27748.8164
# Epoch 142: val_loss did not improve from -28023.80273
# 84/84 [==============================] - 7s 89ms/step - loss: -27748.8164 - val_loss: -26751.4512
# Epoch 143/1000
# 84/84 [==============================] - ETA: 0s - loss: -27574.2559
# Epoch 143: val_loss did not improve from -28023.80273
# 84/84 [==============================] - 7s 87ms/step - loss: -27574.2559 - val_loss: -27836.7832
# Epoch 144/1000
# 84/84 [==============================] - ETA: 0s - loss: -27490.4629
# Epoch 144: val_loss did not improve from -28023.80273
# 84/84 [==============================] - 7s 86ms/step - loss: -27490.4629 - val_loss: -27592.4902
# Epoch 145/1000
# 84/84 [==============================] - ETA: 0s - loss: -27513.6934
# Epoch 145: val_loss did not improve from -28023.80273
# 84/84 [==============================] - 8s 90ms/step - loss: -27513.6934 - val_loss: -27392.9023
# Epoch 146/1000
# 84/84 [==============================] - ETA: 0s - loss: -27467.7051
# Epoch 146: val_loss did not improve from -28023.80273
# 84/84 [==============================] - 7s 87ms/step - loss: -27467.7051 - val_loss: -27447.5801
# Epoch 147/1000
# 84/84 [==============================] - ETA: 0s - loss: -27617.3867
# Epoch 147: val_loss did not improve from -28023.80273
# 84/84 [==============================] - 7s 86ms/step - loss: -27617.3867 - val_loss: -27686.7031
# Epoch 148/1000
# 84/84 [==============================] - ETA: 0s - loss: -27528.9336
# Epoch 148: val_loss did not improve from -28023.80273
# 84/84 [==============================] - 7s 87ms/step - loss: -27528.9336 - val_loss: -26995.2324
# Epoch 149/1000
# 84/84 [==============================] - ETA: 0s - loss: -27250.8848
# Epoch 149: val_loss did not improve from -28023.80273
# 84/84 [==============================] - 7s 88ms/step - loss: -27250.8848 - val_loss: -26620.2363
# Epoch 150/1000
# 84/84 [==============================] - ETA: 0s - loss: -27680.8125
# Epoch 150: val_loss improved from -28023.80273 to -28394.49805, saving model to ./trained_models/model-15252d39-checkpoints/weights.150-t-27680.81-v-28394.50.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -27680.8125 - val_loss: -28394.4980
# Epoch 151/1000
# 84/84 [==============================] - ETA: 0s - loss: -27736.3301
# Epoch 151: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 86ms/step - loss: -27736.3301 - val_loss: -27991.5000
# Epoch 152/1000
# 84/84 [==============================] - ETA: 0s - loss: -27901.9980
# Epoch 152: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 87ms/step - loss: -27901.9980 - val_loss: -27658.5664
# Epoch 153/1000
# 84/84 [==============================] - ETA: 0s - loss: -27894.5430
# Epoch 153: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 87ms/step - loss: -27894.5430 - val_loss: -27592.4062
# Epoch 154/1000
# 84/84 [==============================] - ETA: 0s - loss: -27834.3047
# Epoch 154: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 88ms/step - loss: -27834.3047 - val_loss: -27611.6074
# Epoch 155/1000
# 84/84 [==============================] - ETA: 0s - loss: -27814.6426
# Epoch 155: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 85ms/step - loss: -27814.6426 - val_loss: -27923.6289
# Epoch 156/1000
# 84/84 [==============================] - ETA: 0s - loss: -27709.8184
# Epoch 156: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 84ms/step - loss: -27709.8184 - val_loss: -27741.1289
# Epoch 157/1000
# 84/84 [==============================] - ETA: 0s - loss: -27857.6621
# Epoch 157: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 86ms/step - loss: -27857.6621 - val_loss: -27677.4746
# Epoch 158/1000
# 84/84 [==============================] - ETA: 0s - loss: -27900.6309
# Epoch 158: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 87ms/step - loss: -27900.6309 - val_loss: -27445.9922
# Epoch 159/1000
# 84/84 [==============================] - ETA: 0s - loss: -27630.6191
# Epoch 159: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 86ms/step - loss: -27630.6191 - val_loss: -28212.1289
# Epoch 160/1000
# 84/84 [==============================] - ETA: 0s - loss: -27649.0859
# Epoch 160: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 87ms/step - loss: -27649.0859 - val_loss: -28282.3516
# Epoch 161/1000
# 84/84 [==============================] - ETA: 0s - loss: -27928.9062
# Epoch 161: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 84ms/step - loss: -27928.9062 - val_loss: -25177.7969
# Epoch 162/1000
# 84/84 [==============================] - ETA: 0s - loss: -27807.3887
# Epoch 162: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 86ms/step - loss: -27807.3887 - val_loss: -27837.5098
# Epoch 163/1000
# 84/84 [==============================] - ETA: 0s - loss: -27898.0996
# Epoch 163: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 88ms/step - loss: -27898.0996 - val_loss: -28078.4355
# Epoch 164/1000
# 84/84 [==============================] - ETA: 0s - loss: -27807.5020
# Epoch 164: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 85ms/step - loss: -27807.5020 - val_loss: -27400.0645
# Epoch 165/1000
# 84/84 [==============================] - ETA: 0s - loss: -27726.9004
# Epoch 165: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 87ms/step - loss: -27726.9004 - val_loss: -27217.4180
# Epoch 166/1000
# 84/84 [==============================] - ETA: 0s - loss: -28016.1602
# Epoch 166: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 87ms/step - loss: -28016.1602 - val_loss: -28318.1250
# Epoch 167/1000
# 84/84 [==============================] - ETA: 0s - loss: -27980.2324
# Epoch 167: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 86ms/step - loss: -27980.2324 - val_loss: -28341.2227
# Epoch 168/1000
# 84/84 [==============================] - ETA: 0s - loss: -28073.2402
# Epoch 168: val_loss did not improve from -28394.49805
# 84/84 [==============================] - 7s 88ms/step - loss: -28073.2402 - val_loss: -28369.8242
# Epoch 169/1000
# 84/84 [==============================] - ETA: 0s - loss: -28014.5781
# Epoch 169: val_loss improved from -28394.49805 to -28433.05078, saving model to ./trained_models/model-15252d39-checkpoints/weights.169-t-28014.58-v-28433.05.hdf5
# 84/84 [==============================] - 7s 86ms/step - loss: -28014.5781 - val_loss: -28433.0508
# Epoch 170/1000
# 84/84 [==============================] - ETA: 0s - loss: -28007.6328
# Epoch 170: val_loss did not improve from -28433.05078
# 84/84 [==============================] - 7s 88ms/step - loss: -28007.6328 - val_loss: -28266.5723
# Epoch 171/1000
# 84/84 [==============================] - ETA: 0s - loss: -28104.7168
# Epoch 171: val_loss did not improve from -28433.05078
# 84/84 [==============================] - 7s 85ms/step - loss: -28104.7168 - val_loss: -27228.4277
# Epoch 172/1000
# 84/84 [==============================] - ETA: 0s - loss: -27937.0098
# Epoch 172: val_loss did not improve from -28433.05078
# 84/84 [==============================] - 7s 87ms/step - loss: -27937.0098 - val_loss: -28075.7734
# Epoch 173/1000
# 84/84 [==============================] - ETA: 0s - loss: -27952.6719
# Epoch 173: val_loss did not improve from -28433.05078
# 84/84 [==============================] - 7s 86ms/step - loss: -27952.6719 - val_loss: -27828.2715
# Epoch 174/1000
# 84/84 [==============================] - ETA: 0s - loss: -27517.0488
# Epoch 174: val_loss did not improve from -28433.05078
# 84/84 [==============================] - 7s 87ms/step - loss: -27517.0488 - val_loss: -26334.6895
# Epoch 175/1000
# 84/84 [==============================] - ETA: 0s - loss: -27371.0332
# Epoch 175: val_loss did not improve from -28433.05078
# 84/84 [==============================] - 7s 86ms/step - loss: -27371.0332 - val_loss: -27843.9883
# Epoch 176/1000
# 84/84 [==============================] - ETA: 0s - loss: -27295.0898
# Epoch 176: val_loss did not improve from -28433.05078
# 84/84 [==============================] - 7s 87ms/step - loss: -27295.0898 - val_loss: -28163.7656
# Epoch 177/1000
# 50/84 [================>.............] - ETA: 2s - loss: -27955.8633
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 history = diag_model.fit(
#       2         x=training_generator,
#       3         validation_data=validation_generator,
#       4         callbacks=[es, mcp, csv_logger],
#       5         epochs=1000,
#       6         shuffle=False,
#       7         verbose=1
#       8     )
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File /depot/cms/kernels/python3/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
