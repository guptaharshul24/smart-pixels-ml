# %%
import os
import tensorflow as tf
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras

from tensorflow.keras import layers, models
# Out:
# 2025-11-22 05:04:53.055063: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-22 05:04:53.055165: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-22 05:04:53.136315: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-22 05:04:53.276846: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-22 05:05:04.467881: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
os.chdir('/home/das214/SmartPix/SoftQuantize')
# !pwd
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.chdir('/home/das214/SmartPix/SoftQuantize')
#       2 get_ipython().system('pwd')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/das214/SmartPix/SoftQuantize'

# %%
from DG.OptimizedDataGenerator_v2 import OptimizedDataGenerator
from losses.loss import custom_loss
from models.SoftQuantizeLayer import SoftQuantizeLayer

pi = 3.14159265359

maxval=1e9
minval=1e-9

# %%
from DG.OptimizedDataGenerator_v2 import OptimizedDataGenerator
from losses.loss import custom_loss
from models.SoftQuantizeLayer import SoftQuantizeLayer

pi = 3.14159265359

maxval=1e9
minval=1e-9

# %%
# Trasformer model

class PatchExtractor(layers.Layer):
  """Extract 2D patches from images."""
  def __init__(self, patch_size=(3,7)):
    super().__init__()
    self.patch_size = patch_size

  def call(self, images):
    # images: (batch, H, W, C)
    patch_h, patch_w = self.patch_size
    batch_size = tf.shape(images)[0]
    patches = tf.image.extract_patches(
        images=images,
        sizes=(1, patch_h, patch_w, 1),
        strides=(1, patch_h, patch_w, 1),
        rates=(1,1,1,1),
        padding='VALID'
    )
    # Now `patches` has shape: 
    #   (batch, H//patch_h, W//patch_w, patch_h*patch_w*C)
    # Flatten the 2D grid of patches => (batch, num_patches, patch_dim)
    patch_dims = tf.shape(patches)[-1]
    patches = tf.reshape(
        patches,
        [batch_size, -1, patch_dims]
    )
    return patches

class PatchEncoder(layers.Layer):
  """Linear embedding + learnable positional encoding."""
  def __init__(self, num_patches, embed_dim):
    super().__init__()
    self.num_patches = num_patches
    self.projection  = layers.Dense(embed_dim)
    self.pos_embed   = tf.Variable(
        initial_value=tf.zeros((1,num_patches,embed_dim)),
        trainable=True,
        name="pos_embedding"
    )

  def call(self, patch_batch):
    # Linear projection of patch tokens
    projected = self.projection(patch_batch)
    # Add learnable positional embeddings
    return projected + self.pos_embed

def transformer_encoder(inputs,
                        head_size,
                        num_heads,
                        ff_dim,
                        dropout=0.1):
  # LayerNorm + Multi-head attention
  x = layers.LayerNormalization(epsilon=1e-6)(inputs)
  x = layers.MultiHeadAttention(num_heads=num_heads,
                                key_dim=head_size,
                                dropout=dropout)(x, x)
  x = layers.Dropout(dropout)(x)
  res = x + inputs
  
  # Next LN + feed-forward
  x = layers.LayerNormalization(epsilon=1e-6)(res)
  x = layers.Dense(ff_dim, activation="relu")(x)
  x = layers.Dropout(dropout)(x)
  x = layers.Dense(inputs.shape[-1], activation="linear")(x)
  x = layers.Dropout(dropout)(x)
  
  return x + res

def create_vit_model(input_shape=(13,21,2),
                     patch_size=(3,7),
                     embed_dim=64,
                     num_heads=4,
                     ff_dim=128,
                     num_layers=4,
                     dropout=0.1,
                     final_outputs=14):
  # Input
  inp = layers.Input(shape=input_shape, name="raw_input")

  q_out = SoftQuantizeLayer(
      n_bits=2,
      initial_range=[-1.0, 1.0],
      trainable_levels=False,
      trainable_thresholds=True,
      initial_k=1.0,
      trainable_k=True,
      name="soft_quantizer_output"
  )(inp)

  # 1) Extract patches
  patches = PatchExtractor(patch_size=patch_size)(q_out)
  
  # Calculate how many patches we extracted:
  #   (H // patch_h) * (W // patch_w)
  # Must do it statically if possible:
  # e.g. 13//3=4, 21//7=3 => 12 patches total
  H, W, C = input_shape
  ph, pw  = patch_size
  num_patches = (H // ph) * (W // pw)

  # 2) Encode patches (linear projection + positional embedding)
  encoded_patches = PatchEncoder(num_patches, embed_dim)(patches)

  # 3) Apply multiple Transformer encoder blocks
  x = encoded_patches
  for _ in range(num_layers):
    x = transformer_encoder(x,
                            head_size=embed_dim,
                            num_heads=num_heads,
                            ff_dim=ff_dim,
                            dropout=dropout)
  
  # 4) Flatten and final Dense
  x = layers.LayerNormalization(epsilon=1e-6)(x)
  x = layers.Flatten()(x)
  x = layers.Dense(64, activation='relu')(x)
  outputs = layers.Dense(final_outputs, activation='linear')(x)

  # Create model
  model = keras.Model(inputs=inp, outputs=outputs)
  return model

model = create_vit_model(
    input_shape=(16,16,2),   
    patch_size=(3,4),        
    embed_dim=64,           
    num_heads=4,            
    ff_dim=128,              
    num_layers=4,            
    dropout=0.1,             
    final_outputs=14         
)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Nadam(learning_rate=1e-3, clipnorm=1.0),
    loss=custom_loss,
)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  raw_input (InputLayer)      [(None, 16, 16, 2)]          0         []
#
#  soft_quantizer_output (Sof  (None, 16, 16, 2)            8         ['raw_input[0][0]']
#  tQuantizeLayer)
#
#  patch_extractor_1 (PatchEx  (None, None, 24)             0         ['soft_quantizer_output[0][0]'
#  tractor)                                                           ]
#
#  patch_encoder_1 (PatchEnco  (None, 20, 64)               2880      ['patch_extractor_1[0][0]']
#  der)
#
#  layer_normalization_9 (Lay  (None, 20, 64)               128       ['patch_encoder_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_4 (Mu  (None, 20, 64)               66368     ['layer_normalization_9[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_9[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 20, 64)               0         ['multi_head_attention_4[0][0]
#                                                                     ']
#
#  tf.__operators__.add_8 (TF  (None, 20, 64)               0         ['dropout_12[0][0]',
#  OpLambda)                                                           'patch_encoder_1[0][0]']
#
#  layer_normalization_10 (La  (None, 20, 64)               128       ['tf.__operators__.add_8[0][0]
#  yerNormalization)                                                  ']
#
#  dense_12 (Dense)            (None, 20, 128)              8320      ['layer_normalization_10[0][0]
#                                                                     ']
#
#  dropout_13 (Dropout)        (None, 20, 128)              0         ['dense_12[0][0]']
#
#  dense_13 (Dense)            (None, 20, 64)               8256      ['dropout_13[0][0]']
#
#  dropout_14 (Dropout)        (None, 20, 64)               0         ['dense_13[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 20, 64)               0         ['dropout_14[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  layer_normalization_11 (La  (None, 20, 64)               128       ['tf.__operators__.add_9[0][0]
#  yerNormalization)                                                  ']
#
#  multi_head_attention_5 (Mu  (None, 20, 64)               66368     ['layer_normalization_11[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_11[0][0]
#                                                                     ']
#
#  dropout_15 (Dropout)        (None, 20, 64)               0         ['multi_head_attention_5[0][0]
#                                                                     ']
#
#  tf.__operators__.add_10 (T  (None, 20, 64)               0         ['dropout_15[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  layer_normalization_12 (La  (None, 20, 64)               128       ['tf.__operators__.add_10[0][0
#  yerNormalization)                                                  ]']
#
#  dense_14 (Dense)            (None, 20, 128)              8320      ['layer_normalization_12[0][0]
#                                                                     ']
#
#  dropout_16 (Dropout)        (None, 20, 128)              0         ['dense_14[0][0]']
#
#  dense_15 (Dense)            (None, 20, 64)               8256      ['dropout_16[0][0]']
#
#  dropout_17 (Dropout)        (None, 20, 64)               0         ['dense_15[0][0]']
#
#  tf.__operators__.add_11 (T  (None, 20, 64)               0         ['dropout_17[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  layer_normalization_13 (La  (None, 20, 64)               128       ['tf.__operators__.add_11[0][0
#  yerNormalization)                                                  ]']
#
#  multi_head_attention_6 (Mu  (None, 20, 64)               66368     ['layer_normalization_13[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_13[0][0]
#                                                                     ']
#
#  dropout_18 (Dropout)        (None, 20, 64)               0         ['multi_head_attention_6[0][0]
#                                                                     ']
#
#  tf.__operators__.add_12 (T  (None, 20, 64)               0         ['dropout_18[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  layer_normalization_14 (La  (None, 20, 64)               128       ['tf.__operators__.add_12[0][0
#  yerNormalization)                                                  ]']
#
#  dense_16 (Dense)            (None, 20, 128)              8320      ['layer_normalization_14[0][0]
#                                                                     ']
#
#  dropout_19 (Dropout)        (None, 20, 128)              0         ['dense_16[0][0]']
#
#  dense_17 (Dense)            (None, 20, 64)               8256      ['dropout_19[0][0]']
#
#  dropout_20 (Dropout)        (None, 20, 64)               0         ['dense_17[0][0]']
#
#  tf.__operators__.add_13 (T  (None, 20, 64)               0         ['dropout_20[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  layer_normalization_15 (La  (None, 20, 64)               128       ['tf.__operators__.add_13[0][0
#  yerNormalization)                                                  ]']
#
#  multi_head_attention_7 (Mu  (None, 20, 64)               66368     ['layer_normalization_15[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_15[0][0]
#                                                                     ']
#
#  dropout_21 (Dropout)        (None, 20, 64)               0         ['multi_head_attention_7[0][0]
#                                                                     ']
#
#  tf.__operators__.add_14 (T  (None, 20, 64)               0         ['dropout_21[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  layer_normalization_16 (La  (None, 20, 64)               128       ['tf.__operators__.add_14[0][0
#  yerNormalization)                                                  ]']
#
#  dense_18 (Dense)            (None, 20, 128)              8320      ['layer_normalization_16[0][0]
#                                                                     ']
#
#  dropout_22 (Dropout)        (None, 20, 128)              0         ['dense_18[0][0]']
#
#  dense_19 (Dense)            (None, 20, 64)               8256      ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)        (None, 20, 64)               0         ['dense_19[0][0]']
#
#  tf.__operators__.add_15 (T  (None, 20, 64)               0         ['dropout_23[0][0]',
#  FOpLambda)                                                          'tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  layer_normalization_17 (La  (None, 20, 64)               128       ['tf.__operators__.add_15[0][0
#  yerNormalization)                                                  ]']
#
#  flatten_1 (Flatten)         (None, 1280)                 0         ['layer_normalization_17[0][0]
#                                                                     ']
#
#  dense_20 (Dense)            (None, 64)                   81984     ['flatten_1[0][0]']
#
#  dense_21 (Dense)            (None, 14)                   910       ['dense_20[0][0]']
#
# ==================================================================================================
# Total params: 418710 (1.60 MB)
# Trainable params: 418706 (1.60 MB)
# Non-trainable params: 4 (16.00 Byte)
# __________________________________________________________________________________________________

# %%
fingerprint = "6505d613"
# model-6fe6ea98-checkpoints
# 8b72d007: Variable x-bin and y-hieghts

# %%
import glob

base = "/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models"
paths = glob.glob(f"{base}/Transformer_model-*-checkpoints")

for p in paths:
    print(p)
# Out:
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-a582680c-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-86a8a0c2-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-06de83c6-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-2484b3a3-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-c76b7cfd-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-2f64399b-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-3bf58aff-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-30b289ad-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-7e04c64a-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-5bc54ea3-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-f1e1d6e8-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-24dc9e67-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-419c5bd9-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-fa6111d5-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-e01f5297-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-b8eae452-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-1e3095de-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-0a3516e5-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-7f1a5b11-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6434c9a5-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-d70d9928-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-599550bf-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-f075cde6-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-d2cad374-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-42daaeca-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-bf39c972-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-e40ad9b2-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-684b5361-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-c49d3311-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-d870572b-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-50734524-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-237172ff-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-d1fa0d89-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-a3200065-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-e5ba7616-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-f83deb44-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-8b536884-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-f611508f-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-818ce6a7-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-e63a2876-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-58859c8d-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-e0164a3a-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-b9a1ea6a-checkpoints
# /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-ac130f16-checkpoints

# %%
base_dir = f'/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-{fingerprint}-checkpoints'
plot_dir = os.path.join(base_dir, 'plots')
checkpoints_dir = os.path.join(base_dir, 'checkpoints')
training_cp_path = os.path.join(base_dir, 'training_log.csv')
training_history = pd.read_csv(training_cp_path)

os.makedirs(plot_dir, exist_ok=True)

checkpoint_files = sorted([os.path.join(checkpoints_dir, f) for f in os.listdir(checkpoints_dir) if f.endswith('.hdf5')])
checkpoint_files
# Out:
# ['/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.01-t23161.02-v14838.46.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.02-t14535.47-v12948.35.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.03-t12780.81-v11587.92.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.04-t11562.09-v10663.55.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.05-t10762.67-v10070.36.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.06-t10175.81-v9386.72.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.07-t9652.58-v8890.33.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.08-t9216.83-v8432.58.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.09-t8747.38-v7831.68.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.10-t8328.88-v7606.40.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.100-t-16014.65-v-17426.13.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.1000-t-21605.61-v-22048.59.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.101-t-15959.97-v-17499.96.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.102-t-16256.11-v-17249.79.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.103-t-16081.59-v-17032.10.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.104-t-16092.57-v-17167.96.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.105-t-16098.84-v-17438.86.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.106-t-16098.88-v-17339.19.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.107-t-16432.38-v-17700.15.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.108-t-16528.48-v-17637.04.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.109-t-16538.18-v-17611.33.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.11-t7961.23-v7056.64.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.110-t-16562.05-v-17523.95.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.111-t-16580.23-v-17540.22.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.112-t-16662.22-v-17806.39.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.113-t-16529.51-v-17462.18.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.114-t-16531.94-v-17735.00.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.115-t-16688.57-v-17625.38.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.116-t-16899.55-v-17984.91.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.117-t-16832.81-v-17858.95.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.118-t-16928.63-v-18192.97.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.119-t-17061.06-v-17988.43.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.12-t7509.27-v6501.12.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.120-t-16867.20-v-17906.51.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.121-t-16955.98-v-18030.09.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.122-t-17190.04-v-18510.30.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.123-t-17311.06-v-18681.92.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.124-t-17410.93-v-18576.39.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.125-t-17384.96-v-18120.50.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.126-t-17352.55-v-18579.87.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.127-t-17501.77-v-18806.33.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.128-t-17630.29-v-18254.39.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.129-t-17618.77-v-19040.81.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.13-t7024.49-v5936.74.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.130-t-17619.40-v-18705.98.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.131-t-17663.58-v-19238.75.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.132-t-17764.88-v-18686.00.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.133-t-17778.41-v-18659.70.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.134-t-17857.70-v-18721.88.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.135-t-17852.09-v-18975.79.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.136-t-17926.59-v-18913.61.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.137-t-17884.71-v-19264.40.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.138-t-18035.56-v-18787.00.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.139-t-18050.90-v-19298.75.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.14-t6508.72-v5336.51.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.140-t-18149.24-v-19056.73.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.141-t-18178.76-v-19444.97.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.142-t-18156.48-v-18918.70.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.143-t-18264.91-v-19284.66.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.144-t-18298.24-v-19712.33.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.145-t-18324.87-v-19185.52.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.146-t-18355.26-v-19282.61.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.147-t-18380.15-v-19347.50.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.148-t-18434.38-v-19313.61.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.149-t-18450.17-v-19374.84.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.15-t5947.53-v4749.82.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.150-t-18482.24-v-19930.46.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.151-t-18560.74-v-19337.45.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.152-t-18515.92-v-19464.69.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.153-t-18581.10-v-19488.44.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.154-t-18619.41-v-19624.52.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.155-t-18643.54-v-19622.71.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.156-t-18615.03-v-19747.81.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.157-t-18659.04-v-20065.58.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.158-t-18676.13-v-19493.65.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.159-t-18716.89-v-19824.88.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.16-t5340.99-v3981.90.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.160-t-18731.32-v-19688.03.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.161-t-18753.45-v-19751.67.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.162-t-18753.72-v-19657.66.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.163-t-18808.17-v-19758.28.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.164-t-18788.20-v-19490.00.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.165-t-18811.38-v-20121.34.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.166-t-18830.59-v-19972.10.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.167-t-18841.61-v-19608.56.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.168-t-18889.77-v-19566.29.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.169-t-18867.52-v-19986.76.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.17-t4817.51-v3400.51.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.170-t-18896.33-v-20227.76.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.171-t-18913.97-v-19768.69.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.172-t-18942.51-v-19545.77.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.173-t-18962.34-v-19788.99.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.174-t-18961.77-v-20068.76.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.175-t-18952.60-v-19954.08.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.176-t-19011.73-v-19784.86.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.177-t-19019.00-v-20259.57.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.178-t-19046.37-v-19949.45.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.179-t-19012.02-v-19775.14.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.18-t4180.20-v2744.91.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.180-t-19028.59-v-19986.52.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.181-t-19054.87-v-19836.78.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.182-t-19043.84-v-19927.98.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.183-t-19062.71-v-20001.31.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.184-t-19082.72-v-20098.17.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.185-t-19088.96-v-20074.52.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.186-t-19091.46-v-20198.73.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.187-t-19062.24-v-19760.70.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.188-t-19010.26-v-20302.59.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.189-t-19115.98-v-19745.65.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.19-t3609.21-v2114.38.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.190-t-19150.25-v-19969.24.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.191-t-19170.22-v-19868.00.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.192-t-19175.18-v-19967.05.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.193-t-19178.86-v-19843.12.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.194-t-19203.55-v-19940.53.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.195-t-19223.05-v-20395.45.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.196-t-19219.44-v-19873.74.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.197-t-19215.74-v-20126.88.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.198-t-19177.01-v-19970.48.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.199-t-19204.23-v-19958.39.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.20-t2904.32-v1469.74.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.200-t-19225.28-v-19998.72.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.201-t-19167.04-v-19970.12.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.202-t-19260.74-v-19810.03.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.203-t-19204.77-v-20045.67.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.204-t-19237.04-v-19890.96.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.205-t-19233.61-v-19937.43.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.206-t-19248.06-v-19930.15.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.207-t-19296.08-v-19995.99.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.208-t-19288.65-v-20249.72.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.209-t-19273.37-v-20200.74.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.21-t2352.67-v844.46.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.210-t-19324.22-v-19930.98.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.211-t-19289.63-v-19848.58.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.212-t-19299.94-v-19818.01.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.213-t-19291.72-v-19938.78.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.214-t-19342.12-v-19932.92.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.215-t-19323.59-v-20171.67.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.216-t-19328.87-v-20046.31.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.217-t-19340.82-v-20008.38.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.218-t-19373.51-v-20478.28.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.219-t-19379.02-v-19932.92.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.22-t1758.31-v110.05.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.220-t-19371.25-v-20291.63.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.221-t-19386.47-v-20521.39.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.222-t-19379.33-v-19737.34.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.223-t-19409.40-v-20092.15.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.224-t-19394.66-v-20031.11.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.225-t-19416.15-v-19907.56.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.226-t-19383.23-v-20066.49.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.227-t-19422.96-v-20170.06.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.228-t-19391.11-v-20050.10.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.229-t-19399.45-v-20193.39.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.23-t943.58-v-925.60.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.230-t-19467.12-v-20018.76.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.231-t-19466.00-v-19863.54.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.232-t-19413.69-v-20025.83.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.233-t-19478.64-v-20415.31.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.234-t-19483.63-v-20035.04.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.235-t-19512.16-v-20090.86.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.236-t-19487.44-v-20074.83.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.237-t-19512.00-v-20052.63.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.238-t-19527.36-v-20118.17.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.239-t-19532.14-v-20257.39.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.24-t57.05-v-1896.19.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.240-t-19472.44-v-20047.11.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.241-t-19503.43-v-20026.19.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.242-t-19555.53-v-20270.53.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.243-t-19567.66-v-20184.40.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.244-t-19569.97-v-19665.61.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.245-t-19552.74-v-20165.31.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.246-t-19558.33-v-20206.70.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.247-t-19526.98-v-20031.39.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.248-t-19581.52-v-19928.71.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.249-t-19565.98-v-20142.09.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.25-t-805.22-v-2913.50.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.250-t-19600.45-v-19977.36.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.251-t-19616.93-v-20124.24.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.252-t-19587.23-v-20161.02.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.253-t-19617.99-v-20344.84.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.254-t-19636.47-v-20218.82.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.255-t-19649.55-v-20033.28.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.256-t-19625.57-v-20623.15.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.257-t-19617.19-v-20176.33.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.258-t-19651.87-v-20266.26.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.259-t-19655.02-v-20224.45.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.26-t-2406.68-v-5025.56.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.260-t-19643.07-v-20329.03.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.261-t-19654.68-v-20186.57.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.262-t-19685.72-v-20109.27.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.263-t-19685.80-v-20274.39.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.264-t-19682.26-v-20199.73.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.265-t-19687.75-v-20213.69.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.266-t-19698.64-v-20092.93.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.267-t-19700.26-v-20210.18.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.268-t-19706.51-v-20289.35.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.269-t-19693.03-v-20591.96.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.27-t-3958.03-v-6365.64.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.270-t-19718.35-v-20315.80.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.271-t-19735.53-v-20803.15.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.272-t-19749.11-v-20355.22.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.273-t-19719.26-v-20255.46.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.274-t-19753.19-v-20341.88.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.275-t-19742.77-v-20034.90.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.276-t-19757.58-v-20427.35.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.277-t-19770.26-v-20365.92.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.278-t-19781.09-v-20225.75.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.279-t-19779.12-v-20359.25.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.28-t-4814.20-v-7459.52.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.280-t-19765.64-v-20378.63.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.281-t-19778.64-v-20542.13.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.282-t-19799.94-v-20095.81.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.283-t-19794.17-v-20160.74.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.284-t-19809.76-v-20565.56.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.285-t-19794.67-v-20476.15.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.286-t-19797.31-v-20264.96.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.287-t-19822.19-v-20307.74.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.288-t-19827.96-v-20365.48.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.289-t-19835.59-v-20232.09.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.29-t-5895.00-v-8435.81.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.290-t-19820.29-v-20335.58.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.291-t-19839.20-v-20638.31.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.292-t-19857.61-v-20347.43.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.293-t-19826.94-v-20077.74.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.294-t-19837.43-v-20458.04.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.295-t-19846.26-v-20374.42.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.296-t-19855.05-v-20304.18.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.297-t-19855.47-v-20226.09.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.298-t-19873.72-v-20464.22.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.299-t-19861.79-v-20507.55.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.30-t-6910.31-v-9367.98.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.300-t-19894.63-v-20275.08.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.301-t-19849.51-v-20330.75.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.302-t-19871.96-v-20311.17.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.303-t-19882.05-v-20423.06.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.304-t-19902.70-v-20254.94.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.305-t-19882.91-v-20629.64.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.306-t-19887.36-v-20565.25.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.307-t-19887.63-v-20350.14.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.308-t-19903.42-v-20169.85.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.309-t-19898.54-v-20305.24.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.31-t-7975.13-v-10415.96.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.310-t-19907.65-v-20591.41.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.311-t-19916.04-v-20419.06.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.312-t-19898.20-v-20475.80.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.313-t-19907.77-v-20302.26.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.314-t-19899.85-v-20701.62.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.315-t-19923.55-v-20402.63.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.316-t-19928.55-v-20513.80.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.317-t-19945.77-v-20716.80.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.318-t-19930.95-v-20342.82.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.319-t-19955.18-v-20532.03.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.32-t-8842.07-v-11259.98.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.320-t-19952.14-v-20413.18.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.321-t-19966.15-v-20218.44.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.322-t-19949.40-v-20337.63.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.323-t-19966.87-v-20492.91.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.324-t-19951.57-v-20455.52.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.325-t-19950.46-v-20351.67.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.326-t-19955.94-v-20617.24.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.327-t-19965.55-v-20344.64.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.328-t-19968.09-v-20296.26.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.329-t-19960.07-v-20550.41.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.33-t-9676.16-v-12261.02.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.330-t-19975.52-v-20615.36.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.331-t-19989.45-v-20313.93.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.332-t-19989.99-v-20382.61.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.333-t-19980.51-v-20633.57.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.334-t-19987.35-v-20371.28.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.335-t-20000.92-v-20799.57.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.336-t-20012.05-v-20417.91.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.337-t-20004.78-v-20810.99.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.338-t-20007.83-v-20403.06.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.339-t-20004.81-v-20226.80.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.34-t-10819.78-v-14090.34.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.340-t-19999.40-v-20590.83.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.341-t-20015.67-v-20684.53.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.342-t-20013.87-v-20238.47.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.343-t-20027.06-v-20402.32.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.344-t-20032.90-v-20524.49.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.345-t-20005.51-v-20959.57.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.346-t-20021.93-v-20654.54.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.347-t-20034.29-v-20503.67.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.348-t-20034.62-v-20418.27.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.349-t-20053.77-v-20470.97.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.35-t-12060.24-v-14870.85.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.350-t-20058.17-v-20430.77.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.351-t-20062.05-v-20592.37.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.352-t-20058.41-v-20675.61.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.353-t-20051.85-v-20423.47.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.354-t-20051.62-v-20457.66.hdf5',
# ...
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.911-t-21550.46-v-21465.74.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.912-t-21546.37-v-21734.53.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.913-t-21541.75-v-21739.01.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.914-t-21538.75-v-21533.37.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.915-t-21566.19-v-21794.98.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.916-t-21563.38-v-21754.04.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.917-t-21552.30-v-21669.50.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.918-t-21553.62-v-21613.33.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.919-t-21547.77-v-21658.71.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.92-t-15432.11-v-16621.15.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.920-t-21558.08-v-22067.21.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.921-t-21558.64-v-21680.15.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.922-t-21545.41-v-21597.16.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.923-t-21546.55-v-21584.34.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.924-t-21560.31-v-21527.28.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.925-t-21547.86-v-21536.19.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.926-t-21554.70-v-21667.65.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.927-t-21551.14-v-21790.29.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.928-t-21581.72-v-22029.50.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.929-t-21548.47-v-21706.08.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.93-t-15485.07-v-16921.21.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.930-t-21559.12-v-21862.38.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.931-t-21557.83-v-21706.87.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.932-t-21562.75-v-21786.75.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.933-t-21578.48-v-21631.58.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.934-t-21548.41-v-21605.09.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.935-t-21551.98-v-21865.05.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.936-t-21541.19-v-21778.69.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.937-t-21572.36-v-21736.10.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.938-t-21579.21-v-21688.91.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.939-t-21587.28-v-21704.27.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.94-t-15715.15-v-17161.65.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.940-t-21574.58-v-21645.14.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.941-t-21566.42-v-21436.96.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.942-t-21565.09-v-21666.30.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.943-t-21555.62-v-21752.53.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.944-t-21558.09-v-21709.84.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.945-t-21569.04-v-21781.00.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.946-t-21570.65-v-21547.56.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.947-t-21559.76-v-21723.11.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.948-t-21565.88-v-21635.53.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.949-t-21566.35-v-21454.78.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.95-t-15720.01-v-17320.62.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.950-t-21556.54-v-21884.66.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.951-t-21551.26-v-21770.99.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.952-t-21569.24-v-21756.55.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.953-t-21588.32-v-21645.97.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.954-t-21592.72-v-21937.96.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.955-t-21592.64-v-21773.67.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.956-t-21575.79-v-21551.69.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.957-t-21581.24-v-22057.58.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.958-t-21592.47-v-21858.03.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.959-t-21587.69-v-21690.65.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.96-t-15955.87-v-17268.98.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.960-t-21582.09-v-21735.42.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.961-t-21588.03-v-21970.74.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.962-t-21587.47-v-21936.51.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.963-t-21575.96-v-22090.04.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.964-t-21590.34-v-21780.79.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.965-t-21572.65-v-21653.60.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.966-t-21599.56-v-21771.07.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.967-t-21588.14-v-21768.21.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.968-t-21590.10-v-21683.32.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.969-t-21586.62-v-21587.24.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.97-t-16270.87-v-17758.31.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.970-t-21582.86-v-21677.24.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.971-t-21580.39-v-21818.13.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.972-t-21583.08-v-21821.65.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.973-t-21594.06-v-22057.90.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.974-t-21590.20-v-21893.70.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.975-t-21599.68-v-21797.82.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.976-t-21585.73-v-21627.28.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.977-t-21601.67-v-21984.66.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.978-t-21591.18-v-21457.19.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.979-t-21596.87-v-22103.28.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.98-t-16317.10-v-17812.37.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.980-t-21591.07-v-21774.29.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.981-t-21583.55-v-21609.94.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.982-t-21580.52-v-21775.99.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.983-t-21604.07-v-21852.34.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.984-t-21599.27-v-21777.04.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.985-t-21594.73-v-21578.73.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.986-t-21599.47-v-22042.85.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.987-t-21598.57-v-21769.40.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.988-t-21613.06-v-21688.52.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.989-t-21608.55-v-21720.30.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.99-t-16102.58-v-17479.92.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.990-t-21593.93-v-21987.31.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.991-t-21603.27-v-21882.17.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.992-t-21606.02-v-21749.65.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.993-t-21605.49-v-22073.40.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.994-t-21607.04-v-21538.36.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.995-t-21587.90-v-21620.12.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.996-t-21578.44-v-21688.62.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.997-t-21615.18-v-21676.11.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.998-t-21602.46-v-22060.26.hdf5',
#  '/home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.999-t-21621.52-v-21622.59.hdf5']

# %%
def extract_val_metric(fname):
    try:
        val_str = fname.split("-v-")[-1].replace(".hdf5", "")
        return float(val_str)
    except Exception:
        return float("-inf")

best_ckpt = None
best_val = float("-inf")

for f in checkpoint_files:
    val = extract_val_metric(os.path.basename(f))
    if val > best_val:
        best_val = val
        best_ckpt = f

print(f"Loading model from {best_ckpt}")
model.load_weights(best_ckpt)
# Out:
# Loading model from /home/das214/work/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-6505d613-checkpoints/checkpoints/weights.688-t-21385.50-v-22144.45.hdf5

# %%
plt.scatter(training_history['epoch'], training_history['loss'])
plt.scatter(training_history['epoch'], training_history['val_loss'])
plt.legend(['training', 'validation'])
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('NLL loss')
plt.tight_layout() 

plt.savefig(os.path.join(base_dir,'training_hist.png'))
plt.show()

# %%
sq_layer = model.get_layer(name="soft_quantizer_output")

current_k = sq_layer.k.numpy().item()
final_levels = sq_layer.levels.numpy()
final_thresholds = sq_layer.thresholds.numpy()

print(f"Current k: {current_k:.4f}")
print(f"Final Learned Levels: {final_levels}")
print(f"Final Learned Thresholds: {final_thresholds}")
print(f"- log_k: {sq_layer.log_k.numpy().item():.4f}")
print(f"- first_level: {sq_layer.first_level.numpy()}")
print(f"- log_level_deltas: {sq_layer.log_level_deltas.numpy()}")
print(f"- first_threshold: {list(sq_layer.first_threshold.numpy())}")
print(f"- log_threshold_deltas: {sq_layer.log_threshold_deltas.numpy()}")

x_input = tf.constant(np.linspace(-1.5, 1.5, 1000), dtype=tf.float32)
y_hard = sq_layer._hard_quantize(x_input, final_levels, final_thresholds)
y_soft = sq_layer._soft_quantize(x_input, current_k, final_levels, final_thresholds)

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(x_input, y_hard, color='crimson', linewidth=3, label='Hard Quantize (Inference)')
ax.plot(x_input, y_soft, color='royalblue', linestyle='-', linewidth=2, alpha=0.9, label='Soft Quantize (Training Approx.)')

ax.hlines(final_levels, xmin=-1.5, xmax=1.5, colors='green', linestyles='--', lw=1.5, alpha=0.9, label='Learned Levels')
ax.vlines(final_thresholds, ymin=-1.5, ymax=1.5, colors='purple', linestyles=':', lw=2, alpha=0.9, label='Learned Thresholds')
ax.plot(x_input, x_input, 'k--', alpha=0.4, lw=1, label='Identity ($y=x$)')

ax.set_title(f"Learned State of SoftQuantizeLayer (k = {current_k:.2f})", fontsize=16)
ax.set_xlabel("Input Value", fontsize=12)
ax.set_ylabel("Output Value", fontsize=12)
ax.legend(fontsize=11, loc='upper left')
ax.grid(True, linestyle='--', alpha=0.6)
ax.set_xlim(.5, 1.5)
ax.set_ylim(-1.5, 1.5)

plt.show()
# Out:
# Current k: 48.0780
# Final Learned Levels: [-1.         -0.3333333   0.33333337  1.        ]
# Final Learned Thresholds: [0.7327078  0.8046683  0.87692845]
# - log_k: 3.8728
# - first_level: [-1.]
# - log_level_deltas: [-0.40546507 -0.40546507 -0.4054652 ]
# - first_threshold: [0.7327078]
# - log_threshold_deltas: [-2.631638 -2.627483]

# %%
dataset_base_dir = "/depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/"

NOISE_MU = 0.0
NOISE_SIGMA = 400.0 # e-

tfrecords_base_dir = os.path.join(dataset_base_dir, "TFR_files", f"2t_N_{NOISE_MU}mu_{NOISE_SIGMA}sig")
tfrecords_dir_train = os.path.join(tfrecords_base_dir, "TFR_train")
tfrecords_dir_val   = os.path.join(tfrecords_base_dir, "TFR_val")

# %%
test_generator = OptimizedDataGenerator(
    load_from_tfrecords_dir= tfrecords_dir_val,
    shuffle=True,
    seed=42,
    quantize=True,
)
labels_scale = test_generator.labels_scale
print(labels_scale)
# Out:
# Loading metadata from /depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/TFR_files/2t_N_0.0mu_400.0sig/TFR_val/metadata.json
# WARNING:root:Quantization is True in data generator. This may affect model performance.
# [99.17029747 24.79370923  6.53245764  1.89031215]

# %%
def map_normalized_to_raw_charge(model, data_generator):
    """Map soft quantization thresholds & levels from normalized to raw charge space"""
    
    # Extract soft quantization parameters
    sq_layer = model.get_layer(name="soft_quantizer_output")
    thresholds = sq_layer.thresholds.numpy()
    
    # Get normalization parameters from data generator
    mu, sigma = data_generator.dataset_mean[0], data_generator.dataset_std[0] 
    s_pos, s_neg = data_generator.norm_factor_pos, data_generator.norm_factor_neg
    
    def reverse_transform(norm_vals):
        """Reverse the full normalization pipeline"""
        # Step 1: Reverse asymmetric scaling
        scaled_back = np.where(norm_vals > 0, norm_vals * s_pos, norm_vals * s_neg)
        
        # Step 2: Reverse standardization  
        log_vals = scaled_back * sigma + mu
        
        # Step 3: Reverse log compression: x_raw = sign(x_log) * (2^|x_log| - 1)
        raw_charges = np.sign(log_vals) * (2**np.abs(log_vals) - 1)
        
        return raw_charges
    
    # Apply reverse transformation
    raw_thresholds = reverse_transform(thresholds)

    print("QUANTIZATION THRESHOLDS:")
    for i, (norm, raw) in enumerate(zip(thresholds, raw_thresholds)):
        print(f"  Threshold {i+1}: {norm:8.3f} → {raw:10.1f}")

    print(f"\nNormalization params: μ={mu:.3f}, σ={sigma:.3f}, s+={s_pos:.3f}, s-={s_neg:.3f}")
    
    return raw_thresholds

# %%
raw_thresholds = map_normalized_to_raw_charge(model, test_generator)
# Out:
# QUANTIZATION THRESHOLDS:
#   Threshold 1:    0.733 →      609.1
#   Threshold 2:    0.805 →     1115.5
#   Threshold 3:    0.877 →     2047.5
#
# Normalization params: μ=0.374, σ=7.998, s+=1.515, s-=1.327

# %%
# predicts test data
p_test = model.predict(test_generator)
# Out:
# 21/21 [==============================] - 3s 72ms/step

# %%
complete_truth = None
for _, y in tqdm(test_generator):
        if complete_truth is None:
            complete_truth = y
        else:
            complete_truth = np.concatenate((complete_truth, y), axis=0)
# Out:
# 100%|██████████| 21/21 [00:01<00:00, 14.96it/s]

# %%
def softplus(x):
    x = np.asarray(x)
    return np.maximum(x, 0) + np.log1p(np.exp(-np.abs(x)))

# %%
# creates df with all predicted values and matrix elements - 4 predictions, all 10 unique matrix elements
df = pd.DataFrame(p_test,columns=['x','M11','y','M22','cotA','M33','cotB','M44','M21','M31','M32','M41','M42','M43'])

# stores all true values in same matrix as xtrue, ytrue, etc.
df['xtrue'] = complete_truth[:,0]
df['ytrue'] = complete_truth[:,1]
df['cotAtrue'] = complete_truth[:,2]
df['cotBtrue'] = complete_truth[:,3]
df['M11'] = minval+tf.math.maximum(df['M11'], 0)
df['M22'] = minval+tf.math.maximum(df['M22'], 0)
df['M33'] = minval+tf.math.maximum(df['M33'], 0)
df['M44'] = minval+tf.math.maximum(df['M44'], 0)

df['sigmax'] = abs(df['M11'])
df['sigmay'] = np.sqrt(df['M21']**2 + df['M22']**2)
df['sigmacotA'] = np.sqrt(df['M31']**2+df['M32']**2+df['M33']**2)
df['sigmacotB'] = np.sqrt(df['M41']**2+df['M42']**2+df['M43']**2+df['M44']**2)

# calculates residuals for x, y, cotA, cotB
residuals = df['xtrue'] - df['x']
residualsy = df['ytrue'] - df['y']
residualsA = df['cotAtrue'] - df['cotA']
residualsB = df['cotBtrue'] - df['cotB']

# stores results as csv
df.to_csv("test_4x4.csv",header=True,index=False)

# %% [markdown]
# # residuals (mean, stdv)

# %%
# x
(np.mean(residuals)*labels_scale[0],np.std(residuals)*labels_scale[0])
# Out:
# (1.7768264375681153, 11.47219381392085)

# %%
# y
(np.mean(residualsy)*labels_scale[1],np.std(residualsy)*labels_scale[1])
# Out:
# (-0.2807964888229534, 3.9002908629109583)

# %%
# cotA
(np.mean(residualsA)*labels_scale[2],np.std(residualsA)*labels_scale[2])
# Out:
# (-0.014478188515928032, 3.4251854504772195)

# %%
# cotB
(np.mean(residualsB)*labels_scale[3],np.std(residualsB)*labels_scale[3])
# Out:
# (-0.04194157770794991, 0.7746912561214018)

# %% [markdown]
# # x residuals

# %%
plt.hist(p_test[:,0],bins=np.linspace(-2,2,50))
plt.yscale('log')
plt.xlabel(r'$x$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residuals,bins=np.linspace(-1,1,50))
#plt.yscale('Log')
plt.xlabel(r'$x-\mu_x$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['xtrue'], y=(df['xtrue']-df['x']), x_bins=np.linspace(-1,1,50), fit_reg=None, marker='.')
plt.xlabel(r'True $x$ [um]')
plt.ylabel(r'$x-\mu_x$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # y residuals

# %%
plt.hist(p_test[:,2],bins=np.linspace(-1.5,1.5,50))
plt.yscale('log')
plt.xlabel(r'$y$ [um]')

save_fig_path = os.path.join(plot_dir, 'y_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residualsy,bins=np.linspace(-1,1,50))
#plt.yscale('Log')
plt.xlabel(r'$y-\mu_y$ [um]')

save_fig_path = os.path.join(plot_dir, 'y_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['ytrue'], y=(df['ytrue']-df['y']), x_bins=np.linspace(-1,1,50), fit_reg=None, marker='.')
plt.xlabel(r'True $y$ [um]')
plt.ylabel(r'$y-\mu_y$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # cotA residuals

# %%
plt.hist(df["cotA"],bins=np.linspace(-1.25,1.25,50))
plt.yscale('log')
plt.xlabel(r'$cotA$')

save_fig_path = os.path.join(plot_dir, 'cotA_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residualsA,bins=np.linspace(-0.5,0.5,50))
#plt.yscale('Log')
plt.xlabel(r'$cotA-\mu_{cotA}$')

save_fig_path = os.path.join(plot_dir, 'cotA_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['cotAtrue']*labels_scale[2], y=(df['cotAtrue']-df['cotA'])*labels_scale[2], x_bins=np.linspace(-labels_scale[2],labels_scale[2],50), fit_reg=None, marker='.')
plt.xlabel(r'True $cotA$ [um]')
plt.ylabel(r'$cotA-\mu_{cotA}$ [um]')

save_fig_path = os.path.join(plot_dir, 'cotA_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # cotB residuals

# %%
plt.hist(df["cotB"]*labels_scale[3],bins=np.linspace(-labels_scale[3],labels_scale[3],50))
#plt.yscale('Log')
plt.xlabel(r'$cotB$')

save_fig_path = os.path.join(plot_dir, 'cotB_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residualsB*labels_scale[3],bins=np.linspace(-labels_scale[3],labels_scale[3],50))
#plt.yscale('Log')
plt.xlabel(r'$cotB-\mu_{cotB}$')

save_fig_path = os.path.join(plot_dir, 'cotB_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['cotBtrue']*labels_scale[3], y=(df['cotBtrue']-df['cotB'])*labels_scale[3], x_bins=np.linspace(-labels_scale[3],labels_scale[3],100), fit_reg=None, marker='.')
plt.xlabel(r'True $cotB$')
plt.ylabel(r'$cotB-\mu_{cotB} $')

save_fig_path = os.path.join(plot_dir, 'cotB_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # pull

# %%
df['pullx'] = (df['xtrue']-df['x'])/df['sigmax']
df['pully'] = (df['ytrue']-df['y'])/df['sigmay']
df['pullcotA'] = (df['cotAtrue']-df['cotA'])/df['sigmacotA']
df['pullcotB'] = (df['cotBtrue']-df['cotB'])/df['sigmacotB']

# %%
plt.hist(df['sigmax'] *labels_scale[0],bins=np.linspace(0,35,50))
plt.xlabel('$\sigma_{x}$')
plt.yscale('log')

# %%
plt.hist(df['sigmay']*labels_scale[1],bins=np.linspace(0,6,50))
plt.xlabel('$\sigma_{y}$')
plt.yscale('log')

# %%
plt.hist(df['sigmacotA'] *labels_scale[2],bins=np.linspace(0,1.0,50))
plt.xlabel('$\sigma_{cotA}$')
plt.yscale('log')

# %%
plt.hist(df['sigmacotB'] *labels_scale[3] ,bins=np.linspace(0,0.6,50))
plt.xlabel('$\sigma_{cotB}$')
plt.yscale('log')

# %%
from scipy.optimize import curve_fit

def gauss(x, A, mu, sigma):
    return A * np.exp(-(x - mu) ** 2 / (2 * sigma ** 2))

def pull_plot(ax, var, name):
    
    h = ax.hist(df[var],bins=np.linspace(-5,5,50),histtype='step')
    ax.set_xlabel(name)
    ax.set_yscale('log')

    ydata = h[0]
    xdata = h[1][:-1]+3/50.

    pars, cov = curve_fit(gauss,xdata,ydata)

    xbins = np.linspace(-5,5,100)
    ax.plot(xbins,gauss(xbins,pars[0],pars[1],pars[2]),color='black')
    ax.set_ylim(0.5,100000)

    print('Mean',pars[1])
    print('Sigma',pars[2])
    
    ax.text(-5,2000,"$\mu$="+str(round(pars[1],2)))
    ax.text(-5,1000,"$\sigma$="+str(round(abs(pars[2]),2)))

# %% [markdown]
# # Pull Plot

# %%
fig, axes = plt.subplots(2,2,sharex=True,sharey=True,figsize=(8,6))
pull_plot(axes[0][0],'pullx',r'$x$ pull')
pull_plot(axes[0][1],'pully',r'$y$ pull')
pull_plot(axes[1][0],'pullcotA',r'$\cot\alpha$ pull')
pull_plot(axes[1][1],'pullcotB',r'$\cot\beta$ pull')

save_fig_path = os.path.join(plot_dir, 'Pull.png')
plt.savefig(save_fig_path)

plt.show()
# Out:
# Mean 0.11166728201944223
# Sigma 1.104636799299779
# Mean -0.05217865874228065
# Sigma 0.9890945481801929
# Mean -0.05210939860549926
# Sigma -1.3690177332218114
# Mean -0.11783743625086439
# Sigma -1.2942068287939397

# %% [markdown]
# # Summary

# %%
def residual_plot(ax, thisdf, var1, var2, name, scaling=1.0):
    
    nbins = 15
    
    var1_scaled = thisdf[var1] * scaling
    var2_scaled = thisdf[var2] * scaling
    residual_scaled = var1_scaled - var2_scaled
    
    xmin = np.min(var1_scaled)
    xmax = np.max(var1_scaled)
    
    step = 1.0*(xmax-xmin)/nbins
    
    x = sns.regplot(x=var1_scaled, y=residual_scaled, x_bins=np.linspace(xmin,xmax,nbins), fit_reg=None, marker='.', ax=ax)
    ax.set_xlabel('True ' + name)
    ax.set_ylabel('True - predicted ' + name)
    
    thisdf['residual'+var2] = residual_scaled
    print(var1)
    
    means = []
    upbar = []
    downbar = []
    for i in range(0,nbins):
        means += [np.mean(thisdf['residual'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)])]
        upbar += [means[i] + np.mean(thisdf['sigma'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)] * scaling)]
        downbar += [means[i] - np.mean(thisdf['sigma'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)] * scaling)]
    ax.fill_between(x=np.linspace(xmin,xmax,nbins),y1=upbar,y2=downbar, alpha=0.2)

def inverse_cot(cota):
    a = np.arctan(1.0/cota)
    a[np.where(a<0)] = a[np.where(a<0)] + pi
    return a    

def residual_plot_deg(ax, thisdf, var1, var2, name, scaling=1.0):
    # positions
    if 'cot' not in var1:
        residual_plot(ax, thisdf, var1, var2, name, scaling=scaling)
        return

    thisdf['angle'] = inverse_cot(thisdf[var2].values * scaling)*180/pi
    
    thisdf['angleup'] = abs(inverse_cot((thisdf[var2].values + thisdf['sigma'+var2].values) * scaling)*180/pi - thisdf['angle'])
    thisdf['angledown'] = abs(inverse_cot((thisdf[var2].values - thisdf['sigma'+var2].values) * scaling)*180/pi - thisdf['angle'])
    thisdf['angletrue'] = inverse_cot(thisdf[var1].values * scaling)*180/pi
        
    var1 = 'angletrue'
    var2 = 'angle'
    
    nbins = 15
    xmin = np.min(thisdf[var1])
    xmax = np.max(thisdf[var1])
    
    step = 1.0*(xmax-xmin)/nbins
        
    x = sns.regplot(x=thisdf[var1], y=(thisdf[var1]-thisdf[var2]), x_bins=np.linspace(xmin,xmax,nbins), fit_reg=None, marker='.', ax=ax)
    ax.set_xlabel('True ' + name)
    ax.set_ylabel('True - predicted ' + name)
    
    thisdf['residual'+var2] = (thisdf[var1]-thisdf[var2])
    print(var1)
    
    means = []    
    upbar = []
    downbar = []
    for i in range(0,nbins):
        means += [np.mean(thisdf['residual'+var2][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
        upbar += [means[i] + np.mean(thisdf['angleup'][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
        downbar += [means[i] - np.mean(thisdf['angledown'][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
    #ax.scatter(x=np.linspace(xmin,xmax,nbins),y=means)
    ax.fill_between(x=np.linspace(xmin,xmax,nbins),y1=upbar,y2=downbar, alpha=0.2)

# %% [markdown]
# # Summary Plot

# %%
fig, axes = plt.subplots(2,2,figsize=(8,6))
fig.tight_layout(pad=4.0)
residual_plot(axes[0][0],df,'xtrue','x',r'$x$ [um]', scaling=labels_scale[0])
axes[0][0].plot([-25,-25],[-10,10],color='gray',linestyle=':')
axes[0][0].plot([25,25],[-10,10],color='gray',linestyle=':')
residual_plot(axes[0][1],df,'ytrue','y',r'$y$ [um]', scaling=labels_scale[1])
axes[0][1].plot([-6.25,-6.25],[-2,2],color='gray',linestyle=':')
axes[0][1].plot([6.25,6.25],[-2,2],color='gray',linestyle=':')
residual_plot_deg(axes[1][0],df,'cotAtrue','cotA',r'$\alpha$ [deg]', scaling=labels_scale[2])
axes[1][0].plot([90,90],[-10,10],color='gray',linestyle=':')
residual_plot_deg(axes[1][1],df,'cotBtrue','cotB',r'$\beta$ [deg]', scaling=labels_scale[3])
axes[1][1].plot([90,90],[-10,10],color='gray',linestyle=':')

save_fig_path = os.path.join(plot_dir, 'summary.png')
plt.savefig(save_fig_path)
# Out:
# xtrue
# ytrue
# angletrue
# angletrue

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 os.chdir('/home/das214/SmartPix/SoftQuantize')
#       2 get_ipython().system('pwd')
#
# NameError: name 'os' is not defined
