# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.optimize import curve_fit

# %%
model='mlp_SLIM'
ts=2

# %%
df_1 = pd.read_parquet(f'/work/projects/SmartPixML/dataset_3s_10ps_50x12P5/trained_models/model-c2b6dd60-checkpoints/2t_Conv2D_10ps_Charge.parquet')
df_2 = pd.read_parquet(f'/work/projects/SmartPixML/preamp_response/TrainedModels/model-c6103ed3-checkpoints/2t_Conv2D_preamp_response.parquet')

# %% [markdown]
# ### Residuals + Uncertainties Comparison

# %%
def residual_plot(ax, thisdf, var1, var2, name, color, label=None, scaling=1.0, alpha=0.2, slim=False, edgecolor=None, hatch=None):
    
    nbins = 50
    
    var1_scaled = thisdf[var1] * scaling
    var2_scaled = thisdf[var2] * scaling
    residual_scaled = var1_scaled - var2_scaled
    
    xmin = np.min(var1_scaled)
    xmax = np.max(var1_scaled)
    
    step = 1.0*(xmax-xmin)/nbins
    
    x = sns.regplot(x=var1_scaled, y=residual_scaled, x_bins=np.linspace(xmin,xmax,nbins), fit_reg=None, marker='.', ax=ax, color=color, label=label)
    ax.set_xlabel('True ' + name)
    ax.set_ylabel('True - predicted ' + name)
    
    thisdf['residual'+var2] = residual_scaled
    print(var1)
    
    means = []
    upbar = []
    downbar = []
    for i in range(0,nbins):
        means += [np.mean(thisdf['residual'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)])]
        if slim == False:
            upbar += [means[i] + np.mean(thisdf['sigma'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)] * scaling)]
            downbar += [means[i] - np.mean(thisdf['sigma'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)] * scaling)]
    if slim == False:
        ax.fill_between(x=np.linspace(xmin,xmax,nbins),y1=upbar,y2=downbar, alpha=alpha, color=color, edgecolor=edgecolor, hatch=hatch)

pi = 3.14159265359

def inverse_cot(cota):
    a = np.arctan(1.0/cota)
    a[np.where(a<0)] = a[np.where(a<0)] + pi
    return a    

def residual_plot_deg(ax, thisdf, var1, var2, name, color, label=None, scaling=1.0, alpha=0.2, slim=False, edgecolor=None, hatch=None):
    # positions
    if 'cot' not in var1:
        residual_plot(ax, thisdf, var1, var2, name, scaling=scaling)
        return

    thisdf['angle'] = inverse_cot(thisdf[var2].values * scaling)*180/pi

    if slim == False:
        thisdf['angleup'] = abs(inverse_cot((thisdf[var2].values + thisdf['sigma'+var2].values) * scaling)*180/pi - thisdf['angle'])
        thisdf['angledown'] = abs(inverse_cot((thisdf[var2].values - thisdf['sigma'+var2].values) * scaling)*180/pi - thisdf['angle'])
    thisdf['angletrue'] = inverse_cot(thisdf[var1].values * scaling)*180/pi
        
    var1 = 'angletrue'
    var2 = 'angle'
    
    nbins = 50
    xmin = np.min(thisdf[var1])
    xmax = np.max(thisdf[var1])
    
    step = 1.0*(xmax-xmin)/nbins
        
    x = sns.regplot(x=thisdf[var1], y=(thisdf[var1]-thisdf[var2]), x_bins=np.linspace(xmin,xmax,nbins), fit_reg=None, marker='.', ax=ax, color=color, label=label)
    ax.set_xlabel('True ' + name)
    ax.set_ylabel('True - predicted ' + name)
    
    thisdf['residual'+var2] = (thisdf[var1]-thisdf[var2])
    print(var1)
    
    means = []    
    upbar = []
    downbar = []
    for i in range(0,nbins):
        means += [np.mean(thisdf['residual'+var2][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
        if slim == False:
            upbar += [means[i] + np.mean(thisdf['angleup'][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
            downbar += [means[i] - np.mean(thisdf['angledown'][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
    if slim == False:
        ax.fill_between(x=np.linspace(xmin,xmax,nbins),y1=upbar,y2=downbar, alpha=alpha, color=color, edgecolor=edgecolor, hatch=hatch)

# %% [markdown]
# ### Residuals vs Truth

# %%
fig, ax = plt.subplots(2,2, figsize=(15,10))

residual_plot(ax[0,0], df_1, 'xtrue', 'x', label='10ps_Charge', name=r'$x$ $[\mu m]$', edgecolor='red', color='red', scaling=122.89689703635774)
residual_plot(ax[0,0], df_2, 'xtrue', 'x', label='preamp_response', name=r'$x$ $[\mu m]$', edgecolor='blue', color='blue', hatch='x', scaling=122.89689703635774)

ax[0,0].axhline(alpha=0.4, ls='dashed')
ax[0,0].set_title(r'$x$ residuals + uncertainties')
ax[0,0].legend(loc='upper left')

residual_plot(ax[0,1], df_1, 'ytrue', 'y', label='10ps_Charge', name=r'$y$ $[\mu m]$', edgecolor='red', color='red', scaling=30.903849401109394)
residual_plot(ax[0,1], df_2, 'ytrue', 'y', label='preamp_response', name=r'$y$ $[\mu m]$', edgecolor='blue', color='blue', hatch='x', scaling=30.903849401109394)

ax[0,1].axhline(alpha=0.4, ls='dashed')
ax[0,1].set_title(r'$y$ residuals + uncertainties')
ax[0,1].legend(loc='upper left')

residual_plot_deg(ax[1,0], df_1, 'cotAtrue', 'cotA', label='10ps_Charge', name=r'$\alpha$ $[deg]$', edgecolor='red', color='red', scaling=6.560914919886437)
residual_plot_deg(ax[1,0], df_2, 'cotAtrue', 'cotA', label='preamp_response', name=r'$\alpha$ $[deg]$', edgecolor='blue', color='blue', hatch='x', scaling=6.560914919886437)

ax[1,0].axhline(alpha=0.4, ls='dashed')
ax[1,0].set_title(r'$\alpha$ residuals + uncertainties')
ax[1,0].legend(loc='upper left')

residual_plot_deg(ax[1,1], df_1, 'cotBtrue', 'cotB', label='10ps_Charge', name=r'$\beta$ $[deg]$', edgecolor='red', color='red', scaling=1.917222249583349)
residual_plot_deg(ax[1,1], df_2, 'cotBtrue', 'cotB', label='preamp_response', name=r'$\beta$ $[deg]$', edgecolor='blue', color='blue', hatch='x', scaling=1.917222249583349)

ax[1,1].axhline(alpha=0.4, ls='dashed')
ax[1,1].set_title(r'$\beta$ residuals + uncertainties')
ax[1,1].legend(loc='lower right')

fig.tight_layout(pad=1.0)
#fig.legend(title=f'{model}', loc='upper center', ncol=7, bbox_to_anchor=(0.5, 1.03))
fig.savefig(f'/work/projects/SmartPixML/pre_post_preamp_performance_comparison_uncertainity_band.png',  bbox_inches='tight', dpi=300)
fig.show()
# Out:
# xtrue
# xtrue
# ytrue
# ytrue
# /tmp/ipykernel_1263/3791090096.py:35: RuntimeWarning: divide by zero encountered in divide
#   a = np.arctan(1.0/cota)
# angletrue
# angletrue
# angletrue
# angletrue

# %%
fig, ax = plt.subplots(1,3, figsize=(20,6))

residual_plot(ax[0], df_1, 'xtrue', 'x', label='10ps_Charge', name=r'$x$ $[\mu m]$', color='red', scaling=122.89689703635774, slim=True)
residual_plot(ax[0], df_2, 'xtrue', 'x', label='preamp_response', name=r'$x$ $[\mu m]$', color='blue', scaling=122.89689703635774, slim=True)

ax[0].axhline(alpha=0.4, ls='dashed')
#ax[0].set_title(r'$x$ residuals + uncertainties')
ax[0].legend(loc='upper left')

residual_plot(ax[1], df_1, 'ytrue', 'y', label='10ps_Charge', name=r'$y$ $[\mu m]$', color='red', scaling=30.903849401109394, slim=True)
residual_plot(ax[1], df_2, 'ytrue', 'y', label='preamp_response', name=r'$y$ $[\mu m]$', color='blue', scaling=30.903849401109394, slim=True)

ax[1].axhline(alpha=0.4, ls='dashed')
#ax[1].set_title(r'$y$ residuals + uncertainties')
ax[1].legend(loc='upper left')

residual_plot_deg(ax[2], df_1, 'cotBtrue', 'cotB', label='10ps_Charge', name=r'$\beta$ $[deg]$', color='red', scaling=1.917222249583349, slim=True)
residual_plot_deg(ax[2], df_2, 'cotBtrue', 'cotB', label='preamp_response', name=r'$\beta$ $[deg]$', color='blue', scaling=1.917222249583349, slim=True)

ax[2].axhline(alpha=0.4, ls='dashed')
#ax[2].set_title(r'$\beta$ residuals + uncertainties')
ax[2].legend(loc='best')

fig.tight_layout(pad=1.0)
#fig.legend(framealpha=1, loc='upper center')
#fig.legend(loc='upper center', ncol=7, bbox_to_anchor=(0.5, 1.08))
fig.savefig(f'/work/projects/SmartPixML/pre_post_preamp_performance_comparison_predi_vs_truth.png',  bbox_inches='tight', dpi=300)
fig.show()
# Out:
# xtrue
# xtrue
# ytrue
# ytrue
# /tmp/ipykernel_1263/3791090096.py:35: RuntimeWarning: divide by zero encountered in divide
#   a = np.arctan(1.0/cota)
# angletrue
# angletrue

# %%
df_1 = pd.read_parquet(f'/home/dajiang/smart-pixels-ml/processed_parquets/dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/test_dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/soft-quantizer/2t-conv2d_MAX-offsets-soft_quantizer-vars.parquet')
df_2 = pd.read_parquet(f'/home/dajiang/smart-pixels-ml/processed_parquets/dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/test_dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/soft-quantizer/2t-conv2d_FULL-offsets-soft_quantizer-vars.parquet')
df_3 = pd.read_parquet(f'/home/dajiang/smart-pixels-ml/processed_parquets/dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/test_dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/soft-quantizer/2t-mlp_FULL-offsets-soft_quantizer-vars.parquet')
df_4 = pd.read_parquet(f'/home/dajiang/smart-pixels-ml/processed_parquets/dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/test_dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/soft-quantizer/2t-mlp_SLIM-offsets-soft_quantizer-vars.parquet')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_1 = pd.read_parquet(f'/home/dajiang/smart-pixels-ml/processed_parquets/dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/test_dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/soft-quantizer/2t-conv2d_MAX-offsets-soft_quantizer-vars.parquet')
#       2 df_2 = pd.read_parquet(f'/home/dajiang/smart-pixels-ml/processed_parquets/dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/test_dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/soft-quantizer/2t-conv2d_FULL-offsets-soft_quantizer-vars.parquet')
#       3 df_3 = pd.read_parquet(f'/home/dajiang/smart-pixels-ml/processed_parquets/dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/test_dataset_3src_16x16_50x12P5_centeredIncidence_-8_8_offsets/soft-quantizer/2t-mlp_FULL-offsets-soft_quantizer-vars.parquet')
#
# ...

# %%
fig, ax = plt.subplots(2,2, figsize=(15,10))

residual_plot(ax[0,0], df_1, 'xtrue', 'x', label='conv2d-MAX (2bit input, 2t)', name=r'$x$ $[\mu m]$', edgecolor='red', color='red', scaling=494.15916009040166)
residual_plot(ax[0,0], df_2, 'xtrue', 'x', label='conv2d-FULL (2bit input, 2t)', name=r'$x$ $[\mu m]$', edgecolor='turquoise', color='turquoise', scaling=494.15916009040166)
residual_plot(ax[0,0], df_3, 'xtrue', 'x', label='mlp-FULL (2bit input, 2t)', name=r'$x$ $[\mu m]$', edgecolor='purple', color='purple', scaling=494.15916009040166)
residual_plot(ax[0,0], df_4, 'xtrue', 'x', label='mlp-SLIM (2bit input, 2t)', name=r'$x$ $[\mu m]$', color='gold', slim=True, scaling=494.15916009040166)
ax[0,0].axhline(alpha=0.4, ls='dashed')
ax[0,0].set_title(r'$x$ residuals + uncertainties')
ax[0,0].legend(loc='upper left')

residual_plot(ax[0,1], df_1, 'ytrue', 'y', label='conv2d-MAX (2bit input, 2t)', name=r'$y$ $[\mu m]$', edgecolor='red', color='red', scaling=125.57998303417061)
residual_plot(ax[0,1], df_2, 'ytrue', 'y', label='conv2d-FULL (2bit input, 2t)', name=r'$y$ $[\mu m]$', edgecolor='turquoise', color='turquoise', scaling=125.57998303417061)
residual_plot(ax[0,1], df_3, 'ytrue', 'y', label='mlp-FULL (2bit input, 2t)', name=r'$y$ $[\mu m]$', edgecolor='purple', color='purple', scaling=125.57998303417061)
residual_plot(ax[0,1], df_4, 'ytrue', 'y', label='mlp-SLIM (2bit input, 2t)', name=r'$y$ $[\mu m]$', color='gold', slim=True, scaling=125.57998303417061)

ax[0,1].axhline(alpha=0.4, ls='dashed')
ax[0,1].set_title(r'$y$ residuals + uncertainties')
ax[0,1].legend(loc='upper left')

residual_plot_deg(ax[1,0], df_1, 'cotAtrue', 'cotA', label='conv2d-MAX (2bit input, 2t)', name=r'$\alpha$ $[deg]$', edgecolor='red', color='red', scaling=6.568557775061244)
residual_plot_deg(ax[1,0], df_2, 'cotAtrue', 'cotA', label='conv2d-FULL (2bit input, 2t)', name=r'$\alpha$ $[deg]$', edgecolor='turquoise', color='turquoise', scaling=6.568557775061244)
residual_plot_deg(ax[1,0], df_3, 'cotAtrue', 'cotA', label='mlp-FULL (2bit input, 2t)', name=r'$\alpha$ $[deg]$', edgecolor='purple', color='purple', scaling=6.568557775061244)

ax[1,0].axhline(alpha=0.4, ls='dashed')
ax[1,0].set_title(r'$\alpha$ residuals + uncertainties')
ax[1,0].legend(loc='upper left')

residual_plot_deg(ax[1,1], df_1, 'cotBtrue', 'cotB', label='conv2d-MAX (2bit input, 2t)', name=r'$\beta$ $[deg]$', edgecolor='red', color='red', scaling=1.9172254478684552)
residual_plot_deg(ax[1,1], df_2, 'cotBtrue', 'cotB', label='conv2d-FULL (2bit input, 2t)', name=r'$\beta$ $[deg]$', edgecolor='turquoise', color='turquoise', scaling=1.9172254478684552)
residual_plot_deg(ax[1,1], df_3, 'cotBtrue', 'cotB', label='mlp-FULL (2bit input, 2t)', name=r'$\beta$ $[deg]$', edgecolor='purple', color='purple', scaling=1.9172254478684552)
residual_plot_deg(ax[1,1], df_4, 'cotBtrue', 'cotB', label='mlp-SLIM (2bit input, 2t)', name=r'$\beta$ $[deg]$', color='gold', slim=True, scaling=1.9172254478684552)
ax[1,1].axhline(alpha=0.4, ls='dashed')
ax[1,1].set_title(r'$\beta$ residuals + uncertainties')
ax[1,1].legend(loc='lower right')

fig.tight_layout(pad=1.0)
#fig.legend(title='Sensor Geometry [$\mu m^3$]', loc='upper center', ncol=7, bbox_to_anchor=(0.5, 1.03))
#fig.savefig(f'plots/performance/residuals_vs_truth-{ts}t-4_comparison.png',  bbox_inches='tight', dpi=300)
fig.show()
# Out:
# xtrue
# xtrue
# xtrue
# xtrue
# ytrue
# ytrue
# ytrue
# ytrue
# angletrue
# angletrue
# angletrue
# angletrue
# angletrue
# angletrue
# angletrue

# %%
def gauss(x, A, mu, sigma):
    return A * np.exp(-(x - mu) ** 2 / (2 * sigma ** 2))

def pull_plot(ax, data, name, color, label=None,):
    
    h = ax.hist(data, bins=np.linspace(-20,20,100), histtype='step', label=label, color=color)
    ax.legend(loc='upper right')
    ax.set_xlabel(name)
    ax.set_yscale('log')
    ax.axvline(alpha=0.3, ls='dashed')

    ydata = h[0]
    xdata = h[1][:-1]+5/49

    pars, cov = curve_fit(gauss,xdata,ydata,maxfev=5000)

    xbins = np.linspace(-20,20,100)
    ax.plot(xbins,gauss(xbins,pars[0],pars[1],pars[2]),color='black')
    ax.set_ylim(0.5,1000000)

    print('Mean',pars[1])
    print('Sigma',pars[2])
    
    ax.text(-7,11000,r"$\mu$="+str(round(pars[1],2)))
    ax.text(3,11000,r"$\sigma$="+str(round(abs(pars[2]),2)))

# %%
fig, axes = plt.subplots(2,2, figsize=(15,10))
pull_plot(axes[0,0], df_3['residualsx']/df_3['sigmax'], label=f'{ts}t', name='x pull', color='green')
pull_plot(axes[0,1], df_3['residualsy']/df_3['sigmay'], label=f'{ts}t', name='y pull', color='green')
pull_plot(axes[1,0], df_3['residualscotA']/df_3['sigmacotA'], label=f'{ts}t', name='cotA pull', color='green')
pull_plot(axes[1,1], df_3['residualscotB']/df_3['sigmacotB'], label=f'{ts}t', name='cotB pull', color='green')

#fig.suptitle(f'Pull Distributions ({ts}t, {model})')
fig.suptitle(f'Pull Distributions (20t, {model})')
fig.tight_layout()
#fig.savefig(f'plots/performance/pulls-{ts}t-{model}.png', dpi=300)
# Out:
# Mean -0.12582000200275717
# Sigma -1.0617013313826744
# Mean -0.17054690567224173
# Sigma -0.903293361826911
# Mean -0.08902031626462731
# Sigma 1.0632569096226148
# Mean -0.10425332773751615
# Sigma -0.9381665593133117

# %%
a = df_3['residualsx']/df_3['sigmax']
print(min(a))
print(max(a))
# Out:
# -10.695425033569336
# 12.55582332611084
