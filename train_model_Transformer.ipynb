# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
import keras
from keras.models import Sequential, Model
from keras.layers import *
from keras.utils import Sequence
from keras.layers import Conv2D, MaxPooling2D
from qkeras import *

from keras.utils import Sequence
from keras.callbacks import CSVLogger
from keras.callbacks import EarlyStopping

import os
import random
from datetime import datetime
import time

import matplotlib.pyplot as plt

pi = 3.14159265359
maxval=1e9
minval=1e-9
# Out:
# 2025-09-14 03:55:19.235704: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-09-14 03:55:19.235792: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-09-14 03:55:19.516324: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-09-14 03:55:20.093853: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-14 03:55:32.537795: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# # # os.chdir('SmartPix/data_generator')
# os.chdir('/home/das214/SmartPix/SoftQuantize')
# !pwd

# %%
from DG.OptimizedDataGenerator_v2 import OptimizedDataGenerator
from losses.loss import custom_loss
from models.SoftQuantizeLayer import SoftQuantizeLayer
from models.AnnealingScheduler import AnnealingScheduler
# from models.models import CreateModel # Conv2D model

# %%
# Trasformer model

class PatchExtractor(layers.Layer):
  """Extract 2D patches from images."""
  def __init__(self, patch_size=(3,7)):
    super().__init__()
    self.patch_size = patch_size

  def call(self, images):
    # images: (batch, H, W, C)
    patch_h, patch_w = self.patch_size
    batch_size = tf.shape(images)[0]
    patches = tf.image.extract_patches(
        images=images,
        sizes=(1, patch_h, patch_w, 1),
        strides=(1, patch_h, patch_w, 1),
        rates=(1,1,1,1),
        padding='VALID'
    )
    # Now `patches` has shape: 
    #   (batch, H//patch_h, W//patch_w, patch_h*patch_w*C)
    # Flatten the 2D grid of patches => (batch, num_patches, patch_dim)
    patch_dims = tf.shape(patches)[-1]
    patches = tf.reshape(
        patches,
        [batch_size, -1, patch_dims]
    )
    return patches

class PatchEncoder(layers.Layer):
  """Linear embedding + learnable positional encoding."""
  def __init__(self, num_patches, embed_dim):
    super().__init__()
    self.num_patches = num_patches
    self.projection  = layers.Dense(embed_dim)
    self.pos_embed   = tf.Variable(
        initial_value=tf.zeros((1,num_patches,embed_dim)),
        trainable=True,
        name="pos_embedding"
    )

  def call(self, patch_batch):
    # Linear projection of patch tokens
    projected = self.projection(patch_batch)
    # Add learnable positional embeddings
    return projected + self.pos_embed

def transformer_encoder(inputs,
                        head_size,
                        num_heads,
                        ff_dim,
                        dropout=0.1):
  # LayerNorm + Multi-head attention
  x = layers.LayerNormalization(epsilon=1e-6)(inputs)
  x = layers.MultiHeadAttention(num_heads=num_heads,
                                key_dim=head_size,
                                dropout=dropout)(x, x)
  x = layers.Dropout(dropout)(x)
  res = x + inputs
  
  # Next LN + feed-forward
  x = layers.LayerNormalization(epsilon=1e-6)(res)
  x = layers.Dense(ff_dim, activation="relu")(x)
  x = layers.Dropout(dropout)(x)
  x = layers.Dense(inputs.shape[-1], activation="linear")(x)
  x = layers.Dropout(dropout)(x)
  
  return x + res

def create_vit_model(input_shape=(13,21,2),
                     patch_size=(3,7),
                     embed_dim=64,
                     num_heads=4,
                     ff_dim=128,
                     num_layers=4,
                     dropout=0.1,
                     final_outputs=14):
  # Input
  inp = layers.Input(shape=input_shape, name="raw_input")

  q_out = SoftQuantizeLayer(
      n_bits=2,
      initial_range=[-1.0, 1.0],
      trainable_levels=False,
      trainable_thresholds=True,
      initial_k=1.0,
      trainable_k=True,
      name="soft_quantizer_output"
  )(inp)

  # 1) Extract patches
  patches = PatchExtractor(patch_size=patch_size)(q_out)
  
  # Calculate how many patches we extracted:
  #   (H // patch_h) * (W // patch_w)
  # Must do it statically if possible:
  # e.g. 13//3=4, 21//7=3 => 12 patches total
  H, W, C = input_shape
  ph, pw  = patch_size
  num_patches = (H // ph) * (W // pw)

  # 2) Encode patches (linear projection + positional embedding)
  encoded_patches = PatchEncoder(num_patches, embed_dim)(patches)

  # 3) Apply multiple Transformer encoder blocks
  x = encoded_patches
  for _ in range(num_layers):
    x = transformer_encoder(x,
                            head_size=embed_dim,
                            num_heads=num_heads,
                            ff_dim=ff_dim,
                            dropout=dropout)
  
  # 4) Flatten and final Dense
  x = layers.LayerNormalization(epsilon=1e-6)(x)
  x = layers.Flatten()(x)
  x = layers.Dense(64, activation='relu')(x)
  outputs = layers.Dense(final_outputs, activation='linear')(x)

  # Create model
  model = keras.Model(inputs=inp, outputs=outputs)
  return model

model = create_vit_model(
    input_shape=(16,16,2),   
    patch_size=(3,4),        
    embed_dim=64,           
    num_heads=4,            
    ff_dim=128,              
    num_layers=4,            
    dropout=0.1,             
    final_outputs=14         
)


model.summary()
# Out:
# 2025-09-14 03:56:13.489962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38397 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB MIG 7g.40gb, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2025-09-14 03:56:14.064921: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  raw_input (InputLayer)      [(None, 16, 16, 2)]          0         []
#
#  soft_quantizer_output (Sof  (None, 16, 16, 2)            8         ['raw_input[0][0]']
#  tQuantizeLayer)
#
#  patch_extractor (PatchExtr  (None, None, 24)             0         ['soft_quantizer_output[0][0]'
#  actor)                                                             ]
#
#  patch_encoder (PatchEncode  (None, 20, 64)               2880      ['patch_extractor[0][0]']
#  r)
#
#  layer_normalization (Layer  (None, 20, 64)               128       ['patch_encoder[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 20, 64)               66368     ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  dropout (Dropout)           (None, 20, 64)               0         ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOp  (None, 20, 64)               0         ['dropout[0][0]',
#  Lambda)                                                             'patch_encoder[0][0]']
#
#  layer_normalization_1 (Lay  (None, 20, 64)               128       ['tf.__operators__.add[0][0]']
#  erNormalization)
#
#  dense_1 (Dense)             (None, 20, 128)              8320      ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 20, 128)              0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 20, 64)               8256      ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 20, 64)               0         ['dense_2[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 20, 64)               0         ['dropout_2[0][0]',
#  OpLambda)                                                           'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_1[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_1 (Mu  (None, 20, 64)               66368     ['layer_normalization_2[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_2[0][0]
#                                                                     ']
#
#  dropout_3 (Dropout)         (None, 20, 64)               0         ['multi_head_attention_1[0][0]
#                                                                     ']
#
#  tf.__operators__.add_2 (TF  (None, 20, 64)               0         ['dropout_3[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  layer_normalization_3 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_2[0][0]
#  erNormalization)                                                   ']
#
#  dense_3 (Dense)             (None, 20, 128)              8320      ['layer_normalization_3[0][0]'
#                                                                     ]
#
#  dropout_4 (Dropout)         (None, 20, 128)              0         ['dense_3[0][0]']
#
#  dense_4 (Dense)             (None, 20, 64)               8256      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 20, 64)               0         ['dense_4[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 20, 64)               0         ['dropout_5[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  layer_normalization_4 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_3[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_2 (Mu  (None, 20, 64)               66368     ['layer_normalization_4[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 20, 64)               0         ['multi_head_attention_2[0][0]
#                                                                     ']
#
#  tf.__operators__.add_4 (TF  (None, 20, 64)               0         ['dropout_6[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  layer_normalization_5 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_4[0][0]
#  erNormalization)                                                   ']
#
#  dense_5 (Dense)             (None, 20, 128)              8320      ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 20, 128)              0         ['dense_5[0][0]']
#
#  dense_6 (Dense)             (None, 20, 64)               8256      ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)         (None, 20, 64)               0         ['dense_6[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 20, 64)               0         ['dropout_8[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  layer_normalization_6 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_5[0][0]
#  erNormalization)                                                   ']
#
#  multi_head_attention_3 (Mu  (None, 20, 64)               66368     ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  dropout_9 (Dropout)         (None, 20, 64)               0         ['multi_head_attention_3[0][0]
#                                                                     ']
#
#  tf.__operators__.add_6 (TF  (None, 20, 64)               0         ['dropout_9[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  layer_normalization_7 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_6[0][0]
#  erNormalization)                                                   ']
#
#  dense_7 (Dense)             (None, 20, 128)              8320      ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_10 (Dropout)        (None, 20, 128)              0         ['dense_7[0][0]']
#
#  dense_8 (Dense)             (None, 20, 64)               8256      ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 20, 64)               0         ['dense_8[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 20, 64)               0         ['dropout_11[0][0]',
#  OpLambda)                                                           'tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  layer_normalization_8 (Lay  (None, 20, 64)               128       ['tf.__operators__.add_7[0][0]
#  erNormalization)                                                   ']
#
#  flatten (Flatten)           (None, 1280)                 0         ['layer_normalization_8[0][0]'
#                                                                     ]
#
#  dense_9 (Dense)             (None, 64)                   81984     ['flatten[0][0]']
#
#  dense_10 (Dense)            (None, 14)                   910       ['dense_9[0][0]']
#
# ==================================================================================================
# Total params: 418710 (1.60 MB)
# Trainable params: 418706 (1.60 MB)
# Non-trainable params: 4 (16.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Nadam(learning_rate=1e-3, clipnorm=1.0),
    loss=custom_loss,
)

# %%
dataset_base_dir = "/depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/contained"
tfrecords_base_dir = os.path.join(dataset_base_dir, "TFR_files", "2t")

dataset_train_dir = os.path.join(dataset_base_dir, "train")
dataset_test_dir = os.path.join(dataset_base_dir, "test")
tfrecords_dir_train = os.path.join(tfrecords_base_dir, "TFR_train")
tfrecords_dir_val   = os.path.join(tfrecords_base_dir, "TFR_val")

batch_size = 5000
val_batch_size = 5000
train_file_size = len(os.listdir(dataset_train_dir))
val_file_size = len(os.listdir(dataset_test_dir))

# %%
# start_time = time.time()
# validation_generator = OptimizedDataGenerator(
#     dataset_base_dir = dataset_test_dir,
#     file_type = "parquet",
#     data_format = "3D",
#     batch_size = val_batch_size,
#     # optimize_batch_size = True,
#     file_count = val_file_size,
#     to_standardize= True,
#     labels_list = ['x-midplane','y-midplane','cotAlpha','cotBeta'],
#     input_shape = (2,16,16), # (20,13,21),
#     transpose = (0,2,3,1),
#     shuffle = False, 
#     files_from_end=True,

#     tfrecords_dir = tfrecords_dir_val,
#     use_time_stamps = [0,19],
#     max_workers = 2
# )

# print("--- Validation generator %s seconds ---" % (time.time() - start_time))

# # training generator
# start_time = time.time()
# training_generator = OptimizedDataGenerator(
#     dataset_base_dir = dataset_train_dir,
#     file_type = "parquet",
#     data_format = "3D",
#     batch_size = batch_size,
#     # optimize_batch_size = True,
#     file_count = train_file_size,
#     to_standardize= True,
#     labels_list = ['x-midplane','y-midplane','cotAlpha','cotBeta'],
#     input_shape = (2,16,16), # (20,13,21),
#     transpose = (0,2,3,1),
#     shuffle = False, # True 

#     tfrecords_dir = tfrecords_dir_train,
#     use_time_stamps = [0,19],
#     max_workers = 2
# )
# print("--- Training generator %s seconds ---" % (time.time() - start_time))

# %%
# Loading pre-generated TFRecords
validation_generator = OptimizedDataGenerator(
    load_from_tfrecords_dir= tfrecords_dir_val,
    shuffle=True,
    seed=42,
    quantize=False,
)

training_generator = OptimizedDataGenerator(
    load_from_tfrecords_dir = tfrecords_dir_train,
    shuffle=True,
    seed=42,
    quantize=False,
)
# Out:
# Loading metadata from /depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/contained/TFR_files/2t/TFR_val/metadata.json
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# Loading metadata from /depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/contained/TFR_files/2t/TFR_train/metadata.json
# WARNING:root:Quantization is False in data generator. This may affect model performance.

# %%
from datetime import datetime

fingerprint = '%08x' % random.randrange(16**8)
timestamp = datetime.now().strftime('%Y%m%d-%H%M%S')
os.makedirs("trained_models", exist_ok=True)
base_dir = f'./trained_models/Transformer_model-{fingerprint}-checkpoints'

checkpoints_dir = os.path.join(base_dir, 'checkpoints')

os.makedirs(base_dir, exist_ok=True)
os.makedirs(checkpoints_dir, exist_ok=True) 
checkpoint_filepath = os.path.join(checkpoints_dir, 'weights.{epoch:02d}-t{loss:.2f}-v{val_loss:.2f}.hdf5')

# %%
checkpoint_filepath
# Out:
# './trained_models/Transformer_model-641e5444-checkpoints/checkpoints/weights.{epoch:02d}-t{loss:.2f}-v{val_loss:.2f}.hdf5'

# %%
# 9f5e5c2c : 1000 epochs
print(fingerprint)
# Out:
# 641e5444

# %%
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, Callback
import csv

early_stopping_patience = 50
es = EarlyStopping(patience=early_stopping_patience, restore_best_weights=True)

mcp = ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
       save_freq='epoch'
)

class SoftQuantizeLoggerCallback(Callback):
    def __init__(self, log_filepath, layer_name="soft_quantizer_output"):
        super().__init__()
        self.log_filepath = log_filepath
        self.layer_name = layer_name
        self.header_written = False

    def on_train_begin(self, logs=None):
        os.makedirs(os.path.dirname(self.log_filepath), exist_ok=True)

    def on_epoch_end(self, epoch, logs=None):
        try:
            layer = self.model.get_layer(self.layer_name)
            if not hasattr(layer, 'n_bits'):
                 print(f"\nWarning: Layer '{self.layer_name}' is not a SoftQuantizeLayer. Skipping logging.")
                 return
        except ValueError:
            print(f"\nWarning: Layer '{self.layer_name}' not found in the model. Skipping logging.")
            return

        if not self.header_written:
            num_levels = layer.num_levels
            num_thresholds = num_levels - 1
            
            header = ['epoch', 'k']
            header.extend([f'level_{i}' for i in range(num_levels)])
            header.extend([f'threshold_{i}' for i in range(num_thresholds)])

            header.append('raw_first_level')
            header.extend([f'raw_log_level_delta_{i}' for i in range(num_levels - 1)])
            header.append('raw_first_threshold')
            if hasattr(layer, 'log_threshold_deltas'):
                header.extend([f'raw_log_threshold_delta_{i}' for i in range(num_thresholds - 1)])

            with open(self.log_filepath, mode='w', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(header)
            self.header_written = True

        k_val = layer.k.numpy().item()
        levels = layer.levels.numpy().tolist()
        thresholds = layer.thresholds.numpy().tolist()
        
        first_level = layer.first_level.numpy().item()
        log_level_deltas = layer.log_level_deltas.numpy().tolist()
        first_threshold = layer.first_threshold.numpy().item()
        
        row_data = [epoch, k_val]
        row_data.extend(levels)
        row_data.extend(thresholds)
        row_data.append(first_level)
        row_data.extend(log_level_deltas)
        row_data.append(first_threshold)
        
        if hasattr(layer, 'log_threshold_deltas'):
            log_threshold_deltas = layer.log_threshold_deltas.numpy().tolist()
            row_data.extend(log_threshold_deltas)
        
        with open(self.log_filepath, mode='a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(row_data)


csv_logger = CSVLogger(f'{base_dir}/training_log.csv', append=True)
scheduler_callback = AnnealingScheduler(
    schedule='cosine',  
    target_layer_name='soft_quantizer_output', 
    initial_k=1.0,
    final_k=67.0, 
    verbose=1      
)

quantizer_logger = SoftQuantizeLoggerCallback(
    log_filepath=f"{base_dir}/soft_quantizer_state_log.csv", # New, more descriptive filename
    layer_name="soft_quantizer_output"
)

# %%
history = model.fit(
        x=training_generator,
        validation_data=validation_generator,
        callbacks=[mcp, csv_logger, scheduler_callback, quantizer_logger],
        epochs=1000,
        shuffle=False,
        verbose=1
    )
# Out:
# Epoch 1: Annealing 'k' set to 1.0000
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0000, 0.0000, 1.0000
# Epoch 1/1000
# 2025-09-14 03:56:27.961329: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x55986b3e5a20
# 2025-09-14 03:56:28.915337: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f84449a53e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-09-14 03:56:28.915398: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-PCIE-40GB MIG 7g.40gb, Compute Capability 8.0
# 2025-09-14 03:56:28.934017: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-14 03:56:28.963532: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1757814989.057748    2750 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 84/84 [==============================] - 42s 241ms/step - loss: 24630.1602 - val_loss: 14208.9834
#
# Epoch 2: Annealing 'k' set to 1.0002
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9997, -0.0033, 0.9909
# Epoch 2/1000
# 84/84 [==============================] - 10s 114ms/step - loss: 19014.9824 - val_loss: 12014.7129
#
# Epoch 3: Annealing 'k' set to 1.0007
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0005, -0.0071, 0.9765
# Epoch 3/1000
# 84/84 [==============================] - 10s 114ms/step - loss: 12055.3623 - val_loss: 11240.7734
#
# Epoch 4: Annealing 'k' set to 1.0015
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0003, -0.0084, 0.9565
# Epoch 4/1000
# 84/84 [==============================] - 10s 115ms/step - loss: 9122.9443 - val_loss: 5892.6411
#
# Epoch 5: Annealing 'k' set to 1.0026
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9873, 0.0078, 0.9422
# Epoch 5/1000
# 84/84 [==============================] - 10s 114ms/step - loss: 6521.0420 - val_loss: 2218.8015
#
# Epoch 6: Annealing 'k' set to 1.0041
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9978, -0.0230, 0.8679
# Epoch 6/1000
# 84/84 [==============================] - 9s 112ms/step - loss: 1910.6705 - val_loss: -1068.4683
#
# Epoch 7: Annealing 'k' set to 1.0059
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0001, -0.0525, 0.7798
# Epoch 7/1000
# 84/84 [==============================] - 10s 112ms/step - loss: -985.3206 - val_loss: -4478.9585
#
# Epoch 8: Annealing 'k' set to 1.0080
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0246, -0.1175, 0.6644
# Epoch 8/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -4387.4341 - val_loss: -8186.1436
#
# Epoch 9: Annealing 'k' set to 1.0104
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0374, -0.1474, 0.6038
# Epoch 9/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -8297.2246 - val_loss: -12467.9922
#
# Epoch 10: Annealing 'k' set to 1.0132
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0430, -0.1621, 0.5630
# Epoch 10/1000
# 84/84 [==============================] - 11s 127ms/step - loss: -11210.6035 - val_loss: -14807.3252
#
# Epoch 11: Annealing 'k' set to 1.0163
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0434, -0.1718, 0.5272
# Epoch 11/1000
# 84/84 [==============================] - 10s 112ms/step - loss: -13366.1299 - val_loss: -17052.3359
#
# Epoch 12: Annealing 'k' set to 1.0197
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0347, -0.1661, 0.5113
# Epoch 12/1000
# 84/84 [==============================] - 10s 113ms/step - loss: -14705.7861 - val_loss: -18923.1953
#
# Epoch 13: Annealing 'k' set to 1.0234
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0109, -0.1358, 0.5188
# Epoch 13/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -15934.4775 - val_loss: -19358.2441
#
# Epoch 14: Annealing 'k' set to 1.0275
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9948, -0.1125, 0.5265
# Epoch 14/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -17047.0469 - val_loss: -20129.9766
#
# Epoch 15: Annealing 'k' set to 1.0319
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9937, -0.1127, 0.5159
# Epoch 15/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -17961.5195 - val_loss: -21295.1953
#
# Epoch 16: Annealing 'k' set to 1.0366
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9883, -0.1060, 0.5152
# Epoch 16/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -18783.2246 - val_loss: -22246.8652
#
# Epoch 17: Annealing 'k' set to 1.0417
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9833, -0.0989, 0.5142
# Epoch 17/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -19488.7637 - val_loss: -21407.4043
#
# Epoch 18: Annealing 'k' set to 1.0471
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9794, -0.0930, 0.5124
# Epoch 18/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -20137.8145 - val_loss: -22916.5664
#
# Epoch 19: Annealing 'k' set to 1.0527
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9785, -0.0932, 0.5055
# Epoch 19/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -20747.8789 - val_loss: -23801.1230
#
# Epoch 20: Annealing 'k' set to 1.0588
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9766, -0.0955, 0.4933
# Epoch 20/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -21336.6504 - val_loss: -24253.5078
#
# Epoch 21: Annealing 'k' set to 1.0651
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9728, -0.0926, 0.4830
# Epoch 21/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -21898.9590 - val_loss: -25267.0371
#
# Epoch 22: Annealing 'k' set to 1.0718
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9634, -0.0818, 0.4840
# Epoch 22/1000
# 84/84 [==============================] - 10s 113ms/step - loss: -22440.7461 - val_loss: -24340.7910
#
# Epoch 23: Annealing 'k' set to 1.0788
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9606, -0.0815, 0.4740
# Epoch 23/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -22864.6016 - val_loss: -26756.1758
#
# Epoch 24: Annealing 'k' set to 1.0861
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9571, -0.0799, 0.4665
# Epoch 24/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -23211.1523 - val_loss: -27450.0000
#
# Epoch 25: Annealing 'k' set to 1.0938
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9548, -0.0746, 0.4691
# Epoch 25/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -23703.0645 - val_loss: -27612.8066
#
# Epoch 26: Annealing 'k' set to 1.1017
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9510, -0.0699, 0.4657
# Epoch 26/1000
# 84/84 [==============================] - 10s 113ms/step - loss: -24059.3203 - val_loss: -25928.5703
#
# Epoch 27: Annealing 'k' set to 1.1100
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9461, -0.0671, 0.4545
# Epoch 27/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -24492.4902 - val_loss: -28239.5352
#
# Epoch 28: Annealing 'k' set to 1.1186
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9384, -0.0568, 0.4572
# Epoch 28/1000
# 84/84 [==============================] - 10s 113ms/step - loss: -24781.8965 - val_loss: -27800.9004
#
# Epoch 29: Annealing 'k' set to 1.1276
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9377, -0.0624, 0.4400
# Epoch 29/1000
# 84/84 [==============================] - 9s 112ms/step - loss: -25120.5059 - val_loss: -28516.7910
#
# Epoch 30: Annealing 'k' set to 1.1369
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9349, -0.0582, 0.4385
# Epoch 30/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -25519.1445 - val_loss: -28786.0742
#
# Epoch 31: Annealing 'k' set to 1.1465
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9289, -0.0479, 0.4447
# Epoch 31/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -26000.2227 - val_loss: -29165.6055
#
# Epoch 32: Annealing 'k' set to 1.1564
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9183, -0.0309, 0.4568
# Epoch 32/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -26244.5977 - val_loss: -30169.0605
#
# Epoch 33: Annealing 'k' set to 1.1666
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9155, -0.0290, 0.4535
# Epoch 33/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -26528.4531 - val_loss: -27612.2305
#
# Epoch 34: Annealing 'k' set to 1.1772
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9151, -0.0289, 0.4446
# Epoch 34/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -26938.9570 - val_loss: -29541.2168
#
# Epoch 35: Annealing 'k' set to 1.1881
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9104, -0.0226, 0.4466
# Epoch 35/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -27281.3613 - val_loss: -29217.0410
#
# Epoch 36: Annealing 'k' set to 1.1993
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9155, -0.0326, 0.4322
# Epoch 36/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -27437.3555 - val_loss: -29174.9277
#
# Epoch 37: Annealing 'k' set to 1.2108
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9142, -0.0339, 0.4265
# Epoch 37/1000
# 84/84 [==============================] - 9s 111ms/step - loss: -27722.8730 - val_loss: -31327.0176
#
# Epoch 38: Annealing 'k' set to 1.2227
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9173, -0.0394, 0.4163
# Epoch 38/1000
# 84/84 [==============================] - 10s 112ms/step - loss: -28054.5938 - val_loss: -30603.2324
#
# Epoch 39: Annealing 'k' set to 1.2349
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9115, -0.0311, 0.4197
# Epoch 39/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -28133.7363 - val_loss: -31189.7305
#
# Epoch 40: Annealing 'k' set to 1.2474
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9067, -0.0251, 0.4221
# Epoch 40/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -28361.9902 - val_loss: -31287.5430
#
# Epoch 41: Annealing 'k' set to 1.2602
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8977, -0.0157, 0.4233
# Epoch 41/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -28763.7969 - val_loss: -32887.1523
#
# Epoch 42: Annealing 'k' set to 1.2734
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8927, -0.0084, 0.4274
# Epoch 42/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -29110.2051 - val_loss: -32042.0879
#
# Epoch 43: Annealing 'k' set to 1.2868
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8897, -0.0093, 0.4191
# Epoch 43/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -29072.0156 - val_loss: -32771.1055
#
# Epoch 44: Annealing 'k' set to 1.3006
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8902, -0.0143, 0.4085
# Epoch 44/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -29261.8555 - val_loss: -32219.8184
#
# Epoch 45: Annealing 'k' set to 1.3148
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8873, -0.0122, 0.4050
# Epoch 45/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -29526.3105 - val_loss: -33020.1250
#
# Epoch 46: Annealing 'k' set to 1.3292
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8909, -0.0207, 0.3926
# Epoch 46/1000
# 84/84 [==============================] - 9s 111ms/step - loss: -29681.5215 - val_loss: -32964.8398
#
# Epoch 47: Annealing 'k' set to 1.3440
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8864, -0.0125, 0.3981
# Epoch 47/1000
# 84/84 [==============================] - 9s 112ms/step - loss: -29952.1562 - val_loss: -33000.2461
#
# Epoch 48: Annealing 'k' set to 1.3591
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8826, -0.0079, 0.3998
# Epoch 48/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -26407.9941 - val_loss: -33074.4375
#
# Epoch 49: Annealing 'k' set to 1.3745
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8797, -0.0031, 0.4018
# Epoch 49/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -30058.6816 - val_loss: -33447.8477
#
# Epoch 50: Annealing 'k' set to 1.3902
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8776, -0.0006, 0.4020
# Epoch 50/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -24884.0664 - val_loss: -32996.0312
#
# Epoch 51: Annealing 'k' set to 1.4063
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8789, -0.0036, 0.3927
# Epoch 51/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -28180.4629 - val_loss: -32253.1875
#
# Epoch 52: Annealing 'k' set to 1.4227
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8739, -0.0017, 0.3847
# Epoch 52/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -29428.9180 - val_loss: -34705.2461
#
# Epoch 53: Annealing 'k' set to 1.4394
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8667, -0.0008, 0.3752
# Epoch 53/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -30041.1465 - val_loss: -32812.8438
#
# Epoch 54: Annealing 'k' set to 1.4564
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8656, -0.0043, 0.3646
# Epoch 54/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -28780.2871 - val_loss: -32672.9648
#
# Epoch 55: Annealing 'k' set to 1.4737
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8629, -0.0012, 0.3630
# Epoch 55/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -28669.4961 - val_loss: -34635.0820
#
# Epoch 56: Annealing 'k' set to 1.4914
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8597, -0.0034, 0.3520
# Epoch 56/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -29359.2168 - val_loss: -33388.7617
#
# Epoch 57: Annealing 'k' set to 1.5094
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8589, -0.0079, 0.3405
# Epoch 57/1000
# 84/84 [==============================] - 9s 111ms/step - loss: -30518.4648 - val_loss: -32686.1875
#
# Epoch 58: Annealing 'k' set to 1.5277
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8537, -0.0028, 0.3419
# Epoch 58/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -31139.1328 - val_loss: -33702.8125
#
# Epoch 59: Annealing 'k' set to 1.5463
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8481, -0.0003, 0.3382
# Epoch 59/1000
# 84/84 [==============================] - 9s 112ms/step - loss: -29910.2676 - val_loss: -33150.7695
#
# Epoch 60: Annealing 'k' set to 1.5653
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8439, -0.0012, 0.3281
# Epoch 60/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -29917.2070 - val_loss: -25030.6797
#
# Epoch 61: Annealing 'k' set to 1.5845
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8385, 0.0000, 0.3220
# Epoch 61/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -29764.9102 - val_loss: -31245.0742
#
# Epoch 62: Annealing 'k' set to 1.6041
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8354, 0.0017, 0.3180
# Epoch 62/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -29746.9785 - val_loss: -33349.4180
#
# Epoch 63: Annealing 'k' set to 1.6240
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8326, 0.0020, 0.3109
# Epoch 63/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -30305.7012 - val_loss: -33401.1953
#
# Epoch 64: Annealing 'k' set to 1.6442
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8260, -0.0007, 0.2976
# Epoch 64/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -30452.0879 - val_loss: -33936.4570
#
# Epoch 65: Annealing 'k' set to 1.6648
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8224, -0.0024, 0.2891
# Epoch 65/1000
# 84/84 [==============================] - 10s 113ms/step - loss: -30777.7598 - val_loss: -30632.8301
#
# Epoch 66: Annealing 'k' set to 1.6856
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8128, 0.0004, 0.2833
# Epoch 66/1000
# 84/84 [==============================] - 9s 112ms/step - loss: -30818.3203 - val_loss: -34037.9219
#
# Epoch 67: Annealing 'k' set to 1.7068
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8070, 0.0022, 0.2778
# Epoch 67/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -31094.6074 - val_loss: -34976.6406
#
# Epoch 68: Annealing 'k' set to 1.7283
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8014, 0.0008, 0.2695
# Epoch 68/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -32149.5527 - val_loss: -35628.5469
#
# Epoch 69: Annealing 'k' set to 1.7502
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7993, 0.0015, 0.2678
# Epoch 69/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -31283.3301 - val_loss: -35981.6914
#
# Epoch 70: Annealing 'k' set to 1.7723
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7958, 0.0009, 0.2635
# Epoch 70/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -32411.9375 - val_loss: -36058.4375
#
# Epoch 71: Annealing 'k' set to 1.7947
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7877, 0.0051, 0.2629
# Epoch 71/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -33106.7969 - val_loss: -33461.7227
#
# Epoch 72: Annealing 'k' set to 1.8175
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7857, 0.0041, 0.2592
# Epoch 72/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -30386.1855 - val_loss: -35135.0703
#
# Epoch 73: Annealing 'k' set to 1.8406
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7865, 0.0011, 0.2541
# Epoch 73/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -31642.9844 - val_loss: -34053.0859
#
# Epoch 74: Annealing 'k' set to 1.8640
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7856, 0.0006, 0.2511
# Epoch 74/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -31901.2090 - val_loss: -37063.9766
#
# Epoch 75: Annealing 'k' set to 1.8877
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7830, 0.0001, 0.2470
# Epoch 75/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -31949.1816 - val_loss: -34186.3477
#
# Epoch 76: Annealing 'k' set to 1.9118
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7794, 0.0019, 0.2452
# Epoch 76/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -33745.3125 - val_loss: -21509.5625
#
# Epoch 77: Annealing 'k' set to 1.9362
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7775, -0.0000, 0.2403
# Epoch 77/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -33409.8164 - val_loss: -35765.0312
#
# Epoch 78: Annealing 'k' set to 1.9608
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7733, 0.0038, 0.2425
# Epoch 78/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -32383.8398 - val_loss: -34903.9336
#
# Epoch 79: Annealing 'k' set to 1.9858
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7730, 0.0045, 0.2423
# Epoch 79/1000
# 84/84 [==============================] - 9s 112ms/step - loss: -34132.0781 - val_loss: -36853.4727
#
# Epoch 80: Annealing 'k' set to 2.0111
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7665, 0.0101, 0.2457
# Epoch 80/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -34394.0430 - val_loss: -38094.8438
#
# Epoch 81: Annealing 'k' set to 2.0368
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7621, 0.0133, 0.2470
# Epoch 81/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -34616.6016 - val_loss: -36115.0781
#
# Epoch 82: Annealing 'k' set to 2.0627
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7652, 0.0063, 0.2383
# Epoch 82/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -34811.2734 - val_loss: -35033.0000
#
# Epoch 83: Annealing 'k' set to 2.0890
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7652, 0.0051, 0.2344
# Epoch 83/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -35227.9531 - val_loss: -37862.5703
#
# Epoch 84: Annealing 'k' set to 2.1155
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7633, 0.0071, 0.2357
# Epoch 84/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -35120.5938 - val_loss: -38985.2578
#
# Epoch 85: Annealing 'k' set to 2.1424
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7653, 0.0036, 0.2312
# Epoch 85/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -35174.6523 - val_loss: -39274.8438
#
# Epoch 86: Annealing 'k' set to 2.1696
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7614, 0.0088, 0.2349
# Epoch 86/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -35420.3594 - val_loss: -36683.2305
#
# Epoch 87: Annealing 'k' set to 2.1971
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7661, 0.0004, 0.2254
# Epoch 87/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -28008.1953 - val_loss: -37436.5039
#
# Epoch 88: Annealing 'k' set to 2.2249
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7641, 0.0029, 0.2283
# Epoch 88/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -34100.5000 - val_loss: -38262.9492
#
# Epoch 89: Annealing 'k' set to 2.2531
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7630, 0.0017, 0.2253
# Epoch 89/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -35627.2148 - val_loss: -24641.5059
#
# Epoch 90: Annealing 'k' set to 2.2815
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7626, -0.0001, 0.2217
# Epoch 90/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -35001.5938 - val_loss: -36367.0156
#
# Epoch 91: Annealing 'k' set to 2.3103
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7599, 0.0033, 0.2242
# Epoch 91/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -33125.5195 - val_loss: -35987.3125
#
# Epoch 92: Annealing 'k' set to 2.3394
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7604, 0.0013, 0.2199
# Epoch 92/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -35168.7773 - val_loss: -37589.9102
#
# Epoch 93: Annealing 'k' set to 2.3688
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7586, 0.0035, 0.2214
# Epoch 93/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -34843.1328 - val_loss: -39077.8086
#
# Epoch 94: Annealing 'k' set to 2.3985
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7567, 0.0035, 0.2194
# Epoch 94/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -35419.5430 - val_loss: -38923.7070
#
# Epoch 95: Annealing 'k' set to 2.4285
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7563, 0.0027, 0.2175
# Epoch 95/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -34242.0898 - val_loss: -39726.9180
#
# Epoch 96: Annealing 'k' set to 2.4588
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7543, 0.0015, 0.2148
# Epoch 96/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36125.3711 - val_loss: -39129.6758
#
# Epoch 97: Annealing 'k' set to 2.4895
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7472, 0.0069, 0.2187
# Epoch 97/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36294.1484 - val_loss: -39781.0039
#
# Epoch 98: Annealing 'k' set to 2.5204
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7461, 0.0072, 0.2184
# Epoch 98/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -36368.1523 - val_loss: -37830.6367
#
# Epoch 99: Annealing 'k' set to 2.5517
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7419, 0.0121, 0.2225
# Epoch 99/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36305.8477 - val_loss: -36754.8086
#
# Epoch 100: Annealing 'k' set to 2.5833
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7449, 0.0064, 0.2159
# Epoch 100/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36508.2383 - val_loss: -39563.7500
#
# Epoch 101: Annealing 'k' set to 2.6151
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7421, 0.0099, 0.2197
# Epoch 101/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -34070.3086 - val_loss: -38983.7734
#
# Epoch 102: Annealing 'k' set to 2.6473
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7443, 0.0048, 0.2133
# Epoch 102/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36275.3867 - val_loss: -40075.0000
#
# Epoch 103: Annealing 'k' set to 2.6798
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7383, 0.0137, 0.2222
# Epoch 103/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36576.8828 - val_loss: -38226.9805
#
# Epoch 104: Annealing 'k' set to 2.7126
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7342, 0.0194, 0.2278
# Epoch 104/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36433.4141 - val_loss: -38540.2812
#
# Epoch 105: Annealing 'k' set to 2.7458
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7322, 0.0214, 0.2287
# Epoch 105/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -36633.2891 - val_loss: -40050.5703
#
# Epoch 106: Annealing 'k' set to 2.7792
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7358, 0.0151, 0.2215
# Epoch 106/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -36551.6719 - val_loss: -40232.8594
#
# Epoch 107: Annealing 'k' set to 2.8129
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7339, 0.0155, 0.2211
# Epoch 107/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36741.3359 - val_loss: -40344.5391
#
# Epoch 108: Annealing 'k' set to 2.8470
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7340, 0.0153, 0.2208
# Epoch 108/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36881.7734 - val_loss: -40618.4570
#
# Epoch 109: Annealing 'k' set to 2.8813
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7335, 0.0158, 0.2195
# Epoch 109/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -36782.1484 - val_loss: -38111.7812
#
# Epoch 110: Annealing 'k' set to 2.9160
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7284, 0.0248, 0.2291
# Epoch 110/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -36758.3359 - val_loss: -40339.4531
#
# Epoch 111: Annealing 'k' set to 2.9509
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7302, 0.0202, 0.2237
# Epoch 111/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -36587.0156 - val_loss: -39646.0625
#
# Epoch 112: Annealing 'k' set to 2.9862
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7333, 0.0138, 0.2155
# Epoch 112/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -36915.4609 - val_loss: -40057.3672
#
# Epoch 113: Annealing 'k' set to 3.0218
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7351, 0.0106, 0.2120
# Epoch 113/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -36625.1602 - val_loss: -40476.1875
#
# Epoch 114: Annealing 'k' set to 3.0577
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7350, 0.0108, 0.2122
# Epoch 114/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -36722.2734 - val_loss: -40326.1914
#
# Epoch 115: Annealing 'k' set to 3.0939
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7354, 0.0095, 0.2113
# Epoch 115/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36731.0430 - val_loss: -40278.0664
#
# Epoch 116: Annealing 'k' set to 3.1303
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7275, 0.0201, 0.2222
# Epoch 116/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -36693.4219 - val_loss: -38293.0742
#
# Epoch 117: Annealing 'k' set to 3.1671
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7210, 0.0270, 0.2290
# Epoch 117/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -37450.5430 - val_loss: -38737.3555
#
# Epoch 118: Annealing 'k' set to 3.2042
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7213, 0.0264, 0.2282
# Epoch 118/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -37289.0430 - val_loss: -37255.4961
#
# Epoch 119: Annealing 'k' set to 3.2417
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7181, 0.0282, 0.2280
# Epoch 119/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -37121.1719 - val_loss: -38362.8711
#
# Epoch 120: Annealing 'k' set to 3.2794
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7125, 0.0364, 0.2368
# Epoch 120/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -36999.1523 - val_loss: -39349.1328
#
# Epoch 121: Annealing 'k' set to 3.3174
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7101, 0.0406, 0.2407
# Epoch 121/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -37189.8711 - val_loss: -39604.8477
#
# Epoch 122: Annealing 'k' set to 3.3557
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7017, 0.0554, 0.2566
# Epoch 122/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -37199.4609 - val_loss: -39268.6289
#
# Epoch 123: Annealing 'k' set to 3.3943
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7027, 0.0536, 0.2546
# Epoch 123/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -37241.6133 - val_loss: -38698.6719
#
# Epoch 124: Annealing 'k' set to 3.4332
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6985, 0.0575, 0.2581
# Epoch 124/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -37412.3984 - val_loss: -39317.6250
#
# Epoch 125: Annealing 'k' set to 3.4725
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6931, 0.0629, 0.2637
# Epoch 125/1000
# 84/84 [==============================] - 10s 113ms/step - loss: -37447.6523 - val_loss: -40304.8359
#
# Epoch 126: Annealing 'k' set to 3.5120
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6876, 0.0705, 0.2717
# Epoch 126/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -37538.4727 - val_loss: -40401.8867
#
# Epoch 127: Annealing 'k' set to 3.5518
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6803, 0.0825, 0.2851
# Epoch 127/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -37546.2578 - val_loss: -37338.3594
#
# Epoch 128: Annealing 'k' set to 3.5919
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6796, 0.0812, 0.2833
# Epoch 128/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -37267.2500 - val_loss: -38335.7070
#
# Epoch 129: Annealing 'k' set to 3.6323
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6760, 0.0825, 0.2836
# Epoch 129/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -37403.2539 - val_loss: -40232.9375
#
# Epoch 130: Annealing 'k' set to 3.6731
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6753, 0.0836, 0.2847
# Epoch 130/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -37399.7812 - val_loss: -40454.0547
#
# Epoch 131: Annealing 'k' set to 3.7141
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6768, 0.0811, 0.2821
# Epoch 131/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -37339.1094 - val_loss: -40453.4727
#
# Epoch 132: Annealing 'k' set to 3.7554
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6788, 0.0776, 0.2779
# Epoch 132/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -37711.5742 - val_loss: -40383.5195
#
# Epoch 133: Annealing 'k' set to 3.7970
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6755, 0.0802, 0.2797
# Epoch 133/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -37757.9375 - val_loss: -40947.0586
#
# Epoch 134: Annealing 'k' set to 3.8390
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6750, 0.0786, 0.2775
# Epoch 134/1000
# 84/84 [==============================] - 10s 123ms/step - loss: -37604.1562 - val_loss: -40480.9648
#
# Epoch 135: Annealing 'k' set to 3.8812
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6741, 0.0800, 0.2792
# Epoch 135/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -37566.9141 - val_loss: -40250.0352
#
# Epoch 136: Annealing 'k' set to 3.9237
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6729, 0.0829, 0.2825
# Epoch 136/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -37714.8672 - val_loss: -38955.1875
#
# Epoch 137: Annealing 'k' set to 3.9665
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6722, 0.0841, 0.2832
# Epoch 137/1000
# 84/84 [==============================] - 10s 123ms/step - loss: -37842.7109 - val_loss: -39276.3828
#
# Epoch 138: Annealing 'k' set to 4.0096
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6728, 0.0828, 0.2825
# Epoch 138/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -37986.6289 - val_loss: -40045.0664
#
# Epoch 139: Annealing 'k' set to 4.0530
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6718, 0.0846, 0.2852
# Epoch 139/1000
# 84/84 [==============================] - 10s 113ms/step - loss: -37992.7266 - val_loss: -39592.0586
#
# Epoch 140: Annealing 'k' set to 4.0967
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6686, 0.0891, 0.2901
# Epoch 140/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -37937.8828 - val_loss: -37621.6133
#
# Epoch 141: Annealing 'k' set to 4.1407
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6749, 0.0776, 0.2790
# Epoch 141/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -37871.8672 - val_loss: -39119.0000
#
# Epoch 142: Annealing 'k' set to 4.1850
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6688, 0.0866, 0.2885
# Epoch 142/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -37885.6875 - val_loss: -38988.3906
#
# Epoch 143: Annealing 'k' set to 4.2296
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6667, 0.0879, 0.2905
# Epoch 143/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -37923.5820 - val_loss: -39397.5625
#
# Epoch 144: Annealing 'k' set to 4.2745
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6702, 0.0794, 0.2819
# Epoch 144/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38267.4961 - val_loss: -40859.7070
#
# Epoch 145: Annealing 'k' set to 4.3196
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6653, 0.0855, 0.2897
# Epoch 145/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38233.1836 - val_loss: -41018.6641
#
# Epoch 146: Annealing 'k' set to 4.3651
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6620, 0.0907, 0.2960
# Epoch 146/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38270.8672 - val_loss: -40189.5781
#
# Epoch 147: Annealing 'k' set to 4.4108
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6600, 0.0929, 0.2984
# Epoch 147/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -38411.3945 - val_loss: -41491.1875
#
# Epoch 148: Annealing 'k' set to 4.4569
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6587, 0.0950, 0.3014
# Epoch 148/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -38065.8359 - val_loss: -40819.1680
#
# Epoch 149: Annealing 'k' set to 4.5032
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6531, 0.1029, 0.3119
# Epoch 149/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38161.1836 - val_loss: -41233.6484
#
# Epoch 150: Annealing 'k' set to 4.5499
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6429, 0.1153, 0.3238
# Epoch 150/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -38267.8516 - val_loss: -41350.3672
#
# Epoch 151: Annealing 'k' set to 4.5968
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6384, 0.1213, 0.3294
# Epoch 151/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -38167.8359 - val_loss: -38861.3359
#
# Epoch 152: Annealing 'k' set to 4.6440
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6325, 0.1290, 0.3363
# Epoch 152/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38270.8398 - val_loss: -38332.0898
#
# Epoch 153: Annealing 'k' set to 4.6915
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6301, 0.1323, 0.3398
# Epoch 153/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -38295.0898 - val_loss: -40121.8906
#
# Epoch 154: Annealing 'k' set to 4.7393
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6321, 0.1267, 0.3340
# Epoch 154/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -38385.6523 - val_loss: -40762.8984
#
# Epoch 155: Annealing 'k' set to 4.7874
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6277, 0.1334, 0.3404
# Epoch 155/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38452.0859 - val_loss: -39465.7109
#
# Epoch 156: Annealing 'k' set to 4.8357
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6238, 0.1348, 0.3410
# Epoch 156/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -38304.4102 - val_loss: -38084.3984
#
# Epoch 157: Annealing 'k' set to 4.8844
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6196, 0.1404, 0.3471
# Epoch 157/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38320.5391 - val_loss: -39183.1328
#
# Epoch 158: Annealing 'k' set to 4.9333
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6153, 0.1471, 0.3547
# Epoch 158/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38643.2305 - val_loss: -40993.1484
#
# Epoch 159: Annealing 'k' set to 4.9826
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6147, 0.1474, 0.3553
# Epoch 159/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38718.6875 - val_loss: -40228.4062
#
# Epoch 160: Annealing 'k' set to 5.0321
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6193, 0.1394, 0.3469
# Epoch 160/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -38585.0820 - val_loss: -40475.6953
#
# Epoch 161: Annealing 'k' set to 5.0819
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6177, 0.1421, 0.3505
# Epoch 161/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38598.0273 - val_loss: -39560.4570
#
# Epoch 162: Annealing 'k' set to 5.1320
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6125, 0.1484, 0.3584
# Epoch 162/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -38410.9453 - val_loss: -39482.4102
#
# Epoch 163: Annealing 'k' set to 5.1823
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6138, 0.1443, 0.3566
# Epoch 163/1000
# 84/84 [==============================] - 10s 124ms/step - loss: -38514.6133 - val_loss: -39447.2383
#
# Epoch 164: Annealing 'k' set to 5.2330
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6134, 0.1442, 0.3571
# Epoch 164/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -38516.1250 - val_loss: -37888.7812
#
# Epoch 165: Annealing 'k' set to 5.2839
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6112, 0.1464, 0.3591
# Epoch 165/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -38528.9609 - val_loss: -41716.0859
#
# Epoch 166: Annealing 'k' set to 5.3352
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6116, 0.1472, 0.3611
# Epoch 166/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -38865.3594 - val_loss: -40848.8555
#
# Epoch 167: Annealing 'k' set to 5.3867
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6103, 0.1496, 0.3649
# Epoch 167/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -38828.1602 - val_loss: -40766.2188
#
# Epoch 168: Annealing 'k' set to 5.4385
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6132, 0.1444, 0.3598
# Epoch 168/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -38733.4453 - val_loss: -40647.7383
#
# Epoch 169: Annealing 'k' set to 5.4905
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6090, 0.1504, 0.3680
# Epoch 169/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -38966.0977 - val_loss: -39902.1094
#
# Epoch 170: Annealing 'k' set to 5.5429
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6109, 0.1459, 0.3645
# Epoch 170/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -38916.6367 - val_loss: -39862.3594
#
# Epoch 171: Annealing 'k' set to 5.5955
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6106, 0.1461, 0.3667
# Epoch 171/1000
# 84/84 [==============================] - 10s 123ms/step - loss: -38811.6875 - val_loss: -40635.0781
#
# Epoch 172: Annealing 'k' set to 5.6484
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6101, 0.1469, 0.3682
# Epoch 172/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -39031.7539 - val_loss: -41419.4414
#
# Epoch 173: Annealing 'k' set to 5.7016
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6054, 0.1536, 0.3779
# Epoch 173/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -38932.8516 - val_loss: -41739.8477
#
# Epoch 174: Annealing 'k' set to 5.7551
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6084, 0.1469, 0.3718
# Epoch 174/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -39032.5703 - val_loss: -40157.0078
#
# Epoch 175: Annealing 'k' set to 5.8088
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6079, 0.1477, 0.3732
# Epoch 175/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -39108.5195 - val_loss: -42419.6406
#
# Epoch 176: Annealing 'k' set to 5.8629
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6081, 0.1457, 0.3726
# Epoch 176/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -39279.2852 - val_loss: -41920.3906
#
# Epoch 177: Annealing 'k' set to 5.9172
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6067, 0.1482, 0.3774
# Epoch 177/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -39320.0977 - val_loss: -41008.9844
#
# Epoch 178: Annealing 'k' set to 5.9718
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6127, 0.1373, 0.3713
# Epoch 178/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -39225.1602 - val_loss: -41982.7969
#
# Epoch 179: Annealing 'k' set to 6.0266
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6118, 0.1388, 0.3746
# Epoch 179/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -39237.1641 - val_loss: -40735.6172
#
# Epoch 180: Annealing 'k' set to 6.0818
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6094, 0.1414, 0.3794
# Epoch 180/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -39435.3164 - val_loss: -41385.8711
#
# Epoch 181: Annealing 'k' set to 6.1372
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6093, 0.1400, 0.3804
# Epoch 181/1000
# 84/84 [==============================] - 10s 113ms/step - loss: -39471.4961 - val_loss: -41177.4102
#
# Epoch 182: Annealing 'k' set to 6.1929
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6099, 0.1377, 0.3802
# Epoch 182/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -39458.6836 - val_loss: -41508.0156
#
# Epoch 183: Annealing 'k' set to 6.2488
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6067, 0.1418, 0.3870
# Epoch 183/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -39452.4688 - val_loss: -40642.1250
#
# Epoch 184: Annealing 'k' set to 6.3051
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6041, 0.1455, 0.3950
# Epoch 184/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -39617.9727 - val_loss: -41944.4219
#
# Epoch 185: Annealing 'k' set to 6.3616
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6005, 0.1518, 0.4044
# Epoch 185/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -39690.6445 - val_loss: -41681.7930
#
# Epoch 186: Annealing 'k' set to 6.4184
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6036, 0.1458, 0.4007
# Epoch 186/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -39581.0039 - val_loss: -42339.7344
#
# Epoch 187: Annealing 'k' set to 6.4754
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6001, 0.1495, 0.4082
# Epoch 187/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -39784.0586 - val_loss: -40839.1406
#
# Epoch 188: Annealing 'k' set to 6.5327
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6028, 0.1438, 0.4055
# Epoch 188/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -39870.8164 - val_loss: -41542.8320
#
# Epoch 189: Annealing 'k' set to 6.5903
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6037, 0.1422, 0.4059
# Epoch 189/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -39828.5781 - val_loss: -42172.9805
#
# Epoch 190: Annealing 'k' set to 6.6482
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6063, 0.1377, 0.4041
# Epoch 190/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -39770.7812 - val_loss: -42529.1562
#
# Epoch 191: Annealing 'k' set to 6.7063
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6032, 0.1433, 0.4153
# Epoch 191/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -39484.3711 - val_loss: -41722.2148
#
# Epoch 192: Annealing 'k' set to 6.7647
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6044, 0.1423, 0.4135
# Epoch 192/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -39834.7969 - val_loss: -42561.0820
#
# Epoch 193: Annealing 'k' set to 6.8234
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6022, 0.1455, 0.4206
# Epoch 193/1000
# 84/84 [==============================] - 10s 115ms/step - loss: -40063.1641 - val_loss: -42738.0391
#
# Epoch 194: Annealing 'k' set to 6.8824
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6022, 0.1439, 0.4219
# Epoch 194/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -39956.2812 - val_loss: -42231.9375
#
# Epoch 195: Annealing 'k' set to 6.9416
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6061, 0.1369, 0.4154
# Epoch 195/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -40149.4922 - val_loss: -41473.9414
#
# Epoch 196: Annealing 'k' set to 7.0011
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6015, 0.1417, 0.4272
# Epoch 196/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -39945.3125 - val_loss: -42839.9609
#
# Epoch 197: Annealing 'k' set to 7.0608
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6019, 0.1417, 0.4313
# Epoch 197/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -40061.0469 - val_loss: -42996.3047
#
# Epoch 198: Annealing 'k' set to 7.1208
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6061, 0.1352, 0.4278
# Epoch 198/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -40009.3594 - val_loss: -42816.8867
#
# Epoch 199: Annealing 'k' set to 7.1811
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6073, 0.1333, 0.4304
# Epoch 199/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -40095.2891 - val_loss: -42774.4453
#
# Epoch 200: Annealing 'k' set to 7.2416
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6078, 0.1315, 0.4325
# Epoch 200/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -40527.5742 - val_loss: -42946.5039
#
# Epoch 201: Annealing 'k' set to 7.3024
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6046, 0.1379, 0.4426
# Epoch 201/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -40429.9102 - val_loss: -41953.1094
#
# Epoch 202: Annealing 'k' set to 7.3635
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6004, 0.1447, 0.4525
# ...
#
# Epoch 933: Annealing 'k' set to 66.2498
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9159, 0.0806, 0.5713
# Epoch 933/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44862.4375 - val_loss: -46051.9922
#
# Epoch 934: Annealing 'k' set to 66.2717
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9145, 0.0810, 0.5741
# Epoch 934/1000
# 84/84 [==============================] - 10s 123ms/step - loss: -44868.9688 - val_loss: -46255.0078
#
# Epoch 935: Annealing 'k' set to 66.2932
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9150, 0.0798, 0.5759
# Epoch 935/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -44879.4727 - val_loss: -45812.3906
#
# Epoch 936: Annealing 'k' set to 66.3144
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9164, 0.0793, 0.5704
# Epoch 936/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44901.0625 - val_loss: -46065.3281
#
# Epoch 937: Annealing 'k' set to 66.3352
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9154, 0.0783, 0.5705
# Epoch 937/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -44894.7852 - val_loss: -45799.1914
#
# Epoch 938: Annealing 'k' set to 66.3558
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9136, 0.0825, 0.5730
# Epoch 938/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44884.3594 - val_loss: -46086.3164
#
# Epoch 939: Annealing 'k' set to 66.3760
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9133, 0.0835, 0.5760
# Epoch 939/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -44857.5117 - val_loss: -46229.4141
#
# Epoch 940: Annealing 'k' set to 66.3959
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9173, 0.0788, 0.5723
# Epoch 940/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -44885.0508 - val_loss: -45832.2695
#
# Epoch 941: Annealing 'k' set to 66.4155
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9153, 0.0780, 0.5705
# Epoch 941/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -44906.6641 - val_loss: -46124.8672
#
# Epoch 942: Annealing 'k' set to 66.4347
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9165, 0.0779, 0.5709
# Epoch 942/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -44904.8047 - val_loss: -45920.1250
#
# Epoch 943: Annealing 'k' set to 66.4537
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9126, 0.0827, 0.5728
# Epoch 943/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -44912.8906 - val_loss: -46125.1133
#
# Epoch 944: Annealing 'k' set to 66.4723
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9125, 0.0798, 0.5741
# Epoch 944/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -44913.7539 - val_loss: -45846.3438
#
# Epoch 945: Annealing 'k' set to 66.4906
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9157, 0.0742, 0.5703
# Epoch 945/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -44925.7773 - val_loss: -46020.6953
#
# Epoch 946: Annealing 'k' set to 66.5086
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9120, 0.0805, 0.5706
# Epoch 946/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -44928.2109 - val_loss: -46070.2070
#
# Epoch 947: Annealing 'k' set to 66.5263
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9122, 0.0793, 0.5748
# Epoch 947/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -44922.6211 - val_loss: -46085.2188
#
# Epoch 948: Annealing 'k' set to 66.5436
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9132, 0.0791, 0.5720
# Epoch 948/1000
# 84/84 [==============================] - 10s 123ms/step - loss: -44952.5859 - val_loss: -45826.4023
#
# Epoch 949: Annealing 'k' set to 66.5606
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9165, 0.0734, 0.5704
# Epoch 949/1000
# 84/84 [==============================] - 10s 123ms/step - loss: -44954.5781 - val_loss: -45912.1641
#
# Epoch 950: Annealing 'k' set to 66.5773
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9163, 0.0781, 0.5743
# Epoch 950/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -44896.6992 - val_loss: -46108.1602
#
# Epoch 951: Annealing 'k' set to 66.5937
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9156, 0.0786, 0.5719
# Epoch 951/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44914.1758 - val_loss: -46176.8438
#
# Epoch 952: Annealing 'k' set to 66.6098
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9155, 0.0792, 0.5741
# Epoch 952/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -44933.0156 - val_loss: -46033.3906
#
# Epoch 953: Annealing 'k' set to 66.6255
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9172, 0.0783, 0.5718
# Epoch 953/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -44931.2031 - val_loss: -46318.1211
#
# Epoch 954: Annealing 'k' set to 66.6409
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9172, 0.0783, 0.5702
# Epoch 954/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -44936.5000 - val_loss: -46167.6719
#
# Epoch 955: Annealing 'k' set to 66.6560
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9134, 0.0836, 0.5758
# Epoch 955/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -44948.1406 - val_loss: -45819.0938
#
# Epoch 956: Annealing 'k' set to 66.6708
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9166, 0.0780, 0.5731
# Epoch 956/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -44917.9297 - val_loss: -45995.9844
#
# Epoch 957: Annealing 'k' set to 66.6852
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9173, 0.0795, 0.5734
# Epoch 957/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -44929.7422 - val_loss: -45980.6211
#
# Epoch 958: Annealing 'k' set to 66.6993
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9188, 0.0763, 0.5722
# Epoch 958/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -44931.2852 - val_loss: -46116.4844
#
# Epoch 959: Annealing 'k' set to 66.7132
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9173, 0.0776, 0.5735
# Epoch 959/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -44938.3203 - val_loss: -46417.0547
#
# Epoch 960: Annealing 'k' set to 66.7266
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9160, 0.0767, 0.5698
# Epoch 960/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -44937.0586 - val_loss: -46032.0781
#
# Epoch 961: Annealing 'k' set to 66.7398
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9149, 0.0781, 0.5724
# Epoch 961/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -44979.1367 - val_loss: -45903.2695
#
# Epoch 962: Annealing 'k' set to 66.7526
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9147, 0.0780, 0.5725
# Epoch 962/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44979.0898 - val_loss: -46414.7695
#
# Epoch 963: Annealing 'k' set to 66.7651
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9170, 0.0732, 0.5696
# Epoch 963/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -44983.8359 - val_loss: -46374.3867
#
# Epoch 964: Annealing 'k' set to 66.7773
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9142, 0.0761, 0.5706
# Epoch 964/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44947.9609 - val_loss: -45852.9375
#
# Epoch 965: Annealing 'k' set to 66.7892
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9148, 0.0763, 0.5727
# Epoch 965/1000
# 84/84 [==============================] - 11s 126ms/step - loss: -44994.2578 - val_loss: -46319.3906
#
# Epoch 966: Annealing 'k' set to 66.8007
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9134, 0.0809, 0.5758
# Epoch 966/1000
# 84/84 [==============================] - 10s 123ms/step - loss: -44975.9922 - val_loss: -46172.2617
#
# Epoch 967: Annealing 'k' set to 66.8119
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9183, 0.0770, 0.5734
# Epoch 967/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -44968.1953 - val_loss: -46224.2695
#
# Epoch 968: Annealing 'k' set to 66.8228
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9180, 0.0759, 0.5722
# Epoch 968/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44997.4609 - val_loss: -45990.3984
#
# Epoch 969: Annealing 'k' set to 66.8334
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9168, 0.0771, 0.5721
# Epoch 969/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -44965.8086 - val_loss: -46088.4219
#
# Epoch 970: Annealing 'k' set to 66.8436
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9180, 0.0778, 0.5724
# Epoch 970/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -44979.9961 - val_loss: -46583.2930
#
# Epoch 971: Annealing 'k' set to 66.8535
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9183, 0.0764, 0.5733
# Epoch 971/1000
# 84/84 [==============================] - 10s 117ms/step - loss: -44953.1758 - val_loss: -45988.2305
#
# Epoch 972: Annealing 'k' set to 66.8631
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9135, 0.0822, 0.5757
# Epoch 972/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44988.1836 - val_loss: -45871.7656
#
# Epoch 973: Annealing 'k' set to 66.8724
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9148, 0.0779, 0.5723
# Epoch 973/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44966.7734 - val_loss: -45725.5820
#
# Epoch 974: Annealing 'k' set to 66.8814
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9125, 0.0799, 0.5722
# Epoch 974/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44948.9062 - val_loss: -46350.6914
#
# Epoch 975: Annealing 'k' set to 66.8900
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9136, 0.0802, 0.5741
# Epoch 975/1000
# 84/84 [==============================] - 10s 125ms/step - loss: -44981.2695 - val_loss: -45772.2812
#
# Epoch 976: Annealing 'k' set to 66.8983
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9149, 0.0754, 0.5679
# Epoch 976/1000
# 84/84 [==============================] - 11s 125ms/step - loss: -44995.2109 - val_loss: -46184.7695
#
# Epoch 977: Annealing 'k' set to 66.9062
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9142, 0.0770, 0.5709
# Epoch 977/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -44988.3008 - val_loss: -46244.1406
#
# Epoch 978: Annealing 'k' set to 66.9139
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9168, 0.0734, 0.5705
# Epoch 978/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -45003.1602 - val_loss: -46088.5391
#
# Epoch 979: Annealing 'k' set to 66.9212
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9136, 0.0797, 0.5722
# Epoch 979/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -45006.4570 - val_loss: -46054.1680
#
# Epoch 980: Annealing 'k' set to 66.9282
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9152, 0.0787, 0.5738
# Epoch 980/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -45001.5234 - val_loss: -46087.1914
#
# Epoch 981: Annealing 'k' set to 66.9349
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9157, 0.0764, 0.5715
# Epoch 981/1000
# 84/84 [==============================] - 11s 126ms/step - loss: -44990.6719 - val_loss: -45953.3242
#
# Epoch 982: Annealing 'k' set to 66.9412
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9146, 0.0778, 0.5714
# Epoch 982/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -45025.9688 - val_loss: -46449.0352
#
# Epoch 983: Annealing 'k' set to 66.9473
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9149, 0.0769, 0.5707
# Epoch 983/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -45005.3555 - val_loss: -46102.5938
#
# Epoch 984: Annealing 'k' set to 66.9529
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9135, 0.0804, 0.5730
# Epoch 984/1000
# 84/84 [==============================] - 10s 116ms/step - loss: -44976.3242 - val_loss: -45963.0273
#
# Epoch 985: Annealing 'k' set to 66.9583
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9160, 0.0783, 0.5732
# Epoch 985/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -45003.1992 - val_loss: -45775.2031
#
# Epoch 986: Annealing 'k' set to 66.9634
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9173, 0.0761, 0.5755
# Epoch 986/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -44975.6289 - val_loss: -46276.7344
#
# Epoch 987: Annealing 'k' set to 66.9681
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9170, 0.0739, 0.5696
# Epoch 987/1000
# 84/84 [==============================] - 10s 122ms/step - loss: -44996.3828 - val_loss: -45884.4375
#
# Epoch 988: Annealing 'k' set to 66.9725
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9155, 0.0793, 0.5718
# Epoch 988/1000
# 84/84 [==============================] - 10s 118ms/step - loss: -45012.7812 - val_loss: -46404.0352
#
# Epoch 989: Annealing 'k' set to 66.9766
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9167, 0.0781, 0.5725
# Epoch 989/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -45020.2422 - val_loss: -46456.1641
#
# Epoch 990: Annealing 'k' set to 66.9803
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9193, 0.0749, 0.5724
# Epoch 990/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -45006.7734 - val_loss: -46242.6719
#
# Epoch 991: Annealing 'k' set to 66.9837
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9175, 0.0759, 0.5733
# Epoch 991/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -44992.0352 - val_loss: -46116.0234
#
# Epoch 992: Annealing 'k' set to 66.9868
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9160, 0.0769, 0.5714
# Epoch 992/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -45044.3477 - val_loss: -46435.2266
#
# Epoch 993: Annealing 'k' set to 66.9896
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9141, 0.0780, 0.5719
# Epoch 993/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -45039.3555 - val_loss: -46049.6992
#
# Epoch 994: Annealing 'k' set to 66.9920
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9170, 0.0741, 0.5698
# Epoch 994/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -45040.0859 - val_loss: -45990.2773
#
# Epoch 995: Annealing 'k' set to 66.9941
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9158, 0.0779, 0.5736
# Epoch 995/1000
# 84/84 [==============================] - 10s 114ms/step - loss: -45007.2070 - val_loss: -46048.9570
#
# Epoch 996: Annealing 'k' set to 66.9959
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9165, 0.0740, 0.5731
# Epoch 996/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -45055.3008 - val_loss: -45997.8086
#
# Epoch 997: Annealing 'k' set to 66.9974
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9164, 0.0761, 0.5724
# Epoch 997/1000
# 84/84 [==============================] - 10s 124ms/step - loss: -45039.5625 - val_loss: -46031.3672
#
# Epoch 998: Annealing 'k' set to 66.9985
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9156, 0.0786, 0.5746
# Epoch 998/1000
# 84/84 [==============================] - 10s 121ms/step - loss: -45020.8945 - val_loss: -46260.0508
#
# Epoch 999: Annealing 'k' set to 66.9993
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9170, 0.0769, 0.5732
# Epoch 999/1000
# 84/84 [==============================] - 10s 120ms/step - loss: -45028.1367 - val_loss: -46039.4844
#
# Epoch 1000: Annealing 'k' set to 66.9998
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9181, 0.0755, 0.5721
# Epoch 1000/1000
# 84/84 [==============================] - 10s 119ms/step - loss: -45046.7266 - val_loss: -46227.3047

# %%
sq_layer = model.get_layer(name="soft_quantizer_output")
print(f"Successfully retrieved layer: '{sq_layer.name}'\n")


print("="*50)
print("1. LAYER CONFIGURATION")
print("="*50)
config = sq_layer.get_config()
for key, value in config.items():
    print(f"- {key}: {value}")

print("\n" + "="*50)
print("2. CURRENT QUANTIZER STATE (DERIVED)")
print("="*50)

print(f"- Current k value: {sq_layer.k.numpy().item():.4f}") 
print(f"- Current Levels: {sq_layer.levels.numpy()}")
print(f"- Current Thresholds: {sq_layer.thresholds.numpy()}")

print("\n" + "="*50)
print("3. UNDERLYING RAW WEIGHTS")
print("="*50)
print(f"- log_k: {sq_layer.log_k.numpy().item():.4f}")
print(f"- first_level: {sq_layer.first_level.numpy()}")
print(f"- log_level_deltas: {sq_layer.log_level_deltas.numpy()}")
print(f"- first_threshold: {sq_layer.first_threshold.numpy()}")

if hasattr(sq_layer, 'log_threshold_deltas'):
    print(f"- log_threshold_deltas: {sq_layer.log_threshold_deltas.numpy()}")
else:
    print("- log_threshold_deltas: (Not present, expected for n_bits=1)")
    
print("\n" + "="*50)
print("4. KERAS WEIGHT STATUS")
print("="*50)
if sq_layer.trainable_weights:
    print("Trainable Weights:")
    for weight in sq_layer.trainable_weights:
        print(f"  - {weight.name}: shape={weight.shape.as_list()}")
else:
    print("This layer has no trainable weights.")

if sq_layer.non_trainable_weights:
    print("\nNon-Trainable Weights:")
    for weight in sq_layer.non_trainable_weights:
        print(f"  - {weight.name}: shape={weight.shape.as_list()}")
else:
    print("\nThis layer has no non-trainable weights.")
# Out:
# Successfully retrieved layer: 'soft_quantizer_output'
#
# ==================================================
# 1. LAYER CONFIGURATION
# ==================================================
# - name: soft_quantizer_output
# - trainable: True
# - dtype: float32
# - n_bits: 2
# - initial_range: ListWrapper([-1.0, 1.0])
# - trainable_levels: False
# - trainable_thresholds: True
# - initial_k: 1.0
# - trainable_k: True
#
# ==================================================
# 2. CURRENT QUANTIZER STATE (DERIVED)
# ==================================================
# - Current k value: 61.6021
# - Current Levels: [-1.         -0.3333333   0.33333337  1.        ]
# - Current Thresholds: [-0.91636866  0.07758182  0.5741866 ]
#
# ==================================================
# 3. UNDERLYING RAW WEIGHTS
# ==================================================
# - log_k: 4.1207
# - first_level: [-1.]
# - log_level_deltas: [-0.40546507 -0.40546507 -0.4054652 ]
# - first_threshold: [-0.91636866]
# - log_threshold_deltas: [-0.00606788 -0.6999607 ]
#
# ==================================================
# 4. KERAS WEIGHT STATUS
# ==================================================
# Trainable Weights:
#   - soft_quantizer_output/first_threshold:0: shape=[1]
#   - soft_quantizer_output/log_threshold_deltas:0: shape=[2]
#   - soft_quantizer_output/log_k:0: shape=[1]
#
# Non-Trainable Weights:
#   - soft_quantizer_output/first_level:0: shape=[1]
#   - soft_quantizer_output/log_level_deltas:0: shape=[3]
