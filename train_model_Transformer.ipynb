# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.optimizers import Adam
import keras
from keras.models import Sequential, Model
from keras.layers import *
from keras.utils import Sequence
from keras.layers import Conv2D, MaxPooling2D
from qkeras import *

from keras.utils import Sequence
from keras.callbacks import CSVLogger
from keras.callbacks import EarlyStopping

import os
import random
from datetime import datetime
import time

import matplotlib.pyplot as plt

pi = 3.14159265359
maxval=1e9
minval=1e-9
# Out:
# 2025-09-17 07:51:54.327745: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-09-17 07:51:54.327821: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-09-17 07:51:54.328901: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-09-17 07:51:54.336225: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-17 07:52:07.158497: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from DG.OptimizedDataGenerator_v2p5 import OptimizedDataGenerator
from losses.loss import custom_loss
from models.SoftQuantizeLayer import SoftQuantizeLayer
from models.AnnealingScheduler import AnnealingScheduler
# from models.models import CreateModel # Conv2D model

# %%
# Trasformer model

class PatchExtractor(layers.Layer):
  """Extract 2D patches from images."""
  def __init__(self, patch_size=(3,7)):
    super().__init__()
    self.patch_size = patch_size

  def call(self, images):
    # images: (batch, H, W, C)
    patch_h, patch_w = self.patch_size
    batch_size = tf.shape(images)[0]
    patches = tf.image.extract_patches(
        images=images,
        sizes=(1, patch_h, patch_w, 1),
        strides=(1, patch_h, patch_w, 1),
        rates=(1,1,1,1),
        padding='VALID'
    )
    # Now `patches` has shape: 
    #   (batch, H//patch_h, W//patch_w, patch_h*patch_w*C)
    # Flatten the 2D grid of patches => (batch, num_patches, patch_dim)
    patch_dims = tf.shape(patches)[-1]
    patches = tf.reshape(
        patches,
        [batch_size, -1, patch_dims]
    )
    return patches

class PatchEncoder(layers.Layer):
  """Linear embedding + learnable positional encoding."""
  def __init__(self, num_patches, embed_dim):
    super().__init__()
    self.num_patches = num_patches
    self.projection  = layers.Dense(embed_dim)
    self.pos_embed   = tf.Variable(
        initial_value=tf.zeros((1,num_patches,embed_dim)),
        trainable=True,
        name="pos_embedding"
    )

  def call(self, patch_batch):
    # Linear projection of patch tokens
    projected = self.projection(patch_batch)
    # Add learnable positional embeddings
    return projected + self.pos_embed

def transformer_encoder(inputs,
                        head_size,
                        num_heads,
                        ff_dim,
                        dropout=0.1):
  # LayerNorm + Multi-head attention
  x = layers.LayerNormalization(epsilon=1e-6)(inputs)
  x = layers.MultiHeadAttention(num_heads=num_heads,
                                key_dim=head_size,
                                dropout=dropout)(x, x)
  x = layers.Dropout(dropout)(x)
  res = x + inputs
  
  # Next LN + feed-forward
  x = layers.LayerNormalization(epsilon=1e-6)(res)
  x = layers.Dense(ff_dim, activation="relu")(x)
  x = layers.Dropout(dropout)(x)
  x = layers.Dense(inputs.shape[-1], activation="linear")(x)
  x = layers.Dropout(dropout)(x)
  
  return x + res

def create_vit_model(input_shape=(13,21,2),
                     patch_size=(3,7),
                     embed_dim=64,
                     num_heads=4,
                     ff_dim=128,
                     num_layers=4,
                     dropout=0.1,
                     final_outputs=14):
  # Input
  inp = layers.Input(shape=input_shape, name="raw_input")

  q_out = SoftQuantizeLayer(
      n_bits=2,
      initial_range=[-1.0, 1.0],
      trainable_levels=False,
      trainable_thresholds=True,
      initial_k=1.0,
      trainable_k=True,
      name="soft_quantizer_output"
  )(inp)

  # 1) Extract patches
  patches = PatchExtractor(patch_size=patch_size)(q_out)
  
  # Calculate how many patches we extracted:
  #   (H // patch_h) * (W // patch_w)
  # Must do it statically if possible:
  # e.g. 13//3=4, 21//7=3 => 12 patches total
  H, W, C = input_shape
  ph, pw  = patch_size
  num_patches = (H // ph) * (W // pw)

  # 2) Encode patches (linear projection + positional embedding)
  encoded_patches = PatchEncoder(num_patches, embed_dim)(patches)

  # 3) Apply multiple Transformer encoder blocks
  x = encoded_patches
  for _ in range(num_layers):
    x = transformer_encoder(x,
                            head_size=embed_dim,
                            num_heads=num_heads,
                            ff_dim=ff_dim,
                            dropout=dropout)
  
  # 4) Flatten and final Dense
  x = layers.LayerNormalization(epsilon=1e-6)(x)
  x = layers.Flatten()(x)
  x = layers.Dense(64, activation='relu')(x)
  outputs = layers.Dense(final_outputs, activation='linear')(x)

  # Create model
  model = keras.Model(inputs=inp, outputs=outputs)
  return model

model = create_vit_model(
    input_shape=(16,16,2),   
    patch_size=(3,4),        
    embed_dim=64,           
    num_heads=4,            
    ff_dim=128,              
    num_layers=4,            
    dropout=0.1,             
    final_outputs=14         
)


# model.summary()
# Out:
# 2025-09-17 07:52:23.810585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 35830 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB MIG 7g.40gb, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2025-09-17 07:52:24.166131: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory

# %%
model.compile(
    optimizer=tf.keras.optimizers.Nadam(learning_rate=1e-3, clipnorm=1.0),
    loss=custom_loss,
)

# %%
dataset_base_dir = "/depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/"

NOISE_MU = 0.0
NOISE_SIGMA = 400.0 # e-

tfrecords_base_dir = os.path.join(dataset_base_dir, "TFR_files", f"2t_N_{NOISE_MU}mu_{NOISE_SIGMA}sig")

dataset_train_dir = os.path.join(dataset_base_dir, "train")
dataset_test_dir = os.path.join(dataset_base_dir, "test")
tfrecords_dir_train = os.path.join(tfrecords_base_dir, "TFR_train")
tfrecords_dir_val   = os.path.join(tfrecords_base_dir, "TFR_val")

os.makedirs(dataset_train_dir, exist_ok=True)
os.makedirs(dataset_test_dir, exist_ok=True)
os.makedirs(tfrecords_dir_train, exist_ok=True)
os.makedirs(tfrecords_dir_val, exist_ok=True)


batch_size = 5000
val_batch_size = 5000
train_file_size = len(os.listdir(dataset_train_dir))
val_file_size = len(os.listdir(dataset_test_dir))

# %%
# start_time = time.time()
# validation_generator = OptimizedDataGenerator(
#     dataset_base_dir = dataset_test_dir,
#     file_type = "parquet",
#     data_format = "3D",
#     batch_size = val_batch_size,
#     # optimize_batch_size = True,
#     file_count = val_file_size,
#     to_standardize= True,
#     select_contained = True,
#     noise = [NOISE_MU,NOISE_SIGMA], #[mean, sigma]
#     min_threshold = None,
#     max_threshold = None,
#     labels_list = ['x-midplane','y-midplane','cotAlpha','cotBeta'],
#     input_shape = (2,16,16), # (20,13,21),
#     transpose = (0,2,3,1),
#     shuffle = False, 
#     files_from_end=True,

#     tfrecords_dir = tfrecords_dir_val,
#     use_time_stamps = [0,19],
#     max_workers = 2
# )

# print("--- Validation generator %s seconds ---" % (time.time() - start_time))

# # training generator
# start_time = time.time()
# training_generator = OptimizedDataGenerator(
#     dataset_base_dir = dataset_train_dir,
#     file_type = "parquet",
#     data_format = "3D",
#     batch_size = batch_size,
#     # optimize_batch_size = True,
#     file_count = train_file_size,
#     to_standardize= True,
#     select_contained = True,
#     noise = [NOISE_MU,NOISE_SIGMA], #[mean, sigma]
#     min_threshold = None,
#     max_threshold = None,
#     labels_list = ['x-midplane','y-midplane','cotAlpha','cotBeta'],
#     input_shape = (2,16,16), # (20,13,21),
#     transpose = (0,2,3,1),
#     shuffle = False, # True 

#     tfrecords_dir = tfrecords_dir_train,
#     use_time_stamps = [0,19],
#     max_workers = 2
# )
# print("--- Training generator %s seconds ---" % (time.time() - start_time))

# %%
# Loading pre-generated TFRecords
validation_generator = OptimizedDataGenerator(
    load_from_tfrecords_dir= tfrecords_dir_val,
    shuffle=True,
    seed=42,
    quantize=False,
)

training_generator = OptimizedDataGenerator(
    load_from_tfrecords_dir = tfrecords_dir_train,
    shuffle=True,
    seed=42,
    quantize=False,
)
# Out:
# WARNING:root:Quantization is False in data generator. This may affect model performance.
# Loading metadata from /depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/TFR_files/2t_N_0.0mu_400.0sig/TFR_val/metadata.json
# Loading metadata from /depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/TFR_files/2t_N_0.0mu_400.0sig/TFR_train/metadata.json
# WARNING:root:Quantization is False in data generator. This may affect model performance.

# %%
from datetime import datetime

fingerprint = '%08x' % random.randrange(16**8)
timestamp = datetime.now().strftime('%Y%m%d-%H%M%S')
os.makedirs("trained_models", exist_ok=True)

base_dir = f'/depot/cms/users/das214/SmartPixels/SoftQuantize/trained_models/Transformer_model-{fingerprint}-checkpoints'

checkpoints_dir = os.path.join(base_dir, 'checkpoints')

os.makedirs(base_dir, exist_ok=True)
os.makedirs(checkpoints_dir, exist_ok=True) 
checkpoint_filepath = os.path.join(checkpoints_dir, 'weights.{epoch:02d}-t{loss:.2f}-v{val_loss:.2f}.hdf5')

# %%
# 9f5e5c2c : 1000 epochs
print(fingerprint)
# Out:
# 915e0455

# %%
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, Callback
import csv

early_stopping_patience = 50
es = EarlyStopping(patience=early_stopping_patience, restore_best_weights=True)

mcp = ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
       save_freq='epoch'
)

class SoftQuantizeLoggerCallback(Callback):
    def __init__(self, log_filepath, layer_name="soft_quantizer_output"):
        super().__init__()
        self.log_filepath = log_filepath
        self.layer_name = layer_name
        self.header_written = False

    def on_train_begin(self, logs=None):
        os.makedirs(os.path.dirname(self.log_filepath), exist_ok=True)

    def on_epoch_end(self, epoch, logs=None):
        try:
            layer = self.model.get_layer(self.layer_name)
            if not hasattr(layer, 'n_bits'):
                 print(f"\nWarning: Layer '{self.layer_name}' is not a SoftQuantizeLayer. Skipping logging.")
                 return
        except ValueError:
            print(f"\nWarning: Layer '{self.layer_name}' not found in the model. Skipping logging.")
            return

        if not self.header_written:
            num_levels = layer.num_levels
            num_thresholds = num_levels - 1
            
            header = ['epoch', 'k']
            header.extend([f'level_{i}' for i in range(num_levels)])
            header.extend([f'threshold_{i}' for i in range(num_thresholds)])

            header.append('raw_first_level')
            header.extend([f'raw_log_level_delta_{i}' for i in range(num_levels - 1)])
            header.append('raw_first_threshold')
            if hasattr(layer, 'log_threshold_deltas'):
                header.extend([f'raw_log_threshold_delta_{i}' for i in range(num_thresholds - 1)])

            with open(self.log_filepath, mode='w', newline='') as f:
                writer = csv.writer(f)
                writer.writerow(header)
            self.header_written = True

        k_val = layer.k.numpy().item()
        levels = layer.levels.numpy().tolist()
        thresholds = layer.thresholds.numpy().tolist()
        
        first_level = layer.first_level.numpy().item()
        log_level_deltas = layer.log_level_deltas.numpy().tolist()
        first_threshold = layer.first_threshold.numpy().item()
        
        row_data = [epoch, k_val]
        row_data.extend(levels)
        row_data.extend(thresholds)
        row_data.append(first_level)
        row_data.extend(log_level_deltas)
        row_data.append(first_threshold)
        
        if hasattr(layer, 'log_threshold_deltas'):
            log_threshold_deltas = layer.log_threshold_deltas.numpy().tolist()
            row_data.extend(log_threshold_deltas)
        
        with open(self.log_filepath, mode='a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(row_data)


csv_logger = CSVLogger(f'{base_dir}/training_log.csv', append=True)
scheduler_callback = AnnealingScheduler(
    schedule='cosine',  
    target_layer_name='soft_quantizer_output', 
    initial_k=1.0,
    final_k=67.0, 
    verbose=1      
)

quantizer_logger = SoftQuantizeLoggerCallback(
    log_filepath=f"{base_dir}/soft_quantizer_state_log.csv", # New, more descriptive filename
    layer_name="soft_quantizer_output"
)

# %%
history = model.fit(
        x=training_generator,
        validation_data=validation_generator,
        callbacks=[mcp, csv_logger, scheduler_callback, quantizer_logger],
        epochs=1000,
        shuffle=False,
        verbose=1
    )
# Out:
# Epoch 1: Annealing 'k' set to 1.0000
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0000, 0.0000, 1.0000
# Epoch 1/1000
# 2025-09-17 07:52:36.569981: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x55c24758e330
# 2025-09-17 07:52:37.163065: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f138280adc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-09-17 07:52:37.163144: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-PCIE-40GB MIG 7g.40gb, Compute Capability 8.0
# 2025-09-17 07:52:37.176851: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-17 07:52:37.200091: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758088357.289748  976201 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 84/84 [==============================] - 31s 136ms/step - loss: 21774.9727 - val_loss: 14190.8213
#
# Epoch 2: Annealing 'k' set to 1.0002
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -1.0035, -0.0070, 0.9898
# Epoch 2/1000
# 84/84 [==============================] - 12s 137ms/step - loss: 13926.5527 - val_loss: 12636.3398
#
# Epoch 3: Annealing 'k' set to 1.0007
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9943, 0.0121, 1.0037
# Epoch 3/1000
# 84/84 [==============================] - 11s 131ms/step - loss: 12614.4844 - val_loss: 11509.3184
#
# Epoch 4: Annealing 'k' set to 1.0015
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9845, 0.0332, 1.0079
# Epoch 4/1000
# 84/84 [==============================] - 11s 131ms/step - loss: 11246.4580 - val_loss: 10156.9170
#
# Epoch 5: Annealing 'k' set to 1.0026
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9645, 0.0747, 1.0212
# Epoch 5/1000
# 84/84 [==============================] - 11s 130ms/step - loss: 10352.0508 - val_loss: 9621.7715
#
# Epoch 6: Annealing 'k' set to 1.0041
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9402, 0.1199, 1.0346
# Epoch 6/1000
# 84/84 [==============================] - 11s 131ms/step - loss: 9895.8896 - val_loss: 9238.7295
#
# Epoch 7: Annealing 'k' set to 1.0059
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.9151, 0.1646, 1.0459
# Epoch 7/1000
# 84/84 [==============================] - 11s 130ms/step - loss: 9463.4414 - val_loss: 8700.8545
#
# Epoch 8: Annealing 'k' set to 1.0080
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8935, 0.2046, 1.0513
# Epoch 8/1000
# 84/84 [==============================] - 12s 138ms/step - loss: 9109.7158 - val_loss: 8202.6797
#
# Epoch 9: Annealing 'k' set to 1.0104
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8652, 0.2529, 1.0610
# Epoch 9/1000
# 84/84 [==============================] - 11s 134ms/step - loss: 8702.8164 - val_loss: 7829.5400
#
# Epoch 10: Annealing 'k' set to 1.0132
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8404, 0.2902, 1.0586
# Epoch 10/1000
# 84/84 [==============================] - 11s 134ms/step - loss: 8239.1230 - val_loss: 7349.8320
#
# Epoch 11: Annealing 'k' set to 1.0163
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.8151, 0.3324, 1.0623
# Epoch 11/1000
# 84/84 [==============================] - 11s 132ms/step - loss: 7753.1958 - val_loss: 6734.4897
#
# Epoch 12: Annealing 'k' set to 1.0197
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7808, 0.3820, 1.0713
# Epoch 12/1000
# 84/84 [==============================] - 11s 136ms/step - loss: 7165.3052 - val_loss: 5972.0171
#
# Epoch 13: Annealing 'k' set to 1.0234
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7455, 0.4282, 1.0805
# Epoch 13/1000
# 84/84 [==============================] - 12s 139ms/step - loss: 6507.5679 - val_loss: 5313.4556
#
# Epoch 14: Annealing 'k' set to 1.0275
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.7127, 0.4641, 1.0804
# Epoch 14/1000
# 84/84 [==============================] - 11s 130ms/step - loss: 5763.8804 - val_loss: 4376.0195
#
# Epoch 15: Annealing 'k' set to 1.0319
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6847, 0.4927, 1.0759
# Epoch 15/1000
# 84/84 [==============================] - 11s 131ms/step - loss: 5016.9541 - val_loss: 3379.4797
#
# Epoch 16: Annealing 'k' set to 1.0366
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6553, 0.5227, 1.0727
# Epoch 16/1000
# 84/84 [==============================] - 11s 129ms/step - loss: 3932.4106 - val_loss: 2302.9421
#
# Epoch 17: Annealing 'k' set to 1.0417
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6308, 0.5515, 1.0764
# Epoch 17/1000
# 84/84 [==============================] - 11s 129ms/step - loss: 2798.3496 - val_loss: 789.7314
#
# Epoch 18: Annealing 'k' set to 1.0471
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.6035, 0.5857, 1.0895
# Epoch 18/1000
# 84/84 [==============================] - 11s 132ms/step - loss: 1251.5205 - val_loss: -674.0031
#
# Epoch 19: Annealing 'k' set to 1.0527
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.5762, 0.6116, 1.0931
# Epoch 19/1000
# 84/84 [==============================] - 11s 129ms/step - loss: -250.0836 - val_loss: -2498.9531
#
# Epoch 20: Annealing 'k' set to 1.0588
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.5555, 0.6397, 1.1065
# Epoch 20/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -1974.9119 - val_loss: -5017.7915
#
# Epoch 21: Annealing 'k' set to 1.0651
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.5317, 0.6716, 1.1251
# Epoch 21/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -4171.2212 - val_loss: -6983.4272
#
# Epoch 22: Annealing 'k' set to 1.0718
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.5169, 0.6976, 1.1424
# Epoch 22/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -5805.3662 - val_loss: -8406.5928
#
# Epoch 23: Annealing 'k' set to 1.0788
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.5074, 0.7123, 1.1485
# Epoch 23/1000
# 84/84 [==============================] - 11s 128ms/step - loss: -7132.4727 - val_loss: -9842.4736
#
# Epoch 24: Annealing 'k' set to 1.0861
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4960, 0.7292, 1.1573
# Epoch 24/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -8503.5312 - val_loss: -11823.6924
#
# Epoch 25: Annealing 'k' set to 1.0938
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4799, 0.7619, 1.1833
# Epoch 25/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -10073.6309 - val_loss: -13110.4385
#
# Epoch 26: Annealing 'k' set to 1.1017
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4707, 0.7856, 1.2034
# Epoch 26/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -11057.5869 - val_loss: -13360.0771
#
# Epoch 27: Annealing 'k' set to 1.1100
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4601, 0.8116, 1.2267
# Epoch 27/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -11251.2949 - val_loss: -13875.0957
#
# Epoch 28: Annealing 'k' set to 1.1186
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4558, 0.8198, 1.2284
# Epoch 28/1000
# 84/84 [==============================] - 11s 134ms/step - loss: -11396.6680 - val_loss: -13603.8730
#
# Epoch 29: Annealing 'k' set to 1.1276
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4456, 0.8309, 1.2301
# Epoch 29/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -11453.8994 - val_loss: -14074.0449
#
# Epoch 30: Annealing 'k' set to 1.1369
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4404, 0.8299, 1.2194
# Epoch 30/1000
# 84/84 [==============================] - 12s 137ms/step - loss: -11821.7588 - val_loss: -13832.1426
#
# Epoch 31: Annealing 'k' set to 1.1465
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4317, 0.8352, 1.2160
# Epoch 31/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -11639.0820 - val_loss: -14140.2822
#
# Epoch 32: Annealing 'k' set to 1.1564
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4263, 0.8373, 1.2104
# Epoch 32/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -11980.7207 - val_loss: -13769.3672
#
# Epoch 33: Annealing 'k' set to 1.1666
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4159, 0.8409, 1.2048
# Epoch 33/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -11646.9844 - val_loss: -13905.0957
#
# Epoch 34: Annealing 'k' set to 1.1772
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.4063, 0.8456, 1.1985
# Epoch 34/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -11957.7031 - val_loss: -13752.9971
#
# Epoch 35: Annealing 'k' set to 1.1881
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3994, 0.8436, 1.1875
# Epoch 35/1000
# 84/84 [==============================] - 11s 135ms/step - loss: -12266.3066 - val_loss: -14483.5664
#
# Epoch 36: Annealing 'k' set to 1.1993
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3896, 0.8434, 1.1791
# Epoch 36/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -12240.3203 - val_loss: -13719.2988
#
# Epoch 37: Annealing 'k' set to 1.2108
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3813, 0.8484, 1.1769
# Epoch 37/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -11718.3184 - val_loss: -13216.3076
#
# Epoch 38: Annealing 'k' set to 1.2227
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3698, 0.8584, 1.1787
# Epoch 38/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -11576.2324 - val_loss: -13251.7969
#
# Epoch 39: Annealing 'k' set to 1.2349
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3621, 0.8620, 1.1734
# Epoch 39/1000
# 84/84 [==============================] - 11s 129ms/step - loss: -11840.1045 - val_loss: -14152.0781
#
# Epoch 40: Annealing 'k' set to 1.2474
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3615, 0.8524, 1.1565
# Epoch 40/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -12158.7656 - val_loss: -14143.7256
#
# Epoch 41: Annealing 'k' set to 1.2602
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3572, 0.8503, 1.1466
# Epoch 41/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -12463.0674 - val_loss: -14121.4414
#
# Epoch 42: Annealing 'k' set to 1.2734
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3520, 0.8546, 1.1453
# Epoch 42/1000
# 84/84 [==============================] - 11s 134ms/step - loss: -12470.9873 - val_loss: -14256.1250
#
# Epoch 43: Annealing 'k' set to 1.2868
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3456, 0.8510, 1.1333
# Epoch 43/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -12533.1396 - val_loss: -13847.1250
#
# Epoch 44: Annealing 'k' set to 1.3006
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3402, 0.8513, 1.1291
# Epoch 44/1000
# 84/84 [==============================] - 12s 137ms/step - loss: -12805.0361 - val_loss: -14602.4639
#
# Epoch 45: Annealing 'k' set to 1.3148
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3347, 0.8459, 1.1174
# Epoch 45/1000
# 84/84 [==============================] - 12s 139ms/step - loss: -12993.8633 - val_loss: -14847.6475
#
# Epoch 46: Annealing 'k' set to 1.3292
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3302, 0.8396, 1.1054
# Epoch 46/1000
# 84/84 [==============================] - 12s 138ms/step - loss: -13234.8896 - val_loss: -15153.7188
#
# Epoch 47: Annealing 'k' set to 1.3440
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3234, 0.8388, 1.0964
# Epoch 47/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -13340.7412 - val_loss: -15051.1865
#
# Epoch 48: Annealing 'k' set to 1.3591
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3186, 0.8404, 1.0925
# Epoch 48/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -13124.7646 - val_loss: -15045.7969
#
# Epoch 49: Annealing 'k' set to 1.3745
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3067, 0.8437, 1.0889
# Epoch 49/1000
# 84/84 [==============================] - 11s 128ms/step - loss: -13243.7715 - val_loss: -14460.6357
#
# Epoch 50: Annealing 'k' set to 1.3902
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.3024, 0.8435, 1.0846
# Epoch 50/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -12997.3418 - val_loss: -14712.2168
#
# Epoch 51: Annealing 'k' set to 1.4063
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.2882, 0.8527, 1.0867
# Epoch 51/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -12749.7246 - val_loss: -14186.5303
#
# Epoch 52: Annealing 'k' set to 1.4227
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.2797, 0.8528, 1.0812
# Epoch 52/1000
# 84/84 [==============================] - 11s 135ms/step - loss: -12931.8506 - val_loss: -15098.9570
#
# Epoch 53: Annealing 'k' set to 1.4394
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.2698, 0.8459, 1.0666
# Epoch 53/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -13047.2109 - val_loss: -14763.4570
#
# Epoch 54: Annealing 'k' set to 1.4564
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.2610, 0.8528, 1.0681
# Epoch 54/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -12960.8652 - val_loss: -14750.1748
#
# Epoch 55: Annealing 'k' set to 1.4737
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.2544, 0.8524, 1.0622
# Epoch 55/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -12878.7949 - val_loss: -14702.4404
#
# Epoch 56: Annealing 'k' set to 1.4914
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.2434, 0.8517, 1.0551
# Epoch 56/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -13353.1914 - val_loss: -15049.9180
#
# Epoch 57: Annealing 'k' set to 1.5094
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.2368, 0.8456, 1.0434
# Epoch 57/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -13365.5742 - val_loss: -15157.1289
#
# Epoch 58: Annealing 'k' set to 1.5277
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.2280, 0.8435, 1.0372
# Epoch 58/1000
# 84/84 [==============================] - 13s 156ms/step - loss: -13571.7725 - val_loss: -14863.2578
#
# Epoch 59: Annealing 'k' set to 1.5463
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.2187, 0.8459, 1.0347
# Epoch 59/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -13416.9404 - val_loss: -14987.3193
#
# Epoch 60: Annealing 'k' set to 1.5653
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.2077, 0.8505, 1.0344
# Epoch 60/1000
# 84/84 [==============================] - 11s 129ms/step - loss: -13295.9678 - val_loss: -14549.4043
#
# Epoch 61: Annealing 'k' set to 1.5845
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.1952, 0.8520, 1.0313
# Epoch 61/1000
# 84/84 [==============================] - 12s 139ms/step - loss: -13447.0293 - val_loss: -15205.1484
#
# Epoch 62: Annealing 'k' set to 1.6041
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.1901, 0.8478, 1.0223
# Epoch 62/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -13707.8691 - val_loss: -15454.7812
#
# Epoch 63: Annealing 'k' set to 1.6240
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.1753, 0.8448, 1.0145
# Epoch 63/1000
# 84/84 [==============================] - 12s 138ms/step - loss: -13936.5088 - val_loss: -15652.3984
#
# Epoch 64: Annealing 'k' set to 1.6442
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.1675, 0.8389, 1.0049
# Epoch 64/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -13950.0742 - val_loss: -15162.9971
#
# Epoch 65: Annealing 'k' set to 1.6648
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.1490, 0.8491, 1.0093
# Epoch 65/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -13846.9590 - val_loss: -15217.1855
#
# Epoch 66: Annealing 'k' set to 1.6856
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.1375, 0.8467, 1.0002
# Epoch 66/1000
# 84/84 [==============================] - 11s 136ms/step - loss: -13662.2715 - val_loss: -14946.1982
#
# Epoch 67: Annealing 'k' set to 1.7068
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.1258, 0.8520, 1.0010
# Epoch 67/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -13421.8184 - val_loss: -14772.4971
#
# Epoch 68: Annealing 'k' set to 1.7283
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.1062, 0.8557, 1.0005
# Epoch 68/1000
# 84/84 [==============================] - 11s 129ms/step - loss: -13397.8096 - val_loss: -14986.1611
#
# Epoch 69: Annealing 'k' set to 1.7502
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.0932, 0.8513, 0.9918
# Epoch 69/1000
# 84/84 [==============================] - 11s 134ms/step - loss: -13748.3154 - val_loss: -14680.4199
#
# Epoch 70: Annealing 'k' set to 1.7723
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.0739, 0.8542, 0.9900
# Epoch 70/1000
# 84/84 [==============================] - 12s 148ms/step - loss: -13541.0156 - val_loss: -15310.7900
#
# Epoch 71: Annealing 'k' set to 1.7947
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.0653, 0.8514, 0.9833
# Epoch 71/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -13848.6680 - val_loss: -15466.5039
#
# Epoch 72: Annealing 'k' set to 1.8175
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.0538, 0.8490, 0.9777
# Epoch 72/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -13981.3574 - val_loss: -15589.4482
#
# Epoch 73: Annealing 'k' set to 1.8406
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.0417, 0.8483, 0.9742
# Epoch 73/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -14031.9258 - val_loss: -15459.8721
#
# Epoch 74: Annealing 'k' set to 1.8640
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: -0.0237, 0.8482, 0.9699
# Epoch 74/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -13786.6680 - val_loss: -15050.2617
#
# Epoch 75: Annealing 'k' set to 1.8877
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.0006, 0.8539, 0.9712
# Epoch 75/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -13718.6113 - val_loss: -14940.0557
#
# Epoch 76: Annealing 'k' set to 1.9118
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.0161, 0.8564, 0.9700
# Epoch 76/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -13911.9697 - val_loss: -15592.7168
#
# Epoch 77: Annealing 'k' set to 1.9362
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.0221, 0.8498, 0.9607
# Epoch 77/1000
# 84/84 [==============================] - 11s 136ms/step - loss: -14210.0811 - val_loss: -15565.6592
#
# Epoch 78: Annealing 'k' set to 1.9608
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.0342, 0.8512, 0.9601
# Epoch 78/1000
# 84/84 [==============================] - 11s 129ms/step - loss: -14230.4434 - val_loss: -15674.8965
#
# Epoch 79: Annealing 'k' set to 1.9858
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.0457, 0.8486, 0.9548
# Epoch 79/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -14201.5625 - val_loss: -15247.2051
#
# Epoch 80: Annealing 'k' set to 2.0111
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.0646, 0.8531, 0.9563
# Epoch 80/1000
# 84/84 [==============================] - 11s 134ms/step - loss: -14223.3721 - val_loss: -15680.7676
#
# Epoch 81: Annealing 'k' set to 2.0368
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.0800, 0.8512, 0.9514
# Epoch 81/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -14062.0869 - val_loss: -15581.4160
#
# Epoch 82: Annealing 'k' set to 2.0627
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.0966, 0.8526, 0.9497
# Epoch 82/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -14054.0293 - val_loss: -15329.6357
#
# Epoch 83: Annealing 'k' set to 2.0890
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.1168, 0.8537, 0.9475
# Epoch 83/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -14372.4014 - val_loss: -15773.3613
#
# Epoch 84: Annealing 'k' set to 2.1155
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.1299, 0.8492, 0.9405
# Epoch 84/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -14692.8936 - val_loss: -16186.3174
#
# Epoch 85: Annealing 'k' set to 2.1424
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.1357, 0.8462, 0.9354
# Epoch 85/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -14541.0615 - val_loss: -15700.5996
#
# Epoch 86: Annealing 'k' set to 2.1696
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.1581, 0.8525, 0.9385
# Epoch 86/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -14343.0469 - val_loss: -15599.6074
#
# Epoch 87: Annealing 'k' set to 2.1971
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.1791, 0.8544, 0.9368
# Epoch 87/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -14500.6201 - val_loss: -15795.4072
#
# Epoch 88: Annealing 'k' set to 2.2249
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.1886, 0.8480, 0.9272
# Epoch 88/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -15117.3389 - val_loss: -16199.9697
#
# Epoch 89: Annealing 'k' set to 2.2531
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.1982, 0.8459, 0.9226
# Epoch 89/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -15115.1973 - val_loss: -16398.4375
#
# Epoch 90: Annealing 'k' set to 2.2815
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.2165, 0.8461, 0.9198
# Epoch 90/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -15126.0312 - val_loss: -16198.0000
#
# Epoch 91: Annealing 'k' set to 2.3103
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.2330, 0.8473, 0.9181
# Epoch 91/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -15191.3672 - val_loss: -16731.1973
#
# Epoch 92: Annealing 'k' set to 2.3394
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.2397, 0.8440, 0.9131
# Epoch 92/1000
# 84/84 [==============================] - 11s 132ms/step - loss: -15251.5010 - val_loss: -16475.4121
#
# Epoch 93: Annealing 'k' set to 2.3688
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.2540, 0.8472, 0.9147
# Epoch 93/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -15187.9004 - val_loss: -16717.1562
#
# Epoch 94: Annealing 'k' set to 2.3985
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.2608, 0.8407, 0.9066
# Epoch 94/1000
# 84/84 [==============================] - 11s 133ms/step - loss: -15603.7607 - val_loss: -16598.0098
#
# Epoch 95: Annealing 'k' set to 2.4285
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.2737, 0.8443, 0.9087
# Epoch 95/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -15516.1396 - val_loss: -17102.5449
#
# Epoch 96: Annealing 'k' set to 2.4588
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.2799, 0.8405, 0.9037
# Epoch 96/1000
# 84/84 [==============================] - 11s 134ms/step - loss: -15556.3633 - val_loss: -16474.4434
#
# Epoch 97: Annealing 'k' set to 2.4895
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.2983, 0.8449, 0.9062
# Epoch 97/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -15143.3076 - val_loss: -16226.2441
#
# Epoch 98: Annealing 'k' set to 2.5204
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.3188, 0.8505, 0.9098
# Epoch 98/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -15383.5762 - val_loss: -16825.7715
#
# Epoch 99: Annealing 'k' set to 2.5517
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.3279, 0.8459, 0.9038
# Epoch 99/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -15680.8643 - val_loss: -17040.1426
#
# Epoch 100: Annealing 'k' set to 2.5833
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.3409, 0.8434, 0.8995
# Epoch 100/1000
# 84/84 [==============================] - 11s 135ms/step - loss: -15710.6035 - val_loss: -17109.5234
#
# Epoch 101: Annealing 'k' set to 2.6151
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.3545, 0.8429, 0.8967
# Epoch 101/1000
# 84/84 [==============================] - 11s 131ms/step - loss: -15695.4688 - val_loss: -16688.6328
#
# Epoch 102: Annealing 'k' set to 2.6473
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.3677, 0.8464, 0.8985
# Epoch 102/1000
# 84/84 [==============================] - 11s 129ms/step - loss: -15583.4316 - val_loss: -16700.0215
#
# Epoch 103: Annealing 'k' set to 2.6798
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.3808, 0.8488, 0.8997
# Epoch 103/1000
# 84/84 [==============================] - 11s 130ms/step - loss: -15544.7861 - val_loss: -16621.9492
#
# Epoch 104: Annealing 'k' set to 2.7126
# 	Levels: -1.0000, -0.3333, 0.3333, 1.0000
# 	Thresholds: 0.3913, 0.8483, 0.8979
# Epoch 104/1000
# 14/84 [====>.........................] - ETA: 7s - loss: -15560.4482

# %%
sq_layer = model.get_layer(name="soft_quantizer_output")
print(f"Successfully retrieved layer: '{sq_layer.name}'\n")


print("="*50)
print("1. LAYER CONFIGURATION")
print("="*50)
config = sq_layer.get_config()
for key, value in config.items():
    print(f"- {key}: {value}")

print("\n" + "="*50)
print("2. CURRENT QUANTIZER STATE (DERIVED)")
print("="*50)

print(f"- Current k value: {sq_layer.k.numpy().item():.4f}") 
print(f"- Current Levels: {sq_layer.levels.numpy()}")
print(f"- Current Thresholds: {sq_layer.thresholds.numpy()}")

print("\n" + "="*50)
print("3. UNDERLYING RAW WEIGHTS")
print("="*50)
print(f"- log_k: {sq_layer.log_k.numpy().item():.4f}")
print(f"- first_level: {sq_layer.first_level.numpy()}")
print(f"- log_level_deltas: {sq_layer.log_level_deltas.numpy()}")
print(f"- first_threshold: {sq_layer.first_threshold.numpy()}")

if hasattr(sq_layer, 'log_threshold_deltas'):
    print(f"- log_threshold_deltas: {sq_layer.log_threshold_deltas.numpy()}")
else:
    print("- log_threshold_deltas: (Not present, expected for n_bits=1)")
    
print("\n" + "="*50)
print("4. KERAS WEIGHT STATUS")
print("="*50)
if sq_layer.trainable_weights:
    print("Trainable Weights:")
    for weight in sq_layer.trainable_weights:
        print(f"  - {weight.name}: shape={weight.shape.as_list()}")
else:
    print("This layer has no trainable weights.")

if sq_layer.non_trainable_weights:
    print("\nNon-Trainable Weights:")
    for weight in sq_layer.non_trainable_weights:
        print(f"  - {weight.name}: shape={weight.shape.as_list()}")
else:
    print("\nThis layer has no non-trainable weights.")
