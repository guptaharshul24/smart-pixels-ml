# %%
import os
import tensorflow as tf
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras import layers, models

from DG.OptimizedDataGenerator_v2 import OptimizedDataGenerator
from losses.loss import custom_loss
from models.SoftQuantizeLayer import SoftQuantizeLayer

pi = 3.14159265359

maxval=1e9
minval=1e-9

# %%
import keras
from keras.layers import *
from keras.models import Sequential, Model
from keras.utils import Sequence
from qkeras import *

import tensorflow as tf
from tensorflow.keras import datasets, layers, models

def var_network(var, hidden=10, output=2):
    var = Flatten()(var)
    var = QDense(
        hidden,
        kernel_quantizer=quantized_bits(8, 0, alpha=1),
        bias_quantizer=quantized_bits(8, 0, alpha=1),
        kernel_regularizer=tf.keras.regularizers.L1L2(0.01),
        activity_regularizer=tf.keras.regularizers.L2(0.01),
    )(var)
    var = QActivation("quantized_tanh(8, 0, 1)")(var)
    var = QDense(
        hidden,
        kernel_quantizer=quantized_bits(8, 0, alpha=1),
        bias_quantizer=quantized_bits(8, 0, alpha=1),
        kernel_regularizer=tf.keras.regularizers.L1L2(0.01),
        activity_regularizer=tf.keras.regularizers.L2(0.01),
    )(var)
    var = QActivation("quantized_tanh(8, 0, 1)")(var)
    return QDense(
        output,
        kernel_quantizer=quantized_bits(8, 0, alpha=1),
        bias_quantizer=quantized_bits(8, 0, alpha=1),
        kernel_regularizer=tf.keras.regularizers.L1L2(0.01),
    )(var)

def conv_network(var, n_filters=5, kernel_size=3):
    var = QSeparableConv2D(
        n_filters,kernel_size,
        depthwise_quantizer=quantized_bits(4, 0, 1, alpha=1),
        pointwise_quantizer=quantized_bits(4, 0, 1, alpha=1),
        bias_quantizer=quantized_bits(4, 0, alpha=1),
        depthwise_regularizer=tf.keras.regularizers.L1L2(0.01),
        pointwise_regularizer=tf.keras.regularizers.L1L2(0.01),
        activity_regularizer=tf.keras.regularizers.L2(0.01),
    )(var)
    var = QActivation("quantized_tanh(4, 0, 1)")(var)
    var = QConv2D(
        n_filters,1,
        kernel_quantizer=quantized_bits(4, 0, alpha=1),
        bias_quantizer=quantized_bits(4, 0, alpha=1),
        kernel_regularizer=tf.keras.regularizers.L1L2(0.01),
        activity_regularizer=tf.keras.regularizers.L2(0.01),
    )(var)
    var = QActivation("quantized_tanh(4, 0, 1)")(var)    
    return var

def CreateModel(shape, output, n_filters, pool_size):
    x_base = x_in = Input(shape)
    x_base = SoftQuantizeLayer(
        levels=(-1.0, -0.5, 0.0, 0.5),
        initial_k=1.0,
        name='soft_quantizer_output' 
    )(x_base)

    stack = conv_network(x_base)
    stack = AveragePooling2D(
        pool_size=(pool_size, pool_size), 
        strides=None, 
        padding="valid", 
        data_format=None,        
    )(stack)
    stack = QActivation("quantized_bits(8, 0, alpha=1)")(stack)
    stack = var_network(stack, hidden=16, output=output)
    model = Model(inputs=x_in, outputs=stack)
    return model

# %%
model=CreateModel(shape = (16,16,2), output = 14, n_filters=5,pool_size=3)
model.compile(
    optimizer=tf.keras.optimizers.Nadam(learning_rate=1e-3, clipnorm=1.0),
    loss=custom_loss,
)

model.summary()
# Out:
# 2025-07-16 17:25:50.186928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 37080 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB MIG 7g.40gb, pci bus id: 0000:21:00.0, compute capability: 8.0
# 2025-07-16 17:25:50.392894: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 16, 16, 2)]       0
#
#  soft_quantizer_output (Sof  (None, 16, 16, 2)         1
#  tQuantizeLayer)
#
#  q_separable_conv2d (QSepar  (None, 14, 14, 5)         33
#  ableConv2D)
#
#  q_activation (QActivation)  (None, 14, 14, 5)         0
#
#  q_conv2d (QConv2D)          (None, 14, 14, 5)         30
#
#  q_activation_1 (QActivatio  (None, 14, 14, 5)         0
#  n)
#
#  average_pooling2d (Average  (None, 4, 4, 5)           0
#  Pooling2D)
#
#  q_activation_2 (QActivatio  (None, 4, 4, 5)           0
#  n)
#
#  flatten (Flatten)           (None, 80)                0
#
#  q_dense (QDense)            (None, 16)                1296
#
#  q_activation_3 (QActivatio  (None, 16)                0
#  n)
#
#  q_dense_1 (QDense)          (None, 16)                272
#
#  q_activation_4 (QActivatio  (None, 16)                0
#  n)
#
#  q_dense_2 (QDense)          (None, 14)                238
#
# =================================================================
# Total params: 1870 (7.30 KB)
# Trainable params: 1869 (7.30 KB)
# Non-trainable params: 1 (4.00 Byte)
# _________________________________________________________________

# %%
fingerprint = "9f5e5c2c"
# model-6fe6ea98-checkpoints

# %%
base_dir = f'./trained_models/model-{fingerprint}-checkpoints'
plot_dir = os.path.join(base_dir, 'plots')
checkpoints_dir = os.path.join(base_dir, 'checkpoints')
training_cp_path = os.path.join(base_dir, 'training_log.csv')
training_history = pd.read_csv(training_cp_path)

os.makedirs(plot_dir, exist_ok=True)

checkpoint_files = sorted([os.path.join(checkpoints_dir, f) for f in os.listdir(checkpoints_dir) if f.endswith('.hdf5')])
checkpoint_files
# Out:
# ['./trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.01-t48061.31-v13497.59.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.02-t10157.54-v7415.83.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.03-t4373.79-v1336.65.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.04-t653.06-v-1.05.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.05-t-615.59-v-1480.89.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.06-t5236.47-v63052.64.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.07-t7041.03-v-103.24.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.08-t2262.39-v57803.99.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.09-t1855.83-v-1948.55.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.10-t-3102.42-v-3114.30.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.100-t-12787.23-v-13322.21.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.1000-t-22584.27-v-22974.91.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.101-t-13122.60-v-12923.51.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.102-t-13220.68-v-13157.13.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.103-t-13362.24-v-13541.06.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.104-t-13152.83-v-13866.10.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.105-t-13511.32-v-13756.66.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.106-t-13495.68-v-13820.87.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.107-t-13518.51-v-13894.35.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.108-t-13224.58-v-13277.46.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.109-t-13597.69-v-13682.94.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.11-t4819.90-v60047.16.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.110-t-13710.90-v-14092.76.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.111-t-13854.24-v-14021.91.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.112-t-13820.03-v-13687.61.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.113-t-13920.02-v-14045.79.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.114-t-12813.61-v-13568.21.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.115-t-12835.89-v-13588.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.116-t-12953.72-v-14073.13.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.117-t-13697.92-v-13383.06.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.118-t-13131.78-v-13202.53.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.119-t-13705.00-v-13904.41.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.12-t639.23-v-2505.88.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.120-t-13876.19-v-14643.40.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.121-t-13995.70-v-14477.17.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.122-t-13776.13-v-14226.73.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.123-t-13385.89-v-14300.66.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.124-t-13707.67-v-14396.60.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.125-t-13018.71-v-13765.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.126-t-13434.20-v-13701.95.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.127-t-13434.83-v-14278.12.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.128-t-13723.47-v-13610.10.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.129-t-13421.00-v-9814.50.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.13-t-3602.61-v-4006.02.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.130-t-13223.95-v-9045.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.131-t-13805.51-v-13182.88.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.132-t-13816.65-v-14779.04.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.133-t-13527.95-v-14086.63.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.134-t-13468.19-v-14595.01.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.135-t-14238.52-v-14746.51.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.136-t-14139.35-v-14821.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.137-t-13677.36-v-14310.72.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.138-t-13785.59-v-13977.00.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.139-t-14255.23-v-13841.47.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.14-t1799.03-v-4078.47.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.140-t-14058.35-v-14694.83.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.141-t-14145.16-v-14782.36.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.142-t-14434.36-v-14007.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.143-t-13986.19-v-14643.12.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.144-t-13824.13-v-12009.47.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.145-t-13943.36-v-13543.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.146-t-14173.03-v-14299.45.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.147-t-14236.17-v-14442.79.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.148-t-14169.38-v-14339.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.149-t-14368.57-v-14499.04.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.15-t-1547.33-v-3654.93.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.150-t-13917.60-v-14747.26.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.151-t-14199.23-v-14081.08.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.152-t-14474.74-v-13017.97.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.153-t-14475.29-v-15692.86.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.154-t-14472.75-v-13063.73.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.155-t-14413.64-v-13920.05.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.156-t-14409.43-v-14671.98.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.157-t-14407.61-v-14374.22.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.158-t-14416.74-v-14954.83.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.159-t-14822.45-v-15070.06.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.16-t-4066.32-v-4717.88.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.160-t-15279.67-v-15474.02.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.161-t-15331.16-v-15385.90.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.162-t-14807.36-v-15259.05.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.163-t-14952.07-v-14840.39.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.164-t-14934.96-v-15501.87.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.165-t-15169.03-v-14596.51.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.166-t-15071.20-v-13600.55.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.167-t-14987.50-v-13720.32.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.168-t-14965.64-v-14947.53.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.169-t-15326.40-v-15675.56.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.17-t-4692.69-v-4774.02.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.170-t-15678.23-v-15859.04.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.171-t-15747.79-v-16132.02.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.172-t-15772.05-v-15689.57.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.173-t-15873.38-v-15987.61.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.174-t-15883.84-v-16538.61.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.175-t-16062.98-v-16680.55.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.176-t-16243.97-v-15331.42.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.177-t-16034.87-v-16047.91.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.178-t-16107.23-v-16230.25.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.179-t-16122.80-v-16514.01.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.18-t-4939.40-v-5228.62.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.180-t-16254.00-v-16314.03.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.181-t-14382.92-v-15223.65.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.182-t-15269.48-v-15155.00.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.183-t-15483.98-v-15051.80.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.184-t-15466.36-v-16291.86.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.185-t-15753.58-v-16372.80.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.186-t-15735.03-v-15268.30.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.187-t-15713.91-v-15298.28.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.188-t-16215.88-v-17109.16.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.189-t-16347.04-v-16664.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.19-t-2434.88-v-5012.50.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.190-t-16443.82-v-15928.59.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.191-t-16560.33-v-15650.28.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.192-t-17025.98-v-15077.46.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.193-t-16968.76-v-17146.00.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.194-t-16924.40-v-16622.63.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.195-t-16796.79-v-17177.79.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.196-t-15972.59-v-16455.64.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.197-t-15877.86-v-14296.55.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.198-t-15840.26-v-15538.91.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.199-t-16020.32-v-15338.02.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.20-t-5694.67-v-6434.75.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.200-t-16183.17-v-15673.92.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.201-t-16724.58-v-17037.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.202-t-16553.76-v-15815.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.203-t-16438.17-v-17097.61.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.204-t-16955.60-v-17566.43.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.205-t-17206.87-v-17659.53.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.206-t-17276.29-v-17961.24.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.207-t-17220.62-v-16063.38.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.208-t-16951.17-v-17576.43.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.209-t-16998.23-v-16995.10.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.21-t-6668.08-v-7607.64.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.210-t-16778.22-v-15806.81.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.211-t-17111.34-v-17186.46.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.212-t-16895.57-v-17711.13.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.213-t-16511.22-v-16568.77.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.214-t-16488.28-v-17283.58.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.215-t-16780.78-v-16865.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.216-t-16797.65-v-16980.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.217-t-17113.13-v-18028.17.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.218-t-16959.74-v-16904.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.219-t-16892.99-v-17055.48.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.22-t-7419.61-v-7799.84.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.220-t-17211.18-v-17270.45.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.221-t-17294.63-v-17575.10.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.222-t-17187.64-v-16809.00.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.223-t-17233.92-v-17499.77.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.224-t-17426.10-v-17832.42.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.225-t-17312.55-v-16983.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.226-t-17419.25-v-17169.72.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.227-t-17398.61-v-16816.35.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.228-t-17677.15-v-17206.34.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.229-t-17575.75-v-17819.55.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.23-t-8234.95-v-8518.58.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.230-t-17818.72-v-17336.66.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.231-t-17719.44-v-17784.81.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.232-t-17782.01-v-18281.64.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.233-t-17825.22-v-17256.10.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.234-t-17879.25-v-18515.54.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.235-t-17732.43-v-16803.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.236-t-17948.21-v-17473.70.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.237-t-17860.79-v-17419.19.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.238-t-17832.37-v-18036.61.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.239-t-18184.77-v-17235.38.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.24-t-8685.53-v-9107.90.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.240-t-18419.41-v-17899.66.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.241-t-18507.04-v-18462.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.242-t-18497.02-v-18952.49.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.243-t-18512.02-v-18241.40.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.244-t-18544.34-v-18819.69.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.245-t-18742.89-v-18962.68.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.246-t-18708.83-v-18949.93.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.247-t-18495.33-v-18539.77.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.248-t-18728.89-v-18666.89.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.249-t-17227.07-v-18897.30.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.25-t-7499.47-v-9180.62.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.250-t-18145.73-v-18145.84.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.251-t-18251.44-v-18082.24.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.252-t-18484.54-v-18540.40.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.253-t-18417.32-v-18890.83.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.254-t-18115.51-v-17570.03.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.255-t-18291.72-v-19093.48.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.256-t-18351.76-v-19328.63.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.257-t-18062.18-v-18548.83.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.258-t-18567.98-v-18330.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.259-t-18659.31-v-19457.46.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.26-t-8649.06-v-7237.17.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.260-t-18655.68-v-17966.46.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.261-t-18909.40-v-18840.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.262-t-18843.29-v-19350.88.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.263-t-19050.50-v-18994.77.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.264-t-19038.08-v-19938.95.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.265-t-17732.59-v-13754.43.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.266-t-18175.64-v-18449.25.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.267-t-18564.95-v-18083.07.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.268-t-18704.21-v-17425.63.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.269-t-18783.81-v-18642.35.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.27-t-9018.92-v-8905.55.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.270-t-18813.88-v-18777.21.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.271-t-19006.29-v-19104.53.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.272-t-18705.10-v-19632.42.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.273-t-18861.50-v-18216.09.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.274-t-18888.01-v-19549.15.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.275-t-19105.18-v-18699.07.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.276-t-19002.04-v-20047.98.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.277-t-19282.37-v-19267.80.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.278-t-18822.33-v-19319.73.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.279-t-19087.62-v-19344.86.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.28-t-9600.77-v-8941.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.280-t-19353.19-v-18752.96.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.281-t-19008.21-v-18842.91.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.282-t-19572.65-v-19771.40.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.283-t-19357.46-v-18590.95.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.284-t-19076.43-v-18630.04.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.285-t-19229.06-v-19344.35.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.286-t-19297.53-v-19499.12.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.287-t-19270.29-v-19502.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.288-t-19026.70-v-17936.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.289-t-19389.85-v-20334.54.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.29-t-9912.77-v-9225.50.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.290-t-19942.86-v-20855.41.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.291-t-19646.11-v-20574.42.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.292-t-19826.68-v-19880.90.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.293-t-19962.80-v-20683.82.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.294-t-20232.34-v-20560.60.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.295-t-19901.76-v-18544.53.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.296-t-19647.07-v-20362.26.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.297-t-20023.17-v-18373.72.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.298-t-20004.36-v-20975.96.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.299-t-20086.31-v-20563.00.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.30-t-9907.81-v-9467.63.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.300-t-19981.18-v-19240.35.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.301-t-19553.97-v-18830.75.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.302-t-19836.98-v-20010.36.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.303-t-20042.44-v-17959.94.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.304-t-20121.54-v-21051.30.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.305-t-20379.40-v-19643.13.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.306-t-20002.02-v-19746.39.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.307-t-20042.56-v-19683.18.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.308-t-19948.79-v-19935.92.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.309-t-19951.03-v-19863.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.31-t-9789.97-v-9560.17.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.310-t-20073.71-v-18754.68.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.311-t-19882.49-v-19089.77.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.312-t-19735.91-v-20120.01.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.313-t-19249.86-v-19125.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.314-t-19235.30-v-19662.17.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.315-t-19379.05-v-19411.51.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.316-t-19374.29-v-19889.12.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.317-t-19383.48-v-20301.77.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.318-t-20007.14-v-20724.21.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.319-t-19760.44-v-20568.69.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.32-t-9194.42-v-7941.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.320-t-19639.29-v-19571.98.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.321-t-19655.30-v-19091.52.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.322-t-19730.83-v-19188.87.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.323-t-19660.56-v-20287.75.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.324-t-19771.38-v-20492.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.325-t-19923.75-v-20147.15.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.326-t-19848.15-v-20258.54.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.327-t-19871.44-v-19984.18.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.328-t-19849.62-v-20631.93.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.329-t-20183.54-v-21280.22.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.33-t-8988.14-v-9636.76.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.330-t-20524.26-v-20687.88.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.331-t-20551.07-v-19118.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.332-t-19707.37-v-20627.81.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.333-t-19782.36-v-20246.00.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.334-t-19784.47-v-19884.15.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.335-t-19864.30-v-20679.03.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.336-t-20307.08-v-19467.55.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.337-t-20556.73-v-20682.93.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.338-t-20409.48-v-19716.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.339-t-20653.84-v-20043.24.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.34-t-9894.82-v-10154.38.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.340-t-20240.35-v-20792.49.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.341-t-20351.55-v-20865.72.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.342-t-20053.90-v-19058.97.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.343-t-19927.31-v-19428.84.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.344-t-20010.14-v-19481.32.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.345-t-20361.48-v-19984.14.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.346-t-20425.29-v-20683.23.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.347-t-20412.60-v-20074.32.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.348-t-20468.80-v-21043.40.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.349-t-20725.70-v-21316.02.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.35-t-10042.53-v-10366.68.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.350-t-20524.88-v-21461.61.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.351-t-20623.29-v-21514.93.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.352-t-20703.71-v-21060.75.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.353-t-20534.08-v-19652.66.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.354-t-20370.35-v-19031.01.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.355-t-20176.94-v-20248.66.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.356-t-20430.04-v-20276.81.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.357-t-20518.94-v-21049.01.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.358-t-20809.15-v-20373.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.359-t-20733.67-v-21177.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.36-t-10297.31-v-9896.58.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.360-t-20798.29-v-18879.49.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.361-t-20930.70-v-21071.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.362-t-21037.43-v-21688.63.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.363-t-20648.60-v-19411.34.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.364-t-20800.32-v-20787.57.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.365-t-20568.90-v-20549.84.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.366-t-21291.83-v-21370.60.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.367-t-21251.04-v-19337.01.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.368-t-20765.56-v-21949.10.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.369-t-21220.28-v-21625.42.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.37-t-9811.80-v-9248.61.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.370-t-21250.62-v-21088.77.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.371-t-21168.19-v-21177.16.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.372-t-20848.45-v-20754.80.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.373-t-20915.96-v-20792.28.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.374-t-20754.35-v-20695.05.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.375-t-20821.80-v-21818.60.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.376-t-21110.20-v-21174.57.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.377-t-21088.64-v-21228.62.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.378-t-21119.93-v-22024.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.379-t-21253.96-v-20783.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.38-t-9765.53-v-10462.65.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.380-t-21218.19-v-20779.95.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.381-t-21228.17-v-21645.39.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.382-t-21489.19-v-20353.18.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.383-t-20547.82-v-20591.50.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.384-t-20701.11-v-20831.88.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.385-t-20787.54-v-20524.12.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.386-t-20530.72-v-17460.63.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.387-t-20530.00-v-20971.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.388-t-20618.80-v-21147.09.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.389-t-20704.89-v-18144.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.39-t-10311.25-v-10866.38.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.390-t-20710.31-v-22122.35.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.391-t-21023.93-v-19979.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.392-t-20754.95-v-20087.75.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.393-t-20584.61-v-14110.45.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.394-t-20069.14-v-21466.40.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.395-t-21110.59-v-21070.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.396-t-21212.09-v-19870.59.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.397-t-20411.11-v-21244.59.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.398-t-20786.33-v-20275.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.399-t-20760.60-v-21130.19.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.40-t-10733.14-v-10433.36.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.400-t-20848.55-v-20808.04.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.401-t-20958.67-v-18988.79.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.402-t-20687.64-v-22010.67.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.403-t-20820.22-v-21023.14.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.404-t-20973.05-v-21451.99.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.405-t-20579.46-v-21552.43.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.406-t-20658.77-v-20944.00.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.407-t-20713.73-v-20580.86.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.408-t-20719.22-v-21105.64.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.409-t-20784.62-v-20583.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.41-t-10830.61-v-11140.06.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.410-t-20711.89-v-19566.98.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.411-t-20934.06-v-21875.41.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.412-t-20714.75-v-20364.67.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.413-t-20891.48-v-21261.05.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.414-t-21151.48-v-21275.60.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.415-t-21422.68-v-21401.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.416-t-21069.70-v-20555.49.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.417-t-21115.40-v-19824.33.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.418-t-21151.17-v-20528.34.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.419-t-21139.54-v-21177.51.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.42-t-10861.76-v-10884.08.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.420-t-21062.43-v-21863.78.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.421-t-21401.81-v-21249.28.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.422-t-21131.08-v-20988.34.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.423-t-21186.19-v-21444.42.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.424-t-21211.03-v-22426.43.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.425-t-21424.79-v-22004.55.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.426-t-21260.71-v-21261.33.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.427-t-21408.08-v-21764.06.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.428-t-20703.56-v-20740.71.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.429-t-21363.48-v-22220.03.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.43-t-11120.32-v-11421.22.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.430-t-21554.00-v-22286.28.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.431-t-21750.82-v-20966.62.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.432-t-21485.03-v-22154.62.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.433-t-21440.97-v-22354.62.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.434-t-21777.92-v-21418.38.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.435-t-21513.72-v-21341.26.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.436-t-21576.15-v-20825.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.437-t-21608.02-v-22174.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.438-t-21782.85-v-22054.07.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.439-t-21986.38-v-21510.14.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.44-t-11250.43-v-11257.48.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.440-t-22265.10-v-22146.62.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.441-t-21961.29-v-22107.46.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.442-t-21854.45-v-22722.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.443-t-21726.60-v-22494.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.444-t-21944.88-v-22779.48.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.445-t-21849.05-v-22598.04.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.446-t-21866.75-v-22106.51.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.447-t-22053.83-v-21030.13.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.448-t-21736.99-v-21828.78.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.449-t-21612.63-v-20901.04.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.45-t-11312.12-v-11093.23.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.450-t-21755.83-v-22176.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.451-t-21784.03-v-20928.39.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.452-t-22205.43-v-21871.14.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.453-t-22104.60-v-21964.52.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.454-t-21917.42-v-21655.84.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.455-t-21866.17-v-21493.32.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.456-t-21791.11-v-22170.69.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.457-t-21861.18-v-22241.66.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.458-t-21929.20-v-22291.13.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.459-t-21803.13-v-21638.65.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.46-t-11385.13-v-10870.29.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.460-t-21974.22-v-22215.18.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.461-t-21969.01-v-22175.16.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.462-t-22048.12-v-22251.82.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.463-t-22107.47-v-19988.70.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.464-t-21177.76-v-21274.50.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.465-t-21232.36-v-20963.06.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.466-t-21356.00-v-21543.87.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.467-t-21402.89-v-20967.68.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.468-t-21656.52-v-21397.04.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.469-t-21561.94-v-22546.74.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.47-t-11206.37-v-11151.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.470-t-21311.23-v-20753.47.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.471-t-21623.12-v-21804.18.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.472-t-21613.95-v-22526.77.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.473-t-21665.54-v-19414.22.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.474-t-21679.34-v-20726.25.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.475-t-21522.75-v-18154.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.476-t-21677.19-v-21703.89.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.477-t-21732.09-v-20904.93.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.478-t-21720.75-v-21494.50.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.479-t-21805.30-v-21635.04.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.48-t-11399.81-v-11532.48.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.480-t-21875.67-v-22448.02.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.481-t-21903.27-v-20784.84.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.482-t-21805.40-v-21824.38.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.483-t-21839.90-v-22591.29.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.484-t-21737.91-v-19660.26.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.485-t-21910.98-v-22690.78.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.486-t-22159.52-v-22002.30.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.487-t-22152.31-v-21893.94.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.488-t-22092.58-v-22386.80.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.489-t-22248.23-v-21704.19.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.49-t-11555.60-v-11541.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.490-t-22356.46-v-21028.26.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.491-t-22443.98-v-22231.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.492-t-22415.64-v-22251.69.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.493-t-22560.38-v-22363.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.494-t-22341.86-v-19591.76.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.495-t-22188.57-v-22113.62.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.496-t-22219.41-v-21651.88.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.497-t-22628.19-v-22029.50.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.498-t-22151.63-v-22726.09.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.499-t-22412.73-v-22829.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.50-t-11651.52-v-11183.89.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.500-t-22136.20-v-19135.61.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.501-t-21976.84-v-22567.17.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.502-t-22335.04-v-22738.02.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.503-t-22058.58-v-21267.60.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.504-t-22091.93-v-23033.05.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.505-t-22232.77-v-22077.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.506-t-21635.45-v-21472.72.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.507-t-21487.92-v-20883.98.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.508-t-22009.68-v-23077.68.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.509-t-22211.92-v-22499.36.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.51-t-11752.32-v-11663.19.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.510-t-22325.24-v-22926.72.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.511-t-22172.29-v-22229.13.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.512-t-22556.67-v-22448.64.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.513-t-22229.06-v-21955.22.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.514-t-22029.22-v-22220.54.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.515-t-22375.26-v-23060.80.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.516-t-22131.69-v-22929.87.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.517-t-22543.36-v-16512.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.518-t-21905.33-v-23201.88.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.519-t-22847.47-v-23055.67.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.52-t-11847.30-v-11927.68.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.520-t-22629.36-v-22891.08.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.521-t-22671.23-v-22866.79.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.522-t-22829.54-v-22717.33.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.523-t-22700.50-v-23571.97.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.524-t-22860.07-v-23174.24.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.525-t-22673.77-v-23177.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.526-t-22498.73-v-22727.05.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.527-t-22593.42-v-22736.14.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.528-t-22568.23-v-22102.48.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.529-t-22417.76-v-22409.87.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.53-t-11773.67-v-11616.52.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.530-t-22652.57-v-22812.67.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.531-t-22635.87-v-20819.79.hdf5',
# ...
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.853-t-23030.73-v-24026.00.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.854-t-23308.54-v-23369.80.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.855-t-23039.54-v-24082.83.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.856-t-23051.38-v-22160.21.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.857-t-22914.47-v-22061.23.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.858-t-22566.42-v-22222.96.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.859-t-22294.22-v-20679.49.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.86-t-12063.49-v-12463.80.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.860-t-22581.90-v-23863.87.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.861-t-23449.54-v-23643.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.862-t-22800.59-v-23079.49.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.863-t-22611.54-v-23465.19.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.864-t-22769.81-v-21820.46.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.865-t-22692.61-v-23096.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.866-t-22640.17-v-21182.70.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.867-t-22388.77-v-22066.16.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.868-t-22371.29-v-21544.80.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.869-t-22604.39-v-22475.43.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.87-t-12241.90-v-12289.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.870-t-22745.12-v-20542.23.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.871-t-22775.25-v-21950.75.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.872-t-22798.49-v-23400.70.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.873-t-22966.72-v-23346.46.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.874-t-23273.32-v-22668.76.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.875-t-22974.03-v-22144.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.876-t-23042.26-v-23515.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.877-t-23244.01-v-23013.22.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.878-t-23165.53-v-21244.57.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.879-t-23008.62-v-23109.90.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.88-t-11859.50-v-12905.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.880-t-23172.55-v-24208.35.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.881-t-23073.34-v-23392.95.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.882-t-23110.01-v-23069.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.883-t-23259.76-v-23739.25.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.884-t-22930.51-v-23138.64.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.885-t-23048.85-v-23218.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.886-t-22850.06-v-20359.69.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.887-t-22954.91-v-23728.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.888-t-23439.16-v-21408.21.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.889-t-22848.46-v-22474.88.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.89-t-12478.43-v-12464.23.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.890-t-22567.21-v-23104.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.891-t-22682.02-v-17985.66.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.892-t-22900.31-v-22752.03.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.893-t-22714.33-v-24065.23.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.894-t-22234.79-v-20703.53.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.895-t-22824.94-v-23206.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.896-t-22945.17-v-22198.99.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.897-t-22848.22-v-23129.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.898-t-23270.33-v-22503.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.899-t-22927.88-v-21551.28.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.90-t-12589.53-v-13133.68.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.900-t-22596.96-v-22660.81.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.901-t-23080.00-v-21785.70.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.902-t-23105.40-v-22212.52.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.903-t-22594.71-v-22355.28.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.904-t-22773.37-v-22621.28.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.905-t-22856.96-v-23517.65.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.906-t-22824.84-v-22642.56.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.907-t-22789.19-v-22708.70.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.908-t-22764.13-v-22818.25.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.909-t-22898.42-v-23568.45.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.91-t-12741.20-v-11439.43.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.910-t-23296.24-v-21461.43.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.911-t-23018.03-v-22988.51.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.912-t-22659.07-v-23361.13.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.913-t-23030.49-v-23252.93.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.914-t-23247.97-v-22852.32.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.915-t-23237.67-v-21719.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.916-t-23028.96-v-22203.93.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.917-t-23032.83-v-23561.95.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.918-t-22937.37-v-20041.17.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.919-t-23162.79-v-22266.92.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.92-t-9758.86-v-8454.76.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.920-t-23242.49-v-23104.28.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.921-t-23390.71-v-23110.83.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.922-t-23353.88-v-23099.83.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.923-t-23386.33-v-23325.67.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.924-t-23489.67-v-23532.07.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.925-t-23360.40-v-23943.08.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.926-t-23309.38-v-22173.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.927-t-23297.90-v-23026.47.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.928-t-23297.06-v-22498.75.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.929-t-23397.03-v-23353.35.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.93-t-11303.71-v-11560.33.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.930-t-23440.14-v-23722.02.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.931-t-23031.51-v-22242.26.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.932-t-23120.16-v-23307.69.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.933-t-23218.48-v-23089.57.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.934-t-23224.08-v-24011.09.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.935-t-23182.66-v-23296.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.936-t-23336.84-v-23682.21.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.937-t-23292.39-v-22970.49.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.938-t-23341.82-v-22749.40.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.939-t-23350.31-v-23677.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.94-t-11212.71-v-11377.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.940-t-23421.61-v-23899.68.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.941-t-23678.97-v-24089.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.942-t-23476.79-v-23209.05.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.943-t-23602.90-v-24282.52.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.944-t-23632.38-v-23135.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.945-t-23647.12-v-23639.06.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.946-t-23623.62-v-23624.37.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.947-t-23656.71-v-23667.73.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.948-t-23675.07-v-21149.27.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.949-t-23306.64-v-23602.12.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.95-t-10711.63-v-12080.21.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.950-t-23555.08-v-23994.88.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.951-t-23273.24-v-23982.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.952-t-23339.98-v-22879.54.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.953-t-23502.58-v-23333.70.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.954-t-23413.81-v-22954.97.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.955-t-23388.21-v-22790.51.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.956-t-23355.19-v-22494.47.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.957-t-23448.23-v-21402.20.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.958-t-23104.78-v-24151.52.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.959-t-23585.70-v-23205.63.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.96-t-11929.45-v-12664.31.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.960-t-23089.24-v-23533.46.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.961-t-22697.77-v-23761.03.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.962-t-23456.20-v-22729.87.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.963-t-23466.64-v-23389.48.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.964-t-23248.63-v-23713.14.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.965-t-22955.33-v-23808.33.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.966-t-22959.57-v-18462.86.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.967-t-22943.62-v-23475.82.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.968-t-22965.94-v-22460.56.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.969-t-23097.97-v-22482.46.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.97-t-12281.74-v-12705.76.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.970-t-23007.28-v-23740.90.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.971-t-22916.65-v-22748.84.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.972-t-23069.21-v-22407.22.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.973-t-23242.21-v-23061.34.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.974-t-23215.98-v-23277.28.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.975-t-23154.81-v-23594.64.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.976-t-23242.75-v-20574.67.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.977-t-22875.36-v-22663.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.978-t-22782.17-v-22374.17.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.979-t-23282.13-v-23299.85.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.98-t-12773.04-v-13193.56.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.980-t-23823.01-v-23633.42.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.981-t-22783.54-v-23593.11.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.982-t-22904.26-v-23123.92.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.983-t-22619.83-v-23328.94.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.984-t-23005.58-v-16301.35.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.985-t-22467.39-v-20750.26.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.986-t-22314.47-v-23202.09.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.987-t-22259.65-v-20152.49.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.988-t-22766.95-v-23771.06.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.989-t-22969.38-v-22833.04.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.99-t-12708.59-v-10743.44.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.990-t-22938.70-v-23858.02.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.991-t-23147.33-v-22781.89.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.992-t-23028.60-v-23668.05.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.993-t-22982.27-v-23379.94.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.994-t-23123.32-v-22758.49.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.995-t-22978.04-v-22041.72.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.996-t-22734.79-v-20992.52.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.997-t-23361.51-v-24349.56.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.998-t-22848.09-v-23441.36.hdf5',
#  './trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.999-t-22744.58-v-22760.10.hdf5']

# %%
def extract_val_metric(fname):
    try:
        val_str = fname.split("-v-")[-1].replace(".hdf5", "")
        return float(val_str)
    except Exception:
        return float("-inf")

best_ckpt = None
best_val = float("-inf")

for f in checkpoint_files:
    val = extract_val_metric(os.path.basename(f))
    if val > best_val:
        best_val = val
        best_ckpt = f

print(f"Loading model from {best_ckpt}")
model.load_weights(best_ckpt)
# Out:
# Loading model from ./trained_models/model-9f5e5c2c-checkpoints/checkpoints/weights.997-t-23361.51-v-24349.56.hdf5

# %%
plt.scatter(training_history['epoch'], training_history['loss'])
plt.scatter(training_history['epoch'], training_history['val_loss'])
plt.legend(['training', 'validation'])
plt.grid(True)
plt.xlabel('Epochs')
plt.ylabel('NLL loss')
plt.tight_layout() 

plt.savefig(os.path.join(base_dir,'training_hist.png'))
plt.show()

# %%
dataset_base_dir = "/depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/contained"
tfrecords_base_dir = os.path.join(dataset_base_dir, "TFR_files", "2t")
tfrecords_dir_val   = os.path.join(tfrecords_base_dir, "TFR_val")

# %%
test_generator = OptimizedDataGenerator(
    load_from_tfrecords_dir= tfrecords_dir_val,
    shuffle=True,
    seed=42,
    quantize=True,
)
labels_scale = test_generator.labels_scale
print(labels_scale)
# Out:
# WARNING:root:Quantization is True in data generator. This may affect model performance.
# Loading metadata from /depot/cms/users/das214/datasets/dataset_3sr/dataset_3sr_16x16_50x12P5_parquets/contained/TFR_files/2t/TFR_val/metadata.json
# [99.17029747 24.79370923  6.53245764  1.89031215]

# %%
# predicts test data
p_test = model.predict(test_generator)
# Out:
#  4/21 [====>.........................] - ETA: 0s
# 2025-07-17 16:40:22.565546: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 21/21 [==============================] - 2s 74ms/step

# %%
complete_truth = None
for _, y in tqdm(test_generator):
        if complete_truth is None:
            complete_truth = y
        else:
            complete_truth = np.concatenate((complete_truth, y), axis=0)
# Out:
# 100%|██████████| 21/21 [00:01<00:00, 15.30it/s]

# %%
def softplus(x):
    x = np.asarray(x)
    return np.maximum(x, 0) + np.log1p(np.exp(-np.abs(x)))

# %%
# creates df with all predicted values and matrix elements - 4 predictions, all 10 unique matrix elements
df = pd.DataFrame(p_test,columns=['x','M11','y','M22','cotA','M33','cotB','M44','M21','M31','M32','M41','M42','M43'])

# stores all true values in same matrix as xtrue, ytrue, etc.
df['xtrue'] = complete_truth[:,0]
df['ytrue'] = complete_truth[:,1]
df['cotAtrue'] = complete_truth[:,2]
df['cotBtrue'] = complete_truth[:,3]
df['M11'] = minval+tf.math.maximum(df['M11'], 0)
df['M22'] = minval+tf.math.maximum(df['M22'], 0)
df['M33'] = minval+tf.math.maximum(df['M33'], 0)
df['M44'] = minval+tf.math.maximum(df['M44'], 0)

df['sigmax'] = abs(df['M11'])
df['sigmay'] = np.sqrt(df['M21']**2 + df['M22']**2)
df['sigmacotA'] = np.sqrt(df['M31']**2+df['M32']**2+df['M33']**2)
df['sigmacotB'] = np.sqrt(df['M41']**2+df['M42']**2+df['M43']**2+df['M44']**2)

# calculates residuals for x, y, cotA, cotB
residuals = df['xtrue'] - df['x']
residualsy = df['ytrue'] - df['y']
residualsA = df['cotAtrue'] - df['cotA']
residualsB = df['cotBtrue'] - df['cotB']

# stores results as csv
df.to_csv("test_4x4.csv",header=True,index=False)

# %% [markdown]
# # residuals (mean, stdv)

# %%
# x
(np.mean(residuals)*labels_scale[0],np.std(residuals)*labels_scale[0])
# Out:
# (1.2406947506683246, 15.617269135564856)

# %%
# y
(np.mean(residualsy)*labels_scale[1],np.std(residualsy)*labels_scale[1])
# Out:
# (-0.32416102222741305, 3.615560347360132)

# %%
# cotA
(np.mean(residualsA)*labels_scale[2],np.std(residualsA)*labels_scale[2])
# Out:
# (-0.02187627061920076, 0.5321166181766658)

# %%
# cotB
(np.mean(residualsB)*labels_scale[3],np.std(residualsB)*labels_scale[3])
# Out:
# (0.017748707675440716, 0.1348528446701987)

# %% [markdown]
# # x residuals

# %%
plt.hist(p_test[:,0],bins=np.linspace(-2,2,50))
plt.yscale('log')
plt.xlabel(r'$x$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residuals,bins=np.linspace(-1,1,50))
#plt.yscale('Log')
plt.xlabel(r'$x-\mu_x$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['xtrue'], y=(df['xtrue']-df['x']), x_bins=np.linspace(-1,1,50), fit_reg=None, marker='.')
plt.xlabel(r'True $x$ [um]')
plt.ylabel(r'$x-\mu_x$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # y residuals

# %%
plt.hist(p_test[:,2],bins=np.linspace(-1.5,1.5,50))
plt.yscale('log')
plt.xlabel(r'$y$ [um]')

save_fig_path = os.path.join(plot_dir, 'y_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residualsy,bins=np.linspace(-1,1,50))
#plt.yscale('Log')
plt.xlabel(r'$y-\mu_y$ [um]')

save_fig_path = os.path.join(plot_dir, 'y_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['ytrue'], y=(df['ytrue']-df['y']), x_bins=np.linspace(-1,1,50), fit_reg=None, marker='.')
plt.xlabel(r'True $y$ [um]')
plt.ylabel(r'$y-\mu_y$ [um]')

save_fig_path = os.path.join(plot_dir, 'x_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # cotA residuals

# %%
plt.hist(df["cotA"],bins=np.linspace(-1.25,1.25,50))
plt.yscale('log')
plt.xlabel(r'$cotA$')

save_fig_path = os.path.join(plot_dir, 'cotA_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residualsA,bins=np.linspace(-0.5,0.5,50))
#plt.yscale('Log')
plt.xlabel(r'$cotA-\mu_{cotA}$')

save_fig_path = os.path.join(plot_dir, 'cotA_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['cotAtrue']*labels_scale[2], y=(df['cotAtrue']-df['cotA'])*labels_scale[2], x_bins=np.linspace(-labels_scale[2],labels_scale[2],50), fit_reg=None, marker='.')
plt.xlabel(r'True $cotA$ [um]')
plt.ylabel(r'$cotA-\mu_{cotA}$ [um]')

save_fig_path = os.path.join(plot_dir, 'cotA_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # cotB residuals

# %%
plt.hist(df["cotB"]*labels_scale[3],bins=np.linspace(-labels_scale[3],labels_scale[3],50))
#plt.yscale('Log')
plt.xlabel(r'$cotB$')

save_fig_path = os.path.join(plot_dir, 'cotB_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
plt.hist(residualsB*labels_scale[3],bins=np.linspace(-labels_scale[3],labels_scale[3],50))
#plt.yscale('Log')
plt.xlabel(r'$cotB-\mu_{cotB}$')

save_fig_path = os.path.join(plot_dir, 'cotB_res_dist.png')
plt.savefig(save_fig_path)

plt.show()

# %%
x = sns.regplot(x=df['cotBtrue']*labels_scale[3], y=(df['cotBtrue']-df['cotB'])*labels_scale[3], x_bins=np.linspace(-labels_scale[3],labels_scale[3],100), fit_reg=None, marker='.')
plt.xlabel(r'True $cotB$')
plt.ylabel(r'$cotB-\mu_{cotB} $')

save_fig_path = os.path.join(plot_dir, 'cotB_vs_res.png')
plt.savefig(save_fig_path)

plt.show()

# %% [markdown]
# # pull

# %%
df['pullx'] = (df['xtrue']-df['x'])/df['sigmax']
df['pully'] = (df['ytrue']-df['y'])/df['sigmay']
df['pullcotA'] = (df['cotAtrue']-df['cotA'])/df['sigmacotA']
df['pullcotB'] = (df['cotBtrue']-df['cotB'])/df['sigmacotB']

# %%
plt.hist(df['sigmax'] *labels_scale[0],bins=np.linspace(0,35,50))
plt.xlabel('$\sigma_{x}$')
plt.yscale('log')

# %%
plt.hist(df['sigmay']*labels_scale[1],bins=np.linspace(0,6,50))
plt.xlabel('$\sigma_{y}$')
plt.yscale('log')

# %%
plt.hist(df['sigmacotA'] *labels_scale[2],bins=np.linspace(0,1.0,50))
plt.xlabel('$\sigma_{cotA}$')
plt.yscale('log')

# %%
plt.hist(df['sigmacotB'] *labels_scale[3] ,bins=np.linspace(0,0.6,50))
plt.xlabel('$\sigma_{cotB}$')
plt.yscale('log')

# %%
from scipy.optimize import curve_fit

def gauss(x, A, mu, sigma):
    return A * np.exp(-(x - mu) ** 2 / (2 * sigma ** 2))

def pull_plot(ax, var, name):
    
    h = ax.hist(df[var],bins=np.linspace(-5,5,50),histtype='step')
    ax.set_xlabel(name)
    ax.set_yscale('log')

    ydata = h[0]
    xdata = h[1][:-1]+3/50.

    pars, cov = curve_fit(gauss,xdata,ydata)

    xbins = np.linspace(-5,5,100)
    ax.plot(xbins,gauss(xbins,pars[0],pars[1],pars[2]),color='black')
    ax.set_ylim(0.5,100000)

    print('Mean',pars[1])
    print('Sigma',pars[2])
    
    ax.text(-5,2000,"$\mu$="+str(round(pars[1],2)))
    ax.text(-5,1000,"$\sigma$="+str(round(abs(pars[2]),2)))

# %%
fig, axes = plt.subplots(2,2,sharex=True,sharey=True,figsize=(8,6))
pull_plot(axes[0][0],'pullx',r'$x$ pull')
pull_plot(axes[0][1],'pully',r'$y$ pull')
pull_plot(axes[1][0],'pullcotA',r'$\cot\alpha$ pull')
pull_plot(axes[1][1],'pullcotB',r'$\cot\beta$ pull')

save_fig_path = os.path.join(plot_dir, 'Pull.png')
plt.savefig(save_fig_path)

plt.show()
# Out:
# Mean 0.04818278807518127
# Sigma 1.1212731113846937
# Mean -0.1630069743889692
# Sigma 1.0707545692290243
# Mean -0.057655624649250115
# Sigma -1.066219083915813
# Mean 0.09412408520272968
# Sigma 0.9774795140420731

# %%
def residual_plot(ax, thisdf, var1, var2, name, scaling=1.0):
    
    nbins = 15
    
    var1_scaled = thisdf[var1] * scaling
    var2_scaled = thisdf[var2] * scaling
    residual_scaled = var1_scaled - var2_scaled
    
    xmin = np.min(var1_scaled)
    xmax = np.max(var1_scaled)
    
    step = 1.0*(xmax-xmin)/nbins
    
    x = sns.regplot(x=var1_scaled, y=residual_scaled, x_bins=np.linspace(xmin,xmax,nbins), fit_reg=None, marker='.', ax=ax)
    ax.set_xlabel('True ' + name)
    ax.set_ylabel('True - predicted ' + name)
    
    thisdf['residual'+var2] = residual_scaled
    print(var1)
    
    means = []
    upbar = []
    downbar = []
    for i in range(0,nbins):
        means += [np.mean(thisdf['residual'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)])]
        upbar += [means[i] + np.mean(thisdf['sigma'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)] * scaling)]
        downbar += [means[i] - np.mean(thisdf['sigma'+var2][(var1_scaled>xmin + i*step) & (var1_scaled<xmin + (i+1)*step)] * scaling)]
    ax.fill_between(x=np.linspace(xmin,xmax,nbins),y1=upbar,y2=downbar, alpha=0.2)

def inverse_cot(cota):
    a = np.arctan(1.0/cota)
    a[np.where(a<0)] = a[np.where(a<0)] + pi
    return a    

def residual_plot_deg(ax, thisdf, var1, var2, name, scaling=1.0):
    # positions
    if 'cot' not in var1:
        residual_plot(ax, thisdf, var1, var2, name, scaling=scaling)
        return

    thisdf['angle'] = inverse_cot(thisdf[var2].values * scaling)*180/pi
    
    thisdf['angleup'] = abs(inverse_cot((thisdf[var2].values + thisdf['sigma'+var2].values) * scaling)*180/pi - thisdf['angle'])
    thisdf['angledown'] = abs(inverse_cot((thisdf[var2].values - thisdf['sigma'+var2].values) * scaling)*180/pi - thisdf['angle'])
    thisdf['angletrue'] = inverse_cot(thisdf[var1].values * scaling)*180/pi
        
    var1 = 'angletrue'
    var2 = 'angle'
    
    nbins = 15
    xmin = np.min(thisdf[var1])
    xmax = np.max(thisdf[var1])
    
    step = 1.0*(xmax-xmin)/nbins
        
    x = sns.regplot(x=thisdf[var1], y=(thisdf[var1]-thisdf[var2]), x_bins=np.linspace(xmin,xmax,nbins), fit_reg=None, marker='.', ax=ax)
    ax.set_xlabel('True ' + name)
    ax.set_ylabel('True - predicted ' + name)
    
    thisdf['residual'+var2] = (thisdf[var1]-thisdf[var2])
    print(var1)
    
    means = []    
    upbar = []
    downbar = []
    for i in range(0,nbins):
        means += [np.mean(thisdf['residual'+var2][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
        upbar += [means[i] + np.mean(thisdf['angleup'][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
        downbar += [means[i] - np.mean(thisdf['angledown'][(thisdf[var1]>xmin + i*step) & (thisdf[var1]<xmin + (i+1)*step)])]
    #ax.scatter(x=np.linspace(xmin,xmax,nbins),y=means)
    ax.fill_between(x=np.linspace(xmin,xmax,nbins),y1=upbar,y2=downbar, alpha=0.2)

# %%
fig, axes = plt.subplots(2,2,figsize=(8,6))
fig.tight_layout(pad=4.0)
residual_plot(axes[0][0],df,'xtrue','x',r'$x$ [um]', scaling=labels_scale[0])
axes[0][0].plot([-25,-25],[-10,10],color='gray',linestyle=':')
axes[0][0].plot([25,25],[-10,10],color='gray',linestyle=':')
residual_plot(axes[0][1],df,'ytrue','y',r'$y$ [um]', scaling=labels_scale[1])
axes[0][1].plot([-6.25,-6.25],[-2,2],color='gray',linestyle=':')
axes[0][1].plot([6.25,6.25],[-2,2],color='gray',linestyle=':')
residual_plot_deg(axes[1][0],df,'cotAtrue','cotA',r'$\alpha$ [deg]', scaling=labels_scale[2])
axes[1][0].plot([90,90],[-10,10],color='gray',linestyle=':')
residual_plot_deg(axes[1][1],df,'cotBtrue','cotB',r'$\beta$ [deg]', scaling=labels_scale[3])
axes[1][1].plot([90,90],[-10,10],color='gray',linestyle=':')

save_fig_path = os.path.join(plot_dir, 'summary.png')
plt.savefig(save_fig_path)
# Out:
# xtrue
# ytrue
# /tmp/ipykernel_3017379/2844183014.py:31: RuntimeWarning: divide by zero encountered in divide
#   a = np.arctan(1.0/cota)
# angletrue
# /tmp/ipykernel_3017379/2844183014.py:31: RuntimeWarning: divide by zero encountered in divide
#   a = np.arctan(1.0/cota)
# angletrue
